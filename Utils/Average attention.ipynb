# %%
import argparse
import json
from copy import deepcopy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use("ggplot")

from Utils.dataset import *
from Utils.utils import *
from Models.BertClf import *
from Models.LstmClf import *
from Models.ElectraClf import *
device = torch.device("cuda:" + str(0)) if torch.cuda.is_available() else torch.device("cpu")
print(f'training device: {device, torch.cuda.get_device_name()}')
# Out:
# training device: (device(type='cuda', index=0), 'GeForce GTX 1660 Ti')

# %%
class Select_Dataset(Dataset):
    """Create the valid_dataset
    """
    def __init__(self, opt,df):
        # Load
        valid_dataset_df = df
        valid_X_arr = valid_dataset_df.Sentence.values
        valid_y_arr = valid_dataset_df.Category.values
        # Preprocessing
        # Run function `preprocessing_for_bert` on the train set and the validation set
        print('Tokenizing data...')
        valid_X_ids_tsr, valid_X_masks_tsr = preprocessing_for_bert(valid_X_arr, opt)
        print(f"valid_X_ids_tsr.shape: {valid_X_ids_tsr.shape}\nvalid_X_masks_tsr.shape: {valid_X_masks_tsr.shape}")
        
        self.ids_tsr = valid_X_ids_tsr
        self.masks_tsr = valid_X_masks_tsr
        self.labels = torch.LongTensor(valid_y_arr)
        self.df=valid_dataset_df
                
    def __getitem__(self, index):
        ids_tsr = self.ids_tsr[index]
        masks_tsr = self.masks_tsr[index]
        label_tsr = self.labels[index]
        return [ids_tsr, masks_tsr, label_tsr]

    def __len__(self):
        return len(self.ids_tsr)

# %% [markdown]
# ## Total code

# %%
option=2

# %%
signature = "jh_BILSTM_6M_1D_15H_10M"

# %%
# Define signature
signature = "jh_BERT_6M_1D_20H_8M"

# %%
# Define signature
#signature = "jh_ELECTRA_5M_31D_17H_5M"
signature = "sw_focal_ELECTRA_6M_1D_18H_48M"

# %%
# Load options
parser = argparse.ArgumentParser()
#     opt = parser.parse_args() # in .py env
opt, _ = parser.parse_known_args() # in .ipynb env
with open('./Saved_models/' + signature + '_opt.txt', 'r') as f:
    opt.__dict__ = json.load(f)
print(opt)
# Out:
# Namespace(aug=0, author='sw_focal', batch_size=16, data_path='./Dataset', dropout=0.5, embedding_dim=256, eps=1e-08, freeze_pretrained=0, gpu=0, hidden_dim=768, kernel_depth=500, kernel_sizes=[3, 4, 5], lr_clf=0.0001, lr_pretrained=1e-05, max_epoch=30, max_len=50, model='ELECTRA', num_layer=2, save=1, save_model_path='./Saved_models', save_submission_path='./Submissions', sent_embedding=0, signature='sw_focal_ELECTRA_6M_1D_18H_48M', split_ratio=1, weight_decay=0.0005)

# %%
if option==1:
    ## electra만 맞힌 경우   -> OPTION 1
    df=pd.read_csv('./Dataset/ELECTRA_CORRECT.csv')
    df_class=Select_Dataset(opt,df)
elif option==2:
    #LSTM만 맞힌 경우    -> OPTION 2
    df=pd.read_csv('./Dataset/BILSTM_CORRECT.csv')
    df_class=Select_Dataset(opt,df)
elif option==3:
    ## 세개 다 맞힌 경우   -> OPTION 3
    df=pd.read_csv('./Dataset/BERT_ELECTRA_BILSTM_CORRECT.csv')
    df_class=Select_Dataset(opt,df)
# Out:
# Tokenizing data...
# Apply the ElectraTokenizer...
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# valid_X_ids_tsr.shape: torch.Size([574, 50])
# valid_X_masks_tsr.shape: torch.Size([574, 50])

# %%
# Load untrained model
if opt.model == "BERT":
    model = BertClassifier(opt).to(device)
elif opt.model == "ELECTRA":
    model = ElectraClassifier(opt).to(device)
elif opt.model == "BILSTM":
    model = LstmClassifier(opt,30522).to(device)
elif opt.model =='ConvClassifier':
    model = ConvClassifier(opt,30522).to(device)

# %%
# Load trained model
model_save_path = str(opt.save_model_path) + "/" + opt.signature +'.model'
model.load_state_dict(torch.load(model_save_path))
model.to(device)
# Out:
# ElectraClassifier(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=768, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=768, out_features=5, bias=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Load the DataLoaders
#train_dataloader, valid_dataloader, _ = data_load(opt)

# %%
train_dataloader = DataLoader(df_class,batch_size=opt.batch_size,shuffle=False)

# %%
attention_score=[]
attention_score_idx=[]
b_ids_tsr_list=[]
for step, batch in enumerate(train_dataloader):  ####수정 필요
        # Load batch to GPU
    b_ids_tsr, b_masks_tsr = tuple(tsrs.to(device) for tsrs in batch)[:2]
    b_ids_tsr_list.extend(b_ids_tsr)
    
    if opt.model == "BERT":
        output=model.extract_sent_feature(b_ids_tsr,b_masks_tsr)
        batch_size=output[3][0].shape[0]
        for j in range(batch_size):
            check=[]
            for i in range(len(output[3])):  
                check.append(output[3][i][j].detach().cpu().numpy()) ### batch별로 뽑아내는 코드(i 뒤에 있는 숫자)
            check=np.array(check) #(layer, num_heads, sequence_length, sequence_length)
            check_tensor=torch.Tensor(check)
            attentions = check_tensor.permute(2,1,0,3) #(sequence_length, num_heads, layer, sequence_length)
            attentions_pos = attentions[0] # CLS_token (num_heads, layer, sequence_length)
            attentions_pos=attentions_pos[:,-1,:] # last layer (num_heads, sequence_length)
            attention_score.append(attentions_pos.mean(dim=0).detach().cpu().numpy())  #(batch_size,sequence_length)
            attention_score_idx.append(attentions_pos.mean(dim=0).detach().cpu().numpy().argsort()[::-1])  
    
    elif opt.model == "ELECTRA":
        output=model.extract_sent_feature(b_ids_tsr,b_masks_tsr)
        batch_size=output[2][0].shape[0]
        for j in range(batch_size):
            check=[]
            for i in range(len(output[2])):  
                check.append(output[2][i][j].detach().cpu().numpy()) ### batch별로 뽑아내는 코드(i 뒤에 있는 숫자)
            check=np.array(check) #(layer, num_heads, sequence_length, sequence_length)
            check_tensor=torch.Tensor(check)
            attentions = check_tensor.permute(2,1,0,3) #(sequence_length, num_heads, layer, sequence_length)
            attentions_pos = attentions[0] # CLS_token (num_heads, layer, sequence_length)
            attentions_pos=attentions_pos[:,-1,:] # last layer (num_heads, sequence_length)
            attention_score.append(attentions_pos.mean(dim=0).detach().cpu().numpy())  #(batch_size,sequence_length)
            attention_score_idx.append(attentions_pos.mean(dim=0).detach().cpu().numpy().argsort()[::-1])
    
    elif opt.model == "BILSTM":
        output, final_hidden_state=model.extract_sent_feature(b_ids_tsr)
        attention_score.extend(model.attention_net(output, final_hidden_state).detach().cpu().numpy())
    elif opt.model=='CNN':
        output=model.extract_sent_feature(b_ids_tsr)

# %%
attention_score_idx_sel=[]
if opt.model in ["BERT","ELECTRA"]:
    for i,j in enumerate(attention_score):
        #attention_mean =attention_score[i].sum()/len(attention_score[i][attention_score[i]>0])
        #attention_score_idx_sel.append(np.where(attention_score[i]>attention_mean))
        attention_score_idx_sel.append(attention_score[i].argsort()[::-1][:15])
        
elif opt.model=='BILSTM':
    for i,j in enumerate(attention_score):
        #attention_mean =attention_score[i].sum()/len(attention_score[i][attention_score[i]>0])
        #attention_score_idx_sel.append(np.where(attention_score[i]>attention_mean))
        attention_score_idx_sel.append(np.sort(attention_score[i].argsort()[::-1][:15]))
        #attention_score_idx_sel.append(attention_score[i].argsort()[::-1][:15])

# %%
if opt.model in ["BILSTM", "BERT", "CNN"]:
    print("Apply the BertTokenizer...")
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
elif opt.model == "ELECTRA":
    print("Apply the ElectraTokenizer...")
    tokenizer = ElectraTokenizer.from_pretrained('google/electra-base-discriminator')

# %%
sentence_word_token_e=[]
for i,j in enumerate(attention_score_idx_sel):
    sentence_word_token_e.append(tokenizer.decode(b_ids_tsr_list[i].detach().cpu().numpy()[attention_score_idx_sel[i]]))

# %% [markdown]
# ## Option 1
# ### bert

# %%
sentence_word_token
# Out:
# ['[CLS] so genial isce, those that you throughout, dearly hoping. [SEP]',
#  '[CLS] does has some value - well like [SEP]',
#  '[CLS] our, but it grows monotonous after a, as do s. [SEP]',
#  '[CLS] one of but fails to to either in three of screen time.',
#  '[CLS] a medcre exercise,. [SEP]',
#  'that works',
#  '[CLS] excessive tires, the, has its handful ofeeming features. [SEP]',
#  '[CLS] pity is that responsible did t and retle it direct - video and send it its home. [SEP]',
#  '[CLS] halfway, having,tates into a gross - out with that are more. [SEP]',
#  '[CLS], but he feels like a. [SEP]',
#  "it's better than",
#  'is ok to a apparatus, and human [SEP]',
#  '[CLS] an untable look, prism. [SEP]',
#  '[CLS] hasolate, but a, manages to infuse with flashes warmth gentle humor. [SEP]',
#  'another how is losing. [SEP]',
#  '[CLS]uchi vividly captures, chafing against manic and. [SEP]',
#  "[CLS] it's an interesting effort, and barry's cold - act makes worthwhile. [SEP]",
#  '[CLS] an instance. [SEP]',
#  "[CLS] would n t exist without the precedent of, whose'goes to essence [SEP]",
#  'or is one greatest date. [SEP]',
#  '[CLS] what envens this, beyond beautifully detailed all, is a note of defiance. [SEP]',
#  '[CLS] stinks to, gloom. [SEP]',
#  ', moments of caused me to jump in my chair. [SEP]',
#  '[CLS] a boring where,. [SEP]',
#  'a and a cruel. [SEP]',
#  "[CLS] while, nolan's penetrating undercunt of and flair lends stimulating depth. [SEP]",
#  ', the sening and an extremely flat do little thisailing reputation. [SEP]',
#  ', bears out as your typical junk. [SEP]',
#  'settle into aninghed rhythm of artificial suspense. [SEP]',
#  'a disaster of a, [SEP]',
#  '[CLS] but delivers the same bad. [SEP]',
#  '[CLS] the needed more emphasis and the machine that wo. [SEP]',
#  '[CLS] a respectable venture its, lacking. [SEP]',
#  'a compelling, gut clutching piece of that carries you along a torrent of emotion as it [SEP]',
#  'overly long andful. [SEP]',
#  "[CLS] despite slick and's pacing, the final effect is like. [SEP]",
#  'and! [SEP]',
#  '[CLS] it feels more forced than',
#  '[CLS] it, it still cuts all the way down to broken. [SEP]',
#  'get, to more [SEP]',
#  "it's a solid about [SEP]",
#  "a but it's nowhere near as exciting as. [SEP]",
#  '[CLS] the filmmakers are playing. to that end, they mock, [SEP]',
#  'everybody loves and this one is told almost entirely [SEP]',
#  '[CLS], it otherwise drowns in a sea ofiche. [SEP]',
#  '[CLS] the itself is far from disappointing, offering an, and another rate performance. [SEP]',
#  '[CLS] caine makes us watch as his characterns the. [SEP]',
#  'wishtalk had this true. [SEP]',
#  's is not, but it is effective [SEP]',
#  'for its, loses fire midway, nearly. [SEP]',
#  'drawn in by the dark [SEP]',
#  'it just sits there like a [SEP]',
#  '[CLS] lacks the,, and perhaps of. [SEP]',
#  '[CLS] kicks an and then ends with a whimper. [SEP]',
#  '[CLS], but friday spreads them pretty thin. [SEP]',
#  "[CLS] ', we cut to new, also to [SEP]",
#  '[CLS] a chilling without [SEP]',
#  '[CLS] for a, there is precious little of [SEP]',
#  '[CLS] just want you enjoy without. [SEP]',
#  '[CLS],tic. [SEP]',
#  '[CLS]. a and ultimately empty. [SEP]',
#  '[CLS], but the guys still feels. [SEP]',
#  '[CLS] with little superb, this latest may put off and alike. [SEP]',
#  '[CLS] what happens? [SEP]',
#  '[CLS] as franco has all dean, but none of his [SEP]',
#  'as as, there is an accuracy, that keeps grounded in anble. [SEP]',
#  '[CLS] patchy combination of, and,. [SEP]',
#  'rome really wrong with ricture [SEP]',
#  '[CLS] it watch video, but that should n t stop french from. [SEP]',
#  '[CLS] an empty shell rather. [SEP]',
#  '[CLS], but it gets the job done. [SEP]',
#  '[CLS] the film does give a pretty good overall. [SEP]',
#  "[CLS] if'n t put you off, this will be an enjoyable choice for younger [SEP]",
#  '[CLS] comively watchable no matter. [SEP]',
#  ', the movie is rather choppy [SEP]',
#  '[CLS] plays out with a dogged and eventually winning squareness it. [SEP]',
#  "[CLS] even though,'s still entertaining. [SEP]",
#  '[CLS] the has the uncanny ability to. [SEP]',
#  'a moving uneven success.',
#  'oh that clever angle [SEP]',
#  '[CLS] two has appeal beyond. [SEP]',
#  'curiously suffers it does its - minute length. [SEP]',
#  'but a really strong second effort [SEP]',
#  'runs through remarkable short [SEP]',
#  '[CLS] expecting the entire exercise has no. [SEP]',
#  '[CLS] put, pantheon body work. [SEP]',
#  '[CLS]. enthusiastically invokes the, the and the sense that. [SEP]',
#  '10 which is worth seeing',
#  '[CLS] the lousy all but spits out. [SEP]',
#  'pressed more clingly sappy than evelyn this year. [SEP]',
#  '[CLS], the are quietly moving. [SEP]',
#  '[CLS] for a the does t, but introduces who. [SEP]',
#  'a. [SEP]',
#  "' quitting hits home with disorienting force [SEP]",
#  "[CLS] despite, rarely seems interested's as as. [SEP]",
#  '[CLS] it is parochial, accessible,, and smugly suggests [SEP]',
#  '- splitting exercise in. [SEP]',
#  'this is not a [SEP]',
#  '[CLS] that has usually been leavened by a charm that s conspicuously missing. [SEP]',
#  '[CLS] his screenplay needs some serious re - working to dilemma,. [SEP]',
#  "[CLS] ends up being mostly about, and joancky, times'[SEP]",
#  '[CLS] is just as ill - fitting as, and the would sink. [SEP]',
#  'a film that loses. [SEP]',
#  'has partly down. [SEP]',
#  '[CLS] underwater, below casts its and spits back, grzled and charred, somewhere. [SEP]',
#  'is painfully foolish in hold. [SEP]',
#  'as uninkingly pure is distinctrity and an event [SEP]',
#  '[CLS] great performances,ish cinematography and a help make a [SEP]',
#  "he's not [SEP]",
#  'aallyed and sloppy. [SEP]',
#  'a movie [SEP]',
#  'memorable that does its [SEP]',
#  "[CLS]'s witty, wiful,? [SEP]",
#  ", i'recommend dvd and just skipping to [SEP]",
#  '[CLS] is, but in hisal,c drains his movie of all individuality. [SEP]',
#  '##ves into the leaning on badly. [SEP]',
#  'done excellent work here. [SEP]',
#  'belbility was t the film s [SEP]',
#  '[CLS] despite, the weight of water is oppressively heavy. [SEP]',
#  'a movie that s about asaring and it depicts [SEP]',
#  "[CLS] hannibal yes it'like [SEP]",
#  'never [SEP]',
#  '[CLS] as chilling and fascinating as -. [SEP]',
#  ', and as the is basically just a [SEP]',
#  '[CLS] but something far more and hence more chilling effective. [SEP]',
#  'an ebullient tunisian about startling transformation. [SEP]',
#  'directing with a sure and measured hand, steers and offers instead an unching and objective. [SEP]',
#  'yet curiously andpy recycling which. [SEP]',
#  '[CLS] as, this homage fires on all plasma. [SEP]',
#  ', the film suffers from aistic and a, conclusion. [SEP]',
#  '[CLS] will and the should the converts too',
#  '[CLS], narc is strictly. [SEP]',
#  'an even endeavor than. [SEP]',
#  '[CLS] the modern remake is long on narrative and short on [SEP]',
#  's too committed [SEP]',
#  "one, it's not very good [SEP]",
#  "is itself intacto's luckiest stroke [SEP]",
#  'stress. [SEP]',
#  '[CLS] is never. [SEP]',
#  'a lot more dimensional and complex than its. [SEP]',
#  '[CLS] obviously, a lot wasted a on something very incial. [SEP]',
#  "[CLS] immensely and even though, you'll want things to. [SEP]",
#  'heart, but he needs to pull head his butt [SEP]',
#  'something. [SEP]',
#  '[CLS] lets the da in classic mode, and stumbles. [SEP]',
#  "anling aesthetic one that's baroque beauty [SEP]",
#  '[CLS] : the message is consistent with. [SEP]',
#  '[CLS] does point the. [SEP]',
#  "it's a of a that does [SEP]",
#  '[CLS] a creepy, intermittently powerful study about as. [SEP]',
#  '[CLS] s it just more same, done with noticeably less. [SEP]',
#  '[CLS] a compelling that [SEP]',
#  '[CLS] the lack, with the exception [SEP]',
#  '[CLS] served with [SEP]',
#  "[CLS] only pain you'll is your. [SEP]",
#  ', but the film sits with square conviction and touching good sense its [SEP]',
#  'an. [SEP]',
#  '[CLS] this is a monumental achievement in practically everyept filmmaking :',
#  'it s not bad [SEP]',
#  '[CLS] while not, this often very funny comedy goes a long way toward restoring. [SEP]',
#  '[CLS] is exceedingly pleasant, designed',
#  "but awe ; we're wrapped up in,,. [SEP]",
#  '[CLS] well jason and a can be off the of ideas for - - hey n t - [SEP]',
#  'the is enough, but s difficult shrug annoyance that chat fish [SEP]',
#  'a lot like it -, andless. [SEP]',
#  'the movie is agible of manipulation, an [SEP]',
#  '[CLS] whether statham move, but again, who says he has? [SEP]',
#  '[CLS] the film delivers what it promises : a look at sketch. [SEP]',
#  '[CLS] a fascinating examination. [SEP]',
#  '[CLS] rich in atmosphere, it manages to without dust. [SEP]',
#  '[CLS] is a lot like a well :, and but still quitesty and inviting all same. [SEP]',
#  "[CLS] the film's sometimes undermines the. [SEP]",
#  '[CLS] at no during did viewer that, though in, never lot. [SEP]',
#  'must indeed good to this laugh. [SEP]',
#  '[CLS] the help overcome the. [SEP]',
#  "[CLS] a rather brilliant little cult item : a ',. [SEP]",
#  'this slender feels especially thin stretched over. [SEP]',
#  'perhaps found s of kitsch hard going. [SEP]',
#  'an incredibly - joke targeted. [SEP]',
#  '[CLS] is, but as makes the right at every. [SEP]',
#  '[CLS] vera has created a provocative, absorbing drama that curse. [SEP]',
#  '[SEP]',
#  "[CLS] it's also uninspired, lacking real. [SEP]",
#  'is, he can not overcome the sense that pumpkin is a. [SEP]',
#  'a pain',
#  'a witty,. [SEP]']

# %% [markdown]
# ### Electra

# %%
sentence_word_token
# Out:
# ['[CLS] soial isceit, is for throughout, the. [SEP]',
#  '[CLS] does - how much on. [SEP]',
#  "[CLS] there's violence of in hold attention butous as do's. [SEP]",
#  '[CLS] one of those spannings fails to in time. [SEP]',
#  '[CLS] a exercise in, unaware that s of. [SEP]',
#  'that.',
#  '[CLS] thoughome, the principle, as be long. [SEP]',
#  "[CLS] the great is that didn't - retitle it video to. [SEP]",
#  '[CLS] halfway through, however, dry, ii are. [SEP]',
#  '[CLS] nohe has documentary he. [SEP]',
#  's than menace.',
#  '[CLS] it ok to be sitcom apparatus,. [SEP]',
#  '[CLS] angettable at of that omnibus called marriage. [SEP]',
#  '[CLS] skins has a desolate air, but eyre, bye the. [SEP]',
#  '... of.',
#  "[CLS]uchily captures now, chafing against'snessyingsse. [SEP]",
#  "[CLS]'s effort -rb and's act worthwhile. [SEP]",
#  '[CLS] an instance of dogventing. [SEP]',
#  "[CLS] american as wouldn't exist without the precedent fun s sake to of. [SEP]",
#  '[CLS], kissing jessica stein is movies. [SEP]',
#  '[CLS] whatlivens this, theoso, is defiance overtes. [SEP]',
#  'stinks finish, like wet.',
#  '[CLS] despite the holes,... [SEP]',
#  '[CLS] a mas ball where,, bad. [SEP]',
#  '[CLS] and a cruel story. [SEP]',
#  '[CLS]nia is ways remake, s cinemas - lrb - itb. [SEP]',
#  "[CLS],'s performance salvage this'sailing reputation. [SEP]",
#  'once pass, focus bears out as..',
#  '[CLS] thed settle intohed of. [SEP]',
#  'a, saved byants.',
#  '[CLS] formula 51 trip. [SEP]',
#  "[CLS] the filmmakers and the won't about. [SEP]",
#  '[CLS] a, lacking... over to. [SEP]',
#  '[CLS] a clutching cinemant explores awful complications of terrifying day. [SEP]',
#  '[CLS] worshipful bio. [SEP]',
#  "[CLS] despite's tickck, effect like face for hours. [SEP]",
#  'and!',
#  '[CLS] although disney follows this, it more. [SEP]',
#  '[CLS] though withos andrah, still cuts all to bone. [SEP]',
#  'get though, that be.',
#  "' s whose but.",
#  '[CLS]working cliff but s. [SEP]',
#  '[CLS] the are to york l a. to that end, mock t understand ones t understand [SEP]',
#  '[CLS] loves davidth, and s view. [SEP]',
#  '[CLS] gets right, but its in of. [SEP]',
#  '[CLS] the movie itself is far from disappointing, offering an so to and. [SEP]',
#  '[CLS] caine makes watch character to. [SEP]',
#  '[CLS] wishers had had this. [SEP]',
#  '##1ne s not.',
#  '[CLS] for, dragon outtory. [SEP]',
#  "' re dark.",
#  'still, dish ordered.',
#  "[CLS] russellache, and perhaps budgetrs's. [SEP]",
#  '[CLS] inausiouspes through and then whimper. [SEP]',
#  "[CLS]n't quite of next. [SEP]",
#  "[CLS] whenever'seen of, to, be. [SEP]",
#  '[CLS] gore. [SEP]',
#  '[CLS], there is. [SEP]',
#  '. want to withoutned.',
#  '[CLS]ttic bo. [SEP]',
#  '[CLS]..tious of woman. [SEP]',
#  "[CLS]'the guysductive. [SEP]",
#  '[CLS] with visionsed player, thisewering.... [SEP]',
#  '[CLS] when? [SEP]',
#  '[CLS] as role, -rb - has s. [SEP]',
#  '[CLS] as broad cartoonish as screenplay is, is, in. [SEP]',
#  '[CLS]y combination of opera realism andly commentary. [SEP]',
#  'romething s!',
#  "[CLS] it be'watch home, but that shouldn't stopurs from. [SEP]",
#  '[CLS] rather than. [SEP]',
#  'may beial thanous but.',
#  '[CLS] the does give. [SEP]',
#  "if a big number like's'doesn't off,.",
#  '##able, no matter how degraded.',
#  '[CLS] surprisingly,, moviepy. [SEP]',
#  '[CLS] plays out withed winning squareness would of. [SEP]',
#  '[CLS] even though does n t, s practice. [SEP]',
#  "[CLS] the film has to right when's wrong. [SEP]",
#  'a success.',
#  'oh, at!',
#  '[CLS] two notice being vehicle or. [SEP]',
#  "[CLS] curiously, troopers does't have. [SEP]",
#  '[CLS] not as monty, but. [SEP]',
#  "##bo through's.",
#  '[CLS] the with expecting is that. [SEP]',
#  '[CLS] put blade and, pantheon. [SEP]',
#  '[CLS]... enthusiasticallyvokes half of football games. [SEP]',
#  'which seeing',
#  "all but spits out's role.",
#  "[CLS]'d filmpy evelyn. [SEP]",
#  's,.',
#  "[CLS], the hours doesn't, but whonate. [SEP]",
#  '[CLS]. [SEP]',
#  "[CLS]'re out by,ting home disor. [SEP]",
#  "[CLS] despite, knockaround guys rarely in aroundre's as guns. [SEP]",
#  '[CLS] it is, accessible to, to, andly suggests tone skill [SEP]',
#  '[CLS] splitting in formula. [SEP]',
#  'is.',
#  "[CLS] that frtic spectacle -rb -ned charm's '. [SEP]",
#  "[CLS] his -rb nelson'sb show of,. [SEP]",
#  "up being mostly about's,'sl sat",
#  '[CLS] s warm is fitting astorys, and of sink. [SEP]',
#  'of.',
#  "opening up '.",
#  '[CLS] as, below casts spook into ands back of. [SEP]',
#  "[CLS]gal to se'glory. [SEP]",
#  '[CLS] budget \\ / hours is. [SEP]',
#  '[CLS] performances feel make gangster. 1going. [SEP]',
#  'he s.',
#  '[CLS] aorged age. [SEP]',
#  'movie.',
#  '[CLS] unsettling does predecessors proud. [SEP]',
#  "' sful, what time is there?",
#  'but for to.',
#  '[CLS] the movie is loaded with in his to into familiar arc of story,c drains. [SEP]',
#  '[CLS] into,. [SEP]',
#  '[CLS] barry here. [SEP]',
#  "##bilityn't.",
#  '[CLS] despitew, the of heavy. [SEP]',
#  "[CLS] a's as. [SEP]",
#  "as say yes,'s.",
#  'never.',
#  "[CLS] as's hitler snide prejudice. [SEP]",
#  '[CLS] for the is curiosity. [SEP]',
#  '[CLS] schlocky feature butish effective. [SEP]',
#  '[CLS] an ellient film about the of who into. [SEP]',
#  '[CLS], -rbb -s ofal unflinching atverse. [SEP]',
#  '[CLS] earnest yet in whichability winner. [SEP]',
#  '[CLS] as, s island onits. [SEP]',
#  '[CLS] notwithstanding, fromistic. [SEP]',
#  '[CLS]co, and should win too. [SEP]',
#  'despite,rc is.',
#  '[CLS] an even more endeavor than. [SEP]',
#  "[CLS] the ofmas's is -rbb -. [SEP]",
#  ', s.',
#  'i did hate, s.',
#  ". is itself'siest.",
#  ". '",
#  '[CLS] john to back. [SEP]',
#  'a lot than believe.',
#  '[CLS] obviously, a of wasted of timerb on. [SEP]',
#  "[CLS]ancon, and even though is predictable,'ll want to out. [SEP]",
#  "[CLS] adamler's but to of butt [SEP]",
#  '.',
#  '[CLS] louisole in classic, and brother s over t. [SEP]',
#  "[CLS],'s in. [SEP]",
#  "[CLS] thing for : is with's. [SEP]",
#  '[CLS] does pointnic. [SEP]',
#  "[CLS] it's frankenstein does know. [SEP]",
#  '[CLS] a creepy powerful man...ling astory. [SEP]',
#  "[CLS] there's in it,,. [SEP]",
#  '[CLS] illustrates tragedy. [SEP]',
#  '[CLS], with ironic exception ofer. [SEP]',
#  '[CLS] up with heart humor [SEP]',
#  '[CLS] the ll feel as is. [SEP]',
#  '[CLS] expectzzle, but the film sits women. [SEP]',
#  'is.',
#  '[CLS] this is achievement in every inept :lessic annoying handed atrocious and creepy. [SEP]',
#  "worst's bad.",
#  '[CLS] while not, this often funny restoring theer of theoon film franchise, too toncy. [SEP]',
#  'in maidend.',
#  "[CLS] there are flaws ;'re up in. [SEP]",
#  '[CLS], s and hell, sequels -rb - hey, t - [SEP]',
#  '[CLS].. s off. [SEP]',
#  '[CLS] a lot like the onto - -less. [SEP]',
#  '[CLS] the movie isgible, doing to. [SEP]',
#  '[CLS] seen land, but again,? [SEP]',
#  "[CLS] the film delivers what : a at the ` `'' when men with phones and. [SEP]",
#  '[CLS] a of theous, self discovery made by proper. [SEP]',
#  '[CLS], it totructeking dust. [SEP]',
#  "[CLS] clint eastwood's blood work is lot like made sandwichuling. [SEP]",
#  "[CLS]'s \\ / to. [SEP]",
#  '[CLS] at no point during k 19 : themaker this in leave. [SEP]',
#  'recite ofable.',
#  '[CLS] the parker overcome the problematic. [SEP]',
#  "[CLS] a rather brilliant item : aiche of's entertainment. [SEP]",
#  '[CLS] this especially thin time. [SEP]',
#  "[CLS] perhaps the found davis's of. [SEP]",
#  '[CLS] an incredibly jokeiest of obscure. [SEP]',
#  '[CLS] this is the kind of could so been fumbled buts. [SEP]',
#  '[CLS] vera has reveals the curse of a hatreded. [SEP]',
#  '[CLS] with. [SEP]',
#  "[CLS] while the film is,'s alsopired, lackingte. [SEP]",
#  '[CLS] harris, he can not overcome is for directorsearing disabilities. [SEP]',
#  '.',
#  '[CLS] a. [SEP]']

# %%
df[(df['e_pred']==4)&(df['l_pred']==3)]
# Out:
#         Id  Category                                           Sentence  \
# 29   10060         4  Bittersweet comedy\/drama full of life , hand ...
# 58    2606         4  A compelling , gut-clutching piece of advocacy...
# 67    8340         4             A conventional but heartwarming tale .
# 104  11213         4                A classy , sprightly spin on film .
# 146   1388         4                           A riveting documentary .
# 168   7286         4  Great performances , stylish cinematography an...
# 172    148         4  An unsettling , memorable cinematic experience...
# 233   2548         4  A compelling motion picture that illustrates a...
# 235   6719         4      classic cinema served up with heart and humor
# 276   5979         4  A truly wonderful tale combined with stunning ...
# 280  10433         4                A witty , low-key romantic comedy .
#
#      b_pred  e_pred  l_pred
# 29        3       4       3
# 58        4       4       3
# 67        3       4       3
# 104       3       4       3
# 146       4       4       3
# 168       4       4       3
# 172       4       4       3
# 233       4       4       3
# 235       4       4       3
# 276       4       4       3
# 280       4       4       3

# %%
df['Sentence'].values[235]
# Out:
# 'classic cinema served up with heart and humor'

# %%
sentence_word_token[235]
# Out:
# '[CLS] up with heart humor [SEP]'

# %%
sentence_word_token_e[235]
# Out:
# 'up humor with heart [SEP] [CLS] served and cinema classic [PAD] [PAD] [PAD] [PAD] [PAD]'

# %%
sentence_word_token_l[235]
# Out:
# '[CLS] classic cinema served up with heart and [PAD] [PAD] [PAD] [PAD] [PAD] humor [PAD]'

# %% [markdown]
# ### bilstm

# %%
sentence_word_token_l[151]
# Out:
# '[CLS] a compelling motion picture that illustrates [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]'

# %%
sentence_word_token
# Out:
# ['[CLS] so genial is those of the one rare [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie does has some entertainment - how value much depends on [PAD] [PAD]',
#  "[CLS] there'[PAD] [PAD] s lots of and a [PAD] [SEP] to a bid",
#  '[CLS] one of those to be decadess intimate strive and do to fails justice',
#  '[CLS] a mediocre exercise [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] that works. [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] though excessively tiresomely pre, verbalten [PAD] [PAD] may [PAD]',
#  '[CLS] the great pity is that [PAD] [PAD] [PAD] [PAD] those [SEP] [PAD] the responsible',
#  '[CLS] halfway through, however, sucked having dry the undead scary [PAD] [PAD].',
#  "[CLS] nohe has made a decent ` intro'[PAD] [PAD] documentary [PAD] [PAD]",
#  "[CLS] it's better than the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] phantom",
#  '[CLS] it is ok for be something to a of movie [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an unforgettable look at through called tradition omnibus that of prism',
#  '[CLS] skins has a des eyre, but by aolate raised, air american',
#  '[CLS]... another example of how sand [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] hashiguchi mani s vividc'way mix thely chafin",
#  "[CLS] it's interesting an l - -rb effort for particularly j and",
#  '[CLS] an instance of an old dog [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] american musical comedy as we know it'would n t exist jolly theater",
#  '[CLS] gay or straight, kissing jessica stein is one of [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] what entuteli as direction of the cardven performances detailed beyondoso',
#  '[CLS] stinks from start to of, finish sack like gloom [PAD] [PAD] [PAD]',
#  '[CLS] despite the holes in the story and the somewhat [PAD] [PAD] of [PAD] [PAD]',
#  '[CLS] a boringquerade mas ball where normally [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a hypnotic cyber and hymn a cruel [PAD] [PAD] [PAD] story [SEP] [PAD] [PAD]',
#  '[CLS] while ins [PAD] [PAD] [SEP]om [PAD] under penetratingcuniarre is [PAD]',
#  '[CLS] though there are entertaining [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] and',
#  '[CLS] once the downward spiral [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the skirmishes for power amongd wage victims and [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a disaster of a drama [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] formula 51 promises a new kind of high [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the filmmakers needed more emphasis on the storytelling and the audience lesslamorous',
#  '[CLS] a respectable venture on its own a more mainstream to audience. terms [SEP]',
#  '[CLS] a in along compelling you a carries, [PAD] [PAD] [PAD] [PAD] that [PAD]',
#  '[CLS] overly long and worshipful bio - doc [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] despite slick tick - production s to values'and [PAD] [PAD]ck [PAD]",
#  '[CLS] and educational! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] although disney follows its standard [PAD] [PAD] [PAD] [PAD] [PAD] formula [PAD] [PAD] [PAD]',
#  '[CLS] though it flirts knowos with it bathos and path [PAD] [PAD]',
#  '[CLS] you get the idea, though, that kapur intended the [PAD] [PAD]',
#  "[CLS] it's a about people movie solid whose [PAD] lives [PAD] [PAD] [PAD]",
#  '[CLS] a reworking of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[SEP] understand to [CLS] figure they kind care the ones the that, the to',
#  '[CLS] everybody loves a david and go one this and islia, storyth',
#  '[CLS] gets the look and the period trappings [PAD] [PAD] [PAD] [PAD] [PAD] right',
#  '[CLS] the movie itself is an far offering original from [PAD] [PAD] so crucial [PAD]',
#  '[CLS] caine makes watch us as his character awakens to [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] i wish wind faith more [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] in [PAD] [PAD]',
#  "[CLS] s1m0ne's satire is not subtle, but [PAD]",
#  '[CLS] for all dragon its, loses touches brilliant its [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] we're drawn in by the [PAD] [PAD] [PAD] dark [PAD] [PAD] [PAD]",
#  '[CLS] still, it just sits there like a side dish no one. [PAD]',
#  '[CLS] russell lacks theache visual pan, the comic touch, [PAD] [PAD] [PAD]',
#  '[CLS] kicks off ends then and withings [PAD] withder [PAD] meanless plot',
#  '[CLS] ice cube is n of out ripe but thin pretty them spreads next after',
#  "[CLS] whenever you think you'[PAD] [PAD] to [PAD] [PAD] appears to [PAD] [PAD]",
#  '[CLS] a chilling movie without oppressive [PAD] gore [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] for a movie about the power there, and passion [PAD] of [PAD] [PAD]',
#  '[CLS] mr. spielberg and feeling con his withoutned yourselves company. [PAD] just',
#  '[CLS] overwrought, mel [PAD] [PAD] [PAD] [PAD]od [PAD] [PAD] [PAD]',
#  '[CLS]... a pretentious and empty examination ultimately of a [PAD]',
#  "[CLS] no one can doubt the filmmakers'motives, but [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] very with little to add beyond the already dark visions relayed may.',
#  '[CLS] what happens when something goes bump [PAD] [PAD] [PAD] [PAD] [PAD] and in night',
#  '[PAD] [SEP] the rr - franco -rb l -, role title inr',
#  '[CLS] as broad and cartoon of as accuracy anish screenplay the is is there',
#  '[CLS] patchy combination of soap - low opera tech, magic realism [PAD] [PAD]',
#  "[CLS] romething's really wrong [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] it might be to `'easier watch on home video, at but",
#  '[CLS] an empty shell of an epic rather than [PAD] [PAD] the [PAD] [PAD] [PAD]',
#  '[CLS] may be more genial than [PAD] ing [PAD]eni [PAD] [PAD]ous [PAD]',
#  '[CLS] the film does give of the picture situation overall [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] if a number like big musical ` praise the lord [PAD], [PAD] [PAD]',
#  '[CLS] compulsively watchable, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] surprisingly, considering that baird is a [PAD] [PAD] [PAD] [PAD] [PAD] former [PAD]',
#  '[CLS] plays out with of darling many a the it make a dogg anded',
#  "[CLS] even though the film does its to entertaining still s'it, marks",
#  '[CLS] the film has the uncanny ability to right [PAD] [PAD] itself [PAD] [PAD] [PAD]',
#  '[CLS] a moving, if uneven, [PAD] [PAD] [PAD] [PAD] [SEP] [PAD] [PAD] [PAD]',
#  '[CLS] oh, look at that clever angle! [PAD] [SEP] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] two weeks notice has appeal beyond being a sandra bullock [PAD] vehicle [PAD] [PAD]',
#  '[CLS] curiously, super troopers suffers because it does n to length minute - 103',
#  '[CLS] not as good as the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] rubbo runs through amount a remarkable of material [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the one not - so - small [SEP]. [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] put it somewhere between west heaven of sling, of blade and south [PAD]',
#  '[CLS]... enthusiastically invokes brass the soul percussion rhythm and,',
#  '[CLS] after the first 10 minutes [PAD] [PAD] [PAD] [PAD] [PAD] [PAD], which [PAD]',
#  '[CLS] the lousy john q [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS]'i d [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] despite the film'[PAD] [PAD] s [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] for a movie audience, the hours does'n t neat way,",
#  '[CLS] a riveting [PAD] [PAD] [PAD] documentary [PAD] [PAD] [PAD] [PAD] [SEP] [PAD]',
#  "[CLS] if you'of cinema re as notion not totally weird community the -",
#  '[CLS] despite engaging off rarely guys seems interestedbeataround kicking around in touches knock',
#  '[CLS] it is parochial accessible to, a chosen, few standoffish everyone',
#  '[CLS] ear - splitting exercise in formula crash - and [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is not a jackie chan movie [PAD] [PAD] [PAD]. [PAD] [PAD] [PAD]',
#  '[CLS] that frenetic lrb - spectacle - - by rr show a',
#  "[CLS] - his lrb - nelson's - -b rr screenplay needs",
#  "[SEP] sat no joan [CLS] matter a di and he ends'demonstrates times s",
#  "[CLS] cost asner shady fittingfuncac 'tory per -'[PAD]",
#  '[CLS] a film that loses sight of its [PAD] [PAD] own [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] ` opening up'the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] as underwater ghost casts below stories its go, into out the sp net',
#  "[CLS] seagal is painfully foolish in left trying of s to hold onto '",
#  '[CLS] a is big hours - budget \\ a / all - as the star',
#  '[CLS] great performances, stylish 1 cinematography. a and no [PAD] feel',
#  "[CLS] he's not good [PAD] [PAD] [PAD] with [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a characteristically engorged and sloppy [PAD] [PAD] coming [PAD] [PAD] [PAD]',
#  '[CLS] a modestly [PAD] [PAD] [PAD] surprising [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an unsettling, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] tsai ming - liang, witty wi'sstful film,",
#  "[CLS] but even then, i'd [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] the movie [PAD] [SEP] [PAD] is ze hisal. [PAD] inity loaded',
#  '[CLS] devolves into the derivative, on leaning badly [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] consummate actor [PAD] [PAD] [PAD] barry [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] believability was one t [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] despite an impressive roster of stars and direction from kathryn big of [PAD] [PAD]',
#  "[CLS] a movie that's overbe as aboutaring and top over -",
#  '[CLS] as hannibal would say dinner for friend old [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] never once predictable. [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] as chilling and fascinating as philippe mora's modern hitler [PAD] [PAD] [PAD]",
#  '[CLS] we never feel these characters anything for, and film as the is a',
#  '[CLS] not a far more something sc styl buthlishocky [PAD]',
#  '[CLS] an ebullie of startling transformation the widow bound a who about -',
#  '[CLS] directing with a andchingin [PAD] [PAD] objective [PAD] look at sure [PAD]',
#  '[CLS] earnest yetpy chop curiously recycling [PAD] [PAD] and [PAD] [PAD] in [PAD] [PAD]',
#  '[CLS] as action - adventure, this space - based to robert [PAD] [PAD] homage',
#  '[CLS] pc stability notwithstanding, the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] wilco fans will have a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] despite the pyrotechnic [PAD]s [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an even more predictable, cl [PAD] [PAD] [PAD] [PAD] [PAD]iche [PAD] [PAD]',
#  "[CLS] the modern remakemas of du's story is long on narrative [PAD]",
#  "[CLS] no, even that'[PAD]. [PAD] [PAD] s [PAD] [PAD] [PAD] committed",
#  "[CLS] although i didn't hate this one, [PAD] either [PAD] it",
#  '[CLS] the casting ofdo sy vonw.. [PAD] [PAD]. [PAD] luck',
#  "[CLS] stress ` dumb.'[SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] first - timer john mckay is never [PAD] [PAD] able [PAD] to [PAD] pull',
#  '[CLS] a lot more dimensional and complex than its sunny [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] obviously, a people lot of a wasted [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] garcia bernal are and anconan [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] adam sandler'may s heart be in to pull [PAD] [PAD] [PAD]",
#  '[CLS] something for everyone. [PAD] [PAD] [PAD] [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] louiso [PAD] [PAD] lets [PAD] classic di over the movie in [PAD] a',
#  "[CLS] an enth 'ral s that one steep, experienceling aesthetic [PAD]",
#  '[CLS] one thing you have to the of message : the give them movie for',
#  '[CLS] does point the way for adventurous [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] indian [PAD]',
#  "[CLS] it's a frankenstein - monster of a to be film [PAD] wants",
#  '[CLS] a a creepy of self study as, about powerful un - [PAD] [PAD]',
#  "[CLS] there'new of s not inspiration spark a [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a compelling motion picture that illustrates [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the characterizations and dialogue [PAD] [PAD] [PAD] [SEP] [PAD] lack. [PAD] [PAD]',
#  '[CLS] classic cinema served up with heart and [PAD] [PAD] [PAD] [PAD] [PAD] humor [PAD]',
#  "[CLS] the only pain ll'you feel as the [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] expect no major discoveries, nor any sits film the st but square with',
#  '[CLS] an exit sign, that [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is a monumental achievement handed -, in heavy visually ofless,',
#  "[CLS] even at its worst, half it not - s bad '. [SEP]",
#  '[CLS] while [PAD] not [SEP] [PAD] for. toward restoring way every video funny -',
#  '[CLS] everything in maid in manhattan [PAD] [PAD] [PAD], [PAD] designed [PAD] [PAD] [PAD]',
#  '[CLS] there are flaws also, of but stretches impact and of moments [PAD] [PAD]',
#  '[SEP] [CLS] well -, station space in5 245 the year messenger listrb',
#  '[CLS] the main story... [PAD] [PAD] [PAD] [PAD] is [PAD] [PAD] of',
#  '[CLS] a lot like the imaginary sport it projects [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie is a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it remains to be seen stat whetherham can move beyond the crime [PAD]',
#  '[CLS] the film a : look delivers promises what at [PAD] it [PAD] [SEP] [PAD]',
#  '[CLS] a fascinating by made a discovery examination [PAD] [PAD]ous - [PAD] [PAD] [PAD]',
#  '[CLS] rich in atmosphere of the post - [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] clint [PAD] [SEP] eastwood bo and a well [PAD]astul like '.",
#  "[CLS] the film the possibility tos'for be [PAD] [PAD] desire the [PAD]",
#  '[CLS] [PAD] [SEP] at no of themes loyalty. point its, to meant though',
#  '[CLS] the actors must indeed be to rec goodite [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the quirky and recessive charms of donovan co martin and stars -',
#  '[CLS] a rather : brilliant little item a cult entertainment past ofiche s,',
#  '[CLS] this slender plot feels especially thin stretched over [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] perhaps even the sl writerc found - command [PAD] [PAD] high [PAD] [PAD]',
#  '[CLS] an incredibly narrow in - joke an of targeted segment to tiniest already',
#  '[CLS] this is of the subject kind matter that a could by filmmaker lesser fumbled',
#  '[CLS] vera has created a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a truly wonderful tale [PAD] [PAD] [PAD] [PAD] [PAD] combined [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] while the the lacking real film, talent is spired competent'also",
#  '[CLS] though harris is affecting at sense that times the pumpkin overcome, [PAD] [PAD]',
#  '[CLS] a big fat pain [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a witty, low [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] - [PAD]']

# %% [markdown]
# ## Option 2
# ### bert

# %%
sentence_word_token
# Out:
# ['[CLS] is still a [SEP]',
#  '[CLS] more, is carried less than by its that holds after. [SEP]',
#  'a winning. [SEP]',
#  '[CLS] for all its down is a strong, character - oriented piece [SEP]',
#  "[CLS] this is not movies'to watch a. [SEP]",
#  'but in end, do n t gel [SEP]',
#  '[CLS], but reccles the premise [SEP]',
#  ', you can medcre cresting next wave [SEP]',
#  '[CLS] it would have become a, those so bad it. [SEP]',
#  '[CLS] even summer, most restless deserves dignity something. [SEP]',
#  '[CLS], zero, too many and a make for a bad [SEP]',
#  '##nis is perhaps too effective in. [SEP]',
#  'about belongs nicholson [SEP]',
#  "[CLS] what makes compelling, besides its terrific, is fontaine's willingness to. [SEP]",
#  '[CLS] in captured. [SEP]',
#  'is too savy a to let into. [SEP]',
#  '[CLS] is, the should have been made for the tube. [SEP]',
#  'this thing is virtually [SEP]',
#  'has the died strung -. [SEP]',
#  "do't seem much. [SEP]",
#  '[CLS] it cutting her, but who else engaged today is so cot [SEP]',
#  'about this movie [SEP]',
#  '[CLS], the power of this is undeniable. [SEP]',
#  '[CLS] cut through the soap and you find a scathing portrayal. [SEP]',
#  'a good that have baffled. [SEP]',
#  ', a that gets under [SEP]',
#  "while this broken is, doesn't [SEP]",
#  '[CLS] only distinguishes from is the fact that there is nothing distinguishing. [SEP]',
#  '[CLS] it all plays out. -, a. [SEP]',
#  "[CLS], there's nothing here to match that's. [SEP]",
#  '[CLS], but s also one that, next, feels clumsy and convoted. [SEP]',
#  'angling blend of psychedelic, and ` 2 is a visual treat for all. [SEP]',
#  'its is driven by [SEP]',
#  "bad, it's still not a good movie [SEP]",
#  'an movie with too too. [SEP]',
#  'a. [SEP]',
#  '[CLS] trades revulsion for unease. [SEP]',
#  '[CLS] a felt andly detailed. [SEP]',
#  '[CLS] a fascinating, unving examination. [SEP]',
#  'i survived [SEP]',
#  '[CLS]isto smartly emphasizes and omits. [SEP]',
#  '[CLS]. wise andiac [SEP]',
#  'strident and int in its. [SEP]',
#  '[CLS] odd, here a fun one. [SEP]']

# %% [markdown]
# ### Electra

# %%
sentence_word_token
# Out:
# ['[CLS] years later, t.stone. [SEP]',
#  'than, e t. up.',
#  '[CLS] winning. [SEP]',
#  '[CLS] for all twists, and on down blood work. [SEP]',
#  "[CLS] is'watch if live. [SEP]",
#  '[CLS] like about -, end, t. [SEP]',
#  '[CLS] ` creates acles. [SEP]',
#  'the is t but see.',
#  "[CLS] if des up, of's to. [SEP]",
#  '[CLS] even, the most audience by. [SEP]',
#  '[CLS] noop, see, make for bad. [SEP]',
#  '[CLS] caconis is perhaps effective creatingtility. [SEP]',
#  'to.',
#  "[CLS] what how i killed father, is fontaine's to intoing. [SEP]",
#  '.',
#  '[CLS] byler too toph into. [SEP]',
#  '[CLS] given the fact that to for, for the tube. [SEP]',
#  'isable.',
#  '[CLS] the together. [SEP]',
#  "[CLS] the ups ups don't characters. [SEP]",
#  '[CLS] it may not be or weekend and two or things i know her, but who else moral [SEP]',
#  'is red.',
#  '... impact dayfoldsble.',
#  '[CLS] cut through the find a scathing portrayal of a stling out of in. [SEP]',
#  '... film that have baffled.',
#  '[CLS] but silence, s. [SEP]',
#  '..., does t.',
#  '[CLS] the distinguishes a is the that in. [SEP]',
#  "it all out..'s.",
#  "[CLS] while serving sara, there's match s. [SEP]",
#  "[CLS]'sing, s also, to feels. [SEP]",
#  "[CLS] an eye boggling of psychedelic devices, ` kids '. [SEP]",
#  '[CLS] by. [SEP]',
#  "despite the fact that t,'s not movie",
#  '[CLS] an artsation movie with. [SEP]',
#  '.',
#  '[CLS] tradesulsion for. [SEP]',
#  '[CLS] a felt about newcomers. [SEP]',
#  '[CLS] aving ofusions. [SEP]',
#  '.',
#  '[CLS] monteistolyitssfolds. [SEP]',
#  '.....',
#  '[CLS]nt inuring. [SEP]',
#  'and \\ / or s.']

# %%
df[(df['e_pred']==3)&(df['l_pred']==4)][130:]
# Out:
#         Id  Category                                           Sentence  \
# 513  10291         4  It 's a hoot watching The Rock chomp on jumbo ...
# 519  10335         4  If you can get past the taboo subject matter ,...
# 522  10360         4                   Even better than the first one !
# 528  10558         4             The Pianist is Polanski 's best film .
# 529  10617         4               One regards Reign of Fire with awe .
# 530  10619         4                                          Amazing !
# 534  10652         4     Steven Spielberg brings us another masterpiece
# 535  10653         4  Fairy-tale formula , serves as a paper skeleto...
# 537  10692         4  Rifkin 's references are ... impeccable throug...
# 538  10708         4  As quiet , patient and tenacious as Mr. Lopez ...
# 539  10721         4  Stanley Kwan has directed not only one of the ...
# 540  10749         4  It is most remarkable not because of its epic ...
# 550  10945         4  It 's dark but has wonderfully funny moments ;...
# 551  10946         4  Poignant and moving , A Walk to Remember is an...
# 552  10953         4  Humorous and heartfelt , Douglas McGrath 's ve...
# 563  11171         4  That rare movie that works on any number of le...
# 564  11174         4  All in all , Brown Sugar is a satisfying well-...
# 566  11253         4  It 's a lovely , sad dance highlighted by Kwan...
# 567  11271         4  The problems and characters it reveals are uni...
# 569  11344         4  A must for fans of British cinema , if only be...
# 570  11427         4  The script by David Koepp is perfectly service...
#
#      b_pred  e_pred  l_pred
# 513       4       3       4
# 519       4       3       4
# 522       4       3       4
# 528       4       3       4
# 529       4       3       4
# 530       4       3       4
# 534       4       3       4
# 535       4       3       4
# 537       4       3       4
# 538       4       3       4
# 539       4       3       4
# 540       4       3       4
# 550       4       3       4
# 551       4       3       4
# 552       4       3       4
# 563       4       3       4
# 564       4       3       4
# 566       4       3       4
# 567       4       3       4
# 569       4       3       4
# 570       4       3       4

# %%
df['Sentence'].values[570]
# Out:
# 'The script by David Koepp is perfectly serviceable and because he gives the story some soul ... he elevates the experience to a more mythic level .'

# %%
sentence_word_token[570]
# Out:
# '[CLS] thepable and because...evates. [SEP]'

# %%
sentence_word_token_e[570]
# Out:
# '.able.eva because [SEP] [CLS]tes.p. the and service script'

# %%
sentence_word_token_l[570]
# Out:
# '[CLS] the script by david koepp is the experience to a [PAD] [PAD]'

# %% [markdown]
# # bilstm

# %%
sentence_word_token
# Out:
# ['[CLS] twenty years is. t still later. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] more intimate than spectacular factors by wow less than carried is [PAD]. t',
#  '[CLS] a winning and wildly [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] for all its plot twists, and of them some blood verge, on',
#  "[CLS] this is not one of the movies d [PAD] you want '. [PAD]",
#  '[CLS] there are to things like about murder by numbers - - but, in',
#  '[CLS] ` men in black [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie is nio. wave next the oning crestcre can',
#  '[CLS] if de of those oneuce movies wilds had a notch, that',
#  '[CLS] even in the the summer most,time restless young audience [PAD] [PAD] [PAD]',
#  '[CLS] no who bigop nothing, new to see, zero thrill toos',
#  '[CLS] cacoyannis is perhaps - dust cake of tood [PAD] [PAD]',
#  '[CLS] about schmidt belongs to nicholson [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]. [PAD] [PAD]',
#  '[CLS] what makes how i father to killed compelling willingness my, wander performances besides',
#  '[CLS] poetry in motion captured [PAD] [PAD] [PAD] on [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] byler is mor toophvy av sa this into [PAD] [PAD]',
#  '[CLS] given the fact that virtually no one for is to the bound it,',
#  '[CLS] this thing is virtually unwatch [PAD]able. [PAD] [PAD] [SEP] [PAD] [PAD]',
#  '[CLS] has the disjo [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the obligatory break - ups and hook - ups have characters the on impact',
#  '[SEP] moral and [CLS] of it the cultural mayt i weekend of know and',
#  '[CLS] there is nothing redeeming about this movie [PAD]. [PAD] [PAD] [SEP]',
#  '[CLS]... once the true impact of of is power this movie the',
#  '[CLS] cut through the layers of soap - of and emotion portrayal opera find [PAD]',
#  '[CLS]... a good film that must have department [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] but, like silence, it skin movie [PAD] [PAD]. your [PAD] [SEP]',
#  '[CLS]... while each moment of this anywhere go broken study character.',
#  '[CLS] the only thing film from that wallace randall any distinguishes a other is the',
#  '[CLS] it all plays like.. a. out comedy hughes high, of',
#  '[CLS] while serving [PAD] sara [SEP] [PAD] does of cr leveludi. [PAD] have',
#  "[CLS] there'sing no doubt that this is a and personal highly ambitious",
#  "[CLS] an eye - boggling blend of is psychedelic'and effects devices backgrounds",
#  '[CLS] its engaging simplicity is driven by [PAD] [PAD] appealing [PAD] [PAD] [PAD] leads [PAD]',
#  "[CLS] despite the fact that this film wasn't as to be bad",
#  '[CLS] an artsploitation movie with [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a non - mystery [PAD] [PAD] [PAD] [PAD] mystery [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] trades run - of - the - mill revulsion for [PAD] [PAD] [PAD]',
#  '[CLS] a deeply felt in newcomers a about and story detailed [PAD] [PAD] [PAD] vivid',
#  '[CLS] a fascinating, unner del [PAD] [PAD] [PAD] [PAD]usions [PAD] [PAD] the',
#  '[CLS] i survived. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] monte cristo needlessits om smart chase and wrought - storyly',
#  '[CLS]... wise and elegiac... [SEP] [PAD] [PAD]',
#  '[CLS] strident and inelegant in its ` [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] if you like quirky, odd the ironic, here or [PAD] [PAD]']

# %%
sentence_word_token_l_n[570]
# Out:
# '[CLS] the script by david ko to experienceepp the is [PAD] [PAD] a'

# %% [markdown]
# ## Before
# ## Option 1
# ### bert

# %%
sentence_word_token
# Out:
# ['[CLS] so genial isce, those that you throughout, dearly hoping. [SEP]',
#  '[CLS] does has some value - well like [SEP]',
#  '[CLS] our, but it grows monotonous after a, as do s. [SEP]',
#  '[CLS] one of but fails to to either in three of screen time.',
#  '[CLS] a medcre exercise,. [SEP]',
#  'that works',
#  '[CLS] excessive tires, the, has its handful ofeeming features. [SEP]',
#  '[CLS] pity is that responsible did t and retle it direct - video and send it its home. [SEP]',
#  '[CLS] halfway, having,tates into a gross - out with that are more. [SEP]',
#  '[CLS], but he feels like a. [SEP]',
#  "it's better than",
#  'is ok to a apparatus, and human [SEP]',
#  '[CLS] an untable look, prism. [SEP]',
#  '[CLS] hasolate, but a, manages to infuse with flashes warmth gentle humor. [SEP]',
#  'another how is losing. [SEP]',
#  '[CLS]uchi vividly captures, chafing against manic and. [SEP]',
#  "[CLS] it's an interesting effort, and barry's cold - act makes worthwhile. [SEP]",
#  '[CLS] an instance. [SEP]',
#  "[CLS] would n t exist without the precedent of, whose'goes to essence [SEP]",
#  'or is one greatest date. [SEP]',
#  '[CLS] what envens this, beyond beautifully detailed all, is a note of defiance. [SEP]',
#  '[CLS] stinks to, gloom. [SEP]',
#  ', moments of caused me to jump in my chair. [SEP]',
#  '[CLS] a boring where,. [SEP]',
#  'a and a cruel. [SEP]',
#  "[CLS] while, nolan's penetrating undercunt of and flair lends stimulating depth. [SEP]",
#  ', the sening and an extremely flat do little thisailing reputation. [SEP]',
#  ', bears out as your typical junk. [SEP]',
#  'settle into aninghed rhythm of artificial suspense. [SEP]',
#  'a disaster of a, [SEP]',
#  '[CLS] but delivers the same bad. [SEP]',
#  '[CLS] the needed more emphasis and the machine that wo. [SEP]',
#  '[CLS] a respectable venture its, lacking. [SEP]',
#  'a compelling, gut clutching piece of that carries you along a torrent of emotion as it [SEP]',
#  'overly long andful. [SEP]',
#  "[CLS] despite slick and's pacing, the final effect is like. [SEP]",
#  'and! [SEP]',
#  '[CLS] it feels more forced than',
#  '[CLS] it, it still cuts all the way down to broken. [SEP]',
#  'get, to more [SEP]',
#  "it's a solid about [SEP]",
#  "a but it's nowhere near as exciting as. [SEP]",
#  '[CLS] the filmmakers are playing. to that end, they mock, [SEP]',
#  'everybody loves and this one is told almost entirely [SEP]',
#  '[CLS], it otherwise drowns in a sea ofiche. [SEP]',
#  '[CLS] the itself is far from disappointing, offering an, and another rate performance. [SEP]',
#  '[CLS] caine makes us watch as his characterns the. [SEP]',
#  'wishtalk had this true. [SEP]',
#  's is not, but it is effective [SEP]',
#  'for its, loses fire midway, nearly. [SEP]',
#  'drawn in by the dark [SEP]',
#  'it just sits there like a [SEP]',
#  '[CLS] lacks the,, and perhaps of. [SEP]',
#  '[CLS] kicks an and then ends with a whimper. [SEP]',
#  '[CLS], but friday spreads them pretty thin. [SEP]',
#  "[CLS] ', we cut to new, also to [SEP]",
#  '[CLS] a chilling without [SEP]',
#  '[CLS] for a, there is precious little of [SEP]',
#  '[CLS] just want you enjoy without. [SEP]',
#  '[CLS],tic. [SEP]',
#  '[CLS]. a and ultimately empty. [SEP]',
#  '[CLS], but the guys still feels. [SEP]',
#  '[CLS] with little superb, this latest may put off and alike. [SEP]',
#  '[CLS] what happens? [SEP]',
#  '[CLS] as franco has all dean, but none of his [SEP]',
#  'as as, there is an accuracy, that keeps grounded in anble. [SEP]',
#  '[CLS] patchy combination of, and,. [SEP]',
#  'rome really wrong with ricture [SEP]',
#  '[CLS] it watch video, but that should n t stop french from. [SEP]',
#  '[CLS] an empty shell rather. [SEP]',
#  '[CLS], but it gets the job done. [SEP]',
#  '[CLS] the film does give a pretty good overall. [SEP]',
#  "[CLS] if'n t put you off, this will be an enjoyable choice for younger [SEP]",
#  '[CLS] comively watchable no matter. [SEP]',
#  ', the movie is rather choppy [SEP]',
#  '[CLS] plays out with a dogged and eventually winning squareness it. [SEP]',
#  "[CLS] even though,'s still entertaining. [SEP]",
#  '[CLS] the has the uncanny ability to. [SEP]',
#  'a moving uneven success.',
#  'oh that clever angle [SEP]',
#  '[CLS] two has appeal beyond. [SEP]',
#  'curiously suffers it does its - minute length. [SEP]',
#  'but a really strong second effort [SEP]',
#  'runs through remarkable short [SEP]',
#  '[CLS] expecting the entire exercise has no. [SEP]',
#  '[CLS] put, pantheon body work. [SEP]',
#  '[CLS]. enthusiastically invokes the, the and the sense that. [SEP]',
#  '10 which is worth seeing',
#  '[CLS] the lousy all but spits out. [SEP]',
#  'pressed more clingly sappy than evelyn this year. [SEP]',
#  '[CLS], the are quietly moving. [SEP]',
#  '[CLS] for a the does t, but introduces who. [SEP]',
#  'a. [SEP]',
#  "' quitting hits home with disorienting force [SEP]",
#  "[CLS] despite, rarely seems interested's as as. [SEP]",
#  '[CLS] it is parochial, accessible,, and smugly suggests [SEP]',
#  '- splitting exercise in. [SEP]',
#  'this is not a [SEP]',
#  '[CLS] that has usually been leavened by a charm that s conspicuously missing. [SEP]',
#  '[CLS] his screenplay needs some serious re - working to dilemma,. [SEP]',
#  "[CLS] ends up being mostly about, and joancky, times'[SEP]",
#  '[CLS] is just as ill - fitting as, and the would sink. [SEP]',
#  'a film that loses. [SEP]',
#  'has partly down. [SEP]',
#  '[CLS] underwater, below casts its and spits back, grzled and charred, somewhere. [SEP]',
#  'is painfully foolish in hold. [SEP]',
#  'as uninkingly pure is distinctrity and an event [SEP]',
#  '[CLS] great performances,ish cinematography and a help make a [SEP]',
#  "he's not [SEP]",
#  'aallyed and sloppy. [SEP]',
#  'a movie [SEP]',
#  'memorable that does its [SEP]',
#  "[CLS]'s witty, wiful,? [SEP]",
#  ", i'recommend dvd and just skipping to [SEP]",
#  '[CLS] is, but in hisal,c drains his movie of all individuality. [SEP]',
#  '##ves into the leaning on badly. [SEP]',
#  'done excellent work here. [SEP]',
#  'belbility was t the film s [SEP]',
#  '[CLS] despite, the weight of water is oppressively heavy. [SEP]',
#  'a movie that s about asaring and it depicts [SEP]',
#  "[CLS] hannibal yes it'like [SEP]",
#  'never [SEP]',
#  '[CLS] as chilling and fascinating as -. [SEP]',
#  ', and as the is basically just a [SEP]',
#  '[CLS] but something far more and hence more chilling effective. [SEP]',
#  'an ebullient tunisian about startling transformation. [SEP]',
#  'directing with a sure and measured hand, steers and offers instead an unching and objective. [SEP]',
#  'yet curiously andpy recycling which. [SEP]',
#  '[CLS] as, this homage fires on all plasma. [SEP]',
#  ', the film suffers from aistic and a, conclusion. [SEP]',
#  '[CLS] will and the should the converts too',
#  '[CLS], narc is strictly. [SEP]',
#  'an even endeavor than. [SEP]',
#  '[CLS] the modern remake is long on narrative and short on [SEP]',
#  's too committed [SEP]',
#  "one, it's not very good [SEP]",
#  "is itself intacto's luckiest stroke [SEP]",
#  'stress. [SEP]',
#  '[CLS] is never. [SEP]',
#  'a lot more dimensional and complex than its. [SEP]',
#  '[CLS] obviously, a lot wasted a on something very incial. [SEP]',
#  "[CLS] immensely and even though, you'll want things to. [SEP]",
#  'heart, but he needs to pull head his butt [SEP]',
#  'something. [SEP]',
#  '[CLS] lets the da in classic mode, and stumbles. [SEP]',
#  "anling aesthetic one that's baroque beauty [SEP]",
#  '[CLS] : the message is consistent with. [SEP]',
#  '[CLS] does point the. [SEP]',
#  "it's a of a that does [SEP]",
#  '[CLS] a creepy, intermittently powerful study about as. [SEP]',
#  '[CLS] s it just more same, done with noticeably less. [SEP]',
#  '[CLS] a compelling that [SEP]',
#  '[CLS] the lack, with the exception [SEP]',
#  '[CLS] served with [SEP]',
#  "[CLS] only pain you'll is your. [SEP]",
#  ', but the film sits with square conviction and touching good sense its [SEP]',
#  'an. [SEP]',
#  '[CLS] this is a monumental achievement in practically everyept filmmaking :',
#  'it s not bad [SEP]',
#  '[CLS] while not, this often very funny comedy goes a long way toward restoring. [SEP]',
#  '[CLS] is exceedingly pleasant, designed',
#  "but awe ; we're wrapped up in,,. [SEP]",
#  '[CLS] well jason and a can be off the of ideas for - - hey n t - [SEP]',
#  'the is enough, but s difficult shrug annoyance that chat fish [SEP]',
#  'a lot like it -, andless. [SEP]',
#  'the movie is agible of manipulation, an [SEP]',
#  '[CLS] whether statham move, but again, who says he has? [SEP]',
#  '[CLS] the film delivers what it promises : a look at sketch. [SEP]',
#  '[CLS] a fascinating examination. [SEP]',
#  '[CLS] rich in atmosphere, it manages to without dust. [SEP]',
#  '[CLS] is a lot like a well :, and but still quitesty and inviting all same. [SEP]',
#  "[CLS] the film's sometimes undermines the. [SEP]",
#  '[CLS] at no during did viewer that, though in, never lot. [SEP]',
#  'must indeed good to this laugh. [SEP]',
#  '[CLS] the help overcome the. [SEP]',
#  "[CLS] a rather brilliant little cult item : a ',. [SEP]",
#  'this slender feels especially thin stretched over. [SEP]',
#  'perhaps found s of kitsch hard going. [SEP]',
#  'an incredibly - joke targeted. [SEP]',
#  '[CLS] is, but as makes the right at every. [SEP]',
#  '[CLS] vera has created a provocative, absorbing drama that curse. [SEP]',
#  '[SEP]',
#  "[CLS] it's also uninspired, lacking real. [SEP]",
#  'is, he can not overcome the sense that pumpkin is a. [SEP]',
#  'a pain',
#  'a witty,. [SEP]']

# %% [markdown]
# ### Electra

# %%
sentence_word_token
# Out:
# ['[CLS] so genial isce, those that you throughout, dearly hoping. [SEP]',
#  '[CLS] does has some value - well like [SEP]',
#  '[CLS] our, but it grows monotonous after a, as do s. [SEP]',
#  '[CLS] one of but fails to to either in three of screen time.',
#  '[CLS] a medcre exercise,. [SEP]',
#  'that works',
#  '[CLS] excessive tires, the, has its handful ofeeming features. [SEP]',
#  '[CLS] pity is that responsible did t and retle it direct - video and send it its home. [SEP]',
#  '[CLS] halfway, having,tates into a gross - out with that are more. [SEP]',
#  '[CLS], but he feels like a. [SEP]',
#  "it's better than",
#  'is ok to a apparatus, and human [SEP]',
#  '[CLS] an untable look, prism. [SEP]',
#  '[CLS] hasolate, but a, manages to infuse with flashes warmth gentle humor. [SEP]',
#  'another how is losing. [SEP]',
#  '[CLS]uchi vividly captures, chafing against manic and. [SEP]',
#  "[CLS] it's an interesting effort, and barry's cold - act makes worthwhile. [SEP]",
#  '[CLS] an instance. [SEP]',
#  "[CLS] would n t exist without the precedent of, whose'goes to essence [SEP]",
#  'or is one greatest date. [SEP]',
#  '[CLS] what envens this, beyond beautifully detailed all, is a note of defiance. [SEP]',
#  '[CLS] stinks to, gloom. [SEP]',
#  ', moments of caused me to jump in my chair. [SEP]',
#  '[CLS] a boring where,. [SEP]',
#  'a and a cruel. [SEP]',
#  "[CLS] while, nolan's penetrating undercunt of and flair lends stimulating depth. [SEP]",
#  ', the sening and an extremely flat do little thisailing reputation. [SEP]',
#  ', bears out as your typical junk. [SEP]',
#  'settle into aninghed rhythm of artificial suspense. [SEP]',
#  'a disaster of a, [SEP]',
#  '[CLS] but delivers the same bad. [SEP]',
#  '[CLS] the needed more emphasis and the machine that wo. [SEP]',
#  '[CLS] a respectable venture its, lacking. [SEP]',
#  'a compelling, gut clutching piece of that carries you along a torrent of emotion as it [SEP]',
#  'overly long andful. [SEP]',
#  "[CLS] despite slick and's pacing, the final effect is like. [SEP]",
#  'and! [SEP]',
#  '[CLS] it feels more forced than',
#  '[CLS] it, it still cuts all the way down to broken. [SEP]',
#  'get, to more [SEP]',
#  "it's a solid about [SEP]",
#  "a but it's nowhere near as exciting as. [SEP]",
#  '[CLS] the filmmakers are playing. to that end, they mock, [SEP]',
#  'everybody loves and this one is told almost entirely [SEP]',
#  '[CLS], it otherwise drowns in a sea ofiche. [SEP]',
#  '[CLS] the itself is far from disappointing, offering an, and another rate performance. [SEP]',
#  '[CLS] caine makes us watch as his characterns the. [SEP]',
#  'wishtalk had this true. [SEP]',
#  's is not, but it is effective [SEP]',
#  'for its, loses fire midway, nearly. [SEP]',
#  'drawn in by the dark [SEP]',
#  'it just sits there like a [SEP]',
#  '[CLS] lacks the,, and perhaps of. [SEP]',
#  '[CLS] kicks an and then ends with a whimper. [SEP]',
#  '[CLS], but friday spreads them pretty thin. [SEP]',
#  "[CLS] ', we cut to new, also to [SEP]",
#  '[CLS] a chilling without [SEP]',
#  '[CLS] for a, there is precious little of [SEP]',
#  '[CLS] just want you enjoy without. [SEP]',
#  '[CLS],tic. [SEP]',
#  '[CLS]. a and ultimately empty. [SEP]',
#  '[CLS], but the guys still feels. [SEP]',
#  '[CLS] with little superb, this latest may put off and alike. [SEP]',
#  '[CLS] what happens? [SEP]',
#  '[CLS] as franco has all dean, but none of his [SEP]',
#  'as as, there is an accuracy, that keeps grounded in anble. [SEP]',
#  '[CLS] patchy combination of, and,. [SEP]',
#  'rome really wrong with ricture [SEP]',
#  '[CLS] it watch video, but that should n t stop french from. [SEP]',
#  '[CLS] an empty shell rather. [SEP]',
#  '[CLS], but it gets the job done. [SEP]',
#  '[CLS] the film does give a pretty good overall. [SEP]',
#  "[CLS] if'n t put you off, this will be an enjoyable choice for younger [SEP]",
#  '[CLS] comively watchable no matter. [SEP]',
#  ', the movie is rather choppy [SEP]',
#  '[CLS] plays out with a dogged and eventually winning squareness it. [SEP]',
#  "[CLS] even though,'s still entertaining. [SEP]",
#  '[CLS] the has the uncanny ability to. [SEP]',
#  'a moving uneven success.',
#  'oh that clever angle [SEP]',
#  '[CLS] two has appeal beyond. [SEP]',
#  'curiously suffers it does its - minute length. [SEP]',
#  'but a really strong second effort [SEP]',
#  'runs through remarkable short [SEP]',
#  '[CLS] expecting the entire exercise has no. [SEP]',
#  '[CLS] put, pantheon body work. [SEP]',
#  '[CLS]. enthusiastically invokes the, the and the sense that. [SEP]',
#  '10 which is worth seeing',
#  '[CLS] the lousy all but spits out. [SEP]',
#  'pressed more clingly sappy than evelyn this year. [SEP]',
#  '[CLS], the are quietly moving. [SEP]',
#  '[CLS] for a the does t, but introduces who. [SEP]',
#  'a. [SEP]',
#  "' quitting hits home with disorienting force [SEP]",
#  "[CLS] despite, rarely seems interested's as as. [SEP]",
#  '[CLS] it is parochial, accessible,, and smugly suggests [SEP]',
#  '- splitting exercise in. [SEP]',
#  'this is not a [SEP]',
#  '[CLS] that has usually been leavened by a charm that s conspicuously missing. [SEP]',
#  '[CLS] his screenplay needs some serious re - working to dilemma,. [SEP]',
#  "[CLS] ends up being mostly about, and joancky, times'[SEP]",
#  '[CLS] is just as ill - fitting as, and the would sink. [SEP]',
#  'a film that loses. [SEP]',
#  'has partly down. [SEP]',
#  '[CLS] underwater, below casts its and spits back, grzled and charred, somewhere. [SEP]',
#  'is painfully foolish in hold. [SEP]',
#  'as uninkingly pure is distinctrity and an event [SEP]',
#  '[CLS] great performances,ish cinematography and a help make a [SEP]',
#  "he's not [SEP]",
#  'aallyed and sloppy. [SEP]',
#  'a movie [SEP]',
#  'memorable that does its [SEP]',
#  "[CLS]'s witty, wiful,? [SEP]",
#  ", i'recommend dvd and just skipping to [SEP]",
#  '[CLS] is, but in hisal,c drains his movie of all individuality. [SEP]',
#  '##ves into the leaning on badly. [SEP]',
#  'done excellent work here. [SEP]',
#  'belbility was t the film s [SEP]',
#  '[CLS] despite, the weight of water is oppressively heavy. [SEP]',
#  'a movie that s about asaring and it depicts [SEP]',
#  "[CLS] hannibal yes it'like [SEP]",
#  'never [SEP]',
#  '[CLS] as chilling and fascinating as -. [SEP]',
#  ', and as the is basically just a [SEP]',
#  '[CLS] but something far more and hence more chilling effective. [SEP]',
#  'an ebullient tunisian about startling transformation. [SEP]',
#  'directing with a sure and measured hand, steers and offers instead an unching and objective. [SEP]',
#  'yet curiously andpy recycling which. [SEP]',
#  '[CLS] as, this homage fires on all plasma. [SEP]',
#  ', the film suffers from aistic and a, conclusion. [SEP]',
#  '[CLS] will and the should the converts too',
#  '[CLS], narc is strictly. [SEP]',
#  'an even endeavor than. [SEP]',
#  '[CLS] the modern remake is long on narrative and short on [SEP]',
#  's too committed [SEP]',
#  "one, it's not very good [SEP]",
#  "is itself intacto's luckiest stroke [SEP]",
#  'stress. [SEP]',
#  '[CLS] is never. [SEP]',
#  'a lot more dimensional and complex than its. [SEP]',
#  '[CLS] obviously, a lot wasted a on something very incial. [SEP]',
#  "[CLS] immensely and even though, you'll want things to. [SEP]",
#  'heart, but he needs to pull head his butt [SEP]',
#  'something. [SEP]',
#  '[CLS] lets the da in classic mode, and stumbles. [SEP]',
#  "anling aesthetic one that's baroque beauty [SEP]",
#  '[CLS] : the message is consistent with. [SEP]',
#  '[CLS] does point the. [SEP]',
#  "it's a of a that does [SEP]",
#  '[CLS] a creepy, intermittently powerful study about as. [SEP]',
#  '[CLS] s it just more same, done with noticeably less. [SEP]',
#  '[CLS] a compelling that [SEP]',
#  '[CLS] the lack, with the exception [SEP]',
#  '[CLS] served with [SEP]',
#  "[CLS] only pain you'll is your. [SEP]",
#  ', but the film sits with square conviction and touching good sense its [SEP]',
#  'an. [SEP]',
#  '[CLS] this is a monumental achievement in practically everyept filmmaking :',
#  'it s not bad [SEP]',
#  '[CLS] while not, this often very funny comedy goes a long way toward restoring. [SEP]',
#  '[CLS] is exceedingly pleasant, designed',
#  "but awe ; we're wrapped up in,,. [SEP]",
#  '[CLS] well jason and a can be off the of ideas for - - hey n t - [SEP]',
#  'the is enough, but s difficult shrug annoyance that chat fish [SEP]',
#  'a lot like it -, andless. [SEP]',
#  'the movie is agible of manipulation, an [SEP]',
#  '[CLS] whether statham move, but again, who says he has? [SEP]',
#  '[CLS] the film delivers what it promises : a look at sketch. [SEP]',
#  '[CLS] a fascinating examination. [SEP]',
#  '[CLS] rich in atmosphere, it manages to without dust. [SEP]',
#  '[CLS] is a lot like a well :, and but still quitesty and inviting all same. [SEP]',
#  "[CLS] the film's sometimes undermines the. [SEP]",
#  '[CLS] at no during did viewer that, though in, never lot. [SEP]',
#  'must indeed good to this laugh. [SEP]',
#  '[CLS] the help overcome the. [SEP]',
#  "[CLS] a rather brilliant little cult item : a ',. [SEP]",
#  'this slender feels especially thin stretched over. [SEP]',
#  'perhaps found s of kitsch hard going. [SEP]',
#  'an incredibly - joke targeted. [SEP]',
#  '[CLS] is, but as makes the right at every. [SEP]',
#  '[CLS] vera has created a provocative, absorbing drama that curse. [SEP]',
#  '[SEP]',
#  "[CLS] it's also uninspired, lacking real. [SEP]",
#  'is, he can not overcome the sense that pumpkin is a. [SEP]',
#  'a pain',
#  'a witty,. [SEP]']

# %% [markdown]
# ### bilstm

# %%
sentence_word_token
# Out:
# ['[CLS] so genial is those of the one rare [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie does has some entertainment - how value much depends on [PAD] [PAD]',
#  "[CLS] there'[PAD] [PAD] s lots of and a [PAD] [SEP] to a bid",
#  '[CLS] one of those to be decadess intimate strive and do to fails justice',
#  '[CLS] a mediocre exercise [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] that works. [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] though excessively tiresomely pre, verbalten [PAD] [PAD] may [PAD]',
#  '[CLS] the great pity is that [PAD] [PAD] [PAD] [PAD] those [SEP] [PAD] the responsible',
#  '[CLS] halfway through, however, sucked having dry the undead scary [PAD] [PAD].',
#  "[CLS] nohe has made a decent ` intro'[PAD] [PAD] documentary [PAD] [PAD]",
#  "[CLS] it's better than the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] phantom",
#  '[CLS] it is ok for be something to a of movie [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an unforgettable look at through called tradition omnibus that of prism',
#  '[CLS] skins has a des eyre, but by aolate raised, air american',
#  '[CLS]... another example of how sand [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] hashiguchi mani s vividc'way mix thely chafin",
#  "[CLS] it's interesting an l - -rb effort for particularly j and",
#  '[CLS] an instance of an old dog [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] american musical comedy as we know it'would n t exist jolly theater",
#  '[CLS] gay or straight, kissing jessica stein is one of [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] what entuteli as direction of the cardven performances detailed beyondoso',
#  '[CLS] stinks from start to of, finish sack like gloom [PAD] [PAD] [PAD]',
#  '[CLS] despite the holes in the story and the somewhat [PAD] [PAD] of [PAD] [PAD]',
#  '[CLS] a boringquerade mas ball where normally [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a hypnotic cyber and hymn a cruel [PAD] [PAD] [PAD] story [SEP] [PAD] [PAD]',
#  '[CLS] while ins [PAD] [PAD] [SEP]om [PAD] under penetratingcuniarre is [PAD]',
#  '[CLS] though there are entertaining [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] and',
#  '[CLS] once the downward spiral [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the skirmishes for power amongd wage victims and [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a disaster of a drama [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] formula 51 promises a new kind of high [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the filmmakers needed more emphasis on the storytelling and the audience lesslamorous',
#  '[CLS] a respectable venture on its own a more mainstream to audience. terms [SEP]',
#  '[CLS] a in along compelling you a carries, [PAD] [PAD] [PAD] [PAD] that [PAD]',
#  '[CLS] overly long and worshipful bio - doc [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] despite slick tick - production s to values'and [PAD] [PAD]ck [PAD]",
#  '[CLS] and educational! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] although disney follows its standard [PAD] [PAD] [PAD] [PAD] [PAD] formula [PAD] [PAD] [PAD]',
#  '[CLS] though it flirts knowos with it bathos and path [PAD] [PAD]',
#  '[CLS] you get the idea, though, that kapur intended the [PAD] [PAD]',
#  "[CLS] it's a about people movie solid whose [PAD] lives [PAD] [PAD] [PAD]",
#  '[CLS] a reworking of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[SEP] understand to [CLS] figure they kind care the ones the that, the to',
#  '[CLS] everybody loves a david and go one this and islia, storyth',
#  '[CLS] gets the look and the period trappings [PAD] [PAD] [PAD] [PAD] [PAD] right',
#  '[CLS] the movie itself is an far offering original from [PAD] [PAD] so crucial [PAD]',
#  '[CLS] caine makes watch us as his character awakens to [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] i wish wind faith more [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] in [PAD] [PAD]',
#  "[CLS] s1m0ne's satire is not subtle, but [PAD]",
#  '[CLS] for all dragon its, loses touches brilliant its [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] we're drawn in by the [PAD] [PAD] [PAD] dark [PAD] [PAD] [PAD]",
#  '[CLS] still, it just sits there like a side dish no one. [PAD]',
#  '[CLS] russell lacks theache visual pan, the comic touch, [PAD] [PAD] [PAD]',
#  '[CLS] kicks off ends then and withings [PAD] withder [PAD] meanless plot',
#  '[CLS] ice cube is n of out ripe but thin pretty them spreads next after',
#  "[CLS] whenever you think you'[PAD] [PAD] to [PAD] [PAD] appears to [PAD] [PAD]",
#  '[CLS] a chilling movie without oppressive [PAD] gore [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] for a movie about the power there, and passion [PAD] of [PAD] [PAD]',
#  '[CLS] mr. spielberg and feeling con his withoutned yourselves company. [PAD] just',
#  '[CLS] overwrought, mel [PAD] [PAD] [PAD] [PAD]od [PAD] [PAD] [PAD]',
#  '[CLS]... a pretentious and empty examination ultimately of a [PAD]',
#  "[CLS] no one can doubt the filmmakers'motives, but [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] very with little to add beyond the already dark visions relayed may.',
#  '[CLS] what happens when something goes bump [PAD] [PAD] [PAD] [PAD] [PAD] and in night',
#  '[PAD] [SEP] the rr - franco -rb l -, role title inr',
#  '[CLS] as broad and cartoon of as accuracy anish screenplay the is is there',
#  '[CLS] patchy combination of soap - low opera tech, magic realism [PAD] [PAD]',
#  "[CLS] romething's really wrong [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] it might be to `'easier watch on home video, at but",
#  '[CLS] an empty shell of an epic rather than [PAD] [PAD] the [PAD] [PAD] [PAD]',
#  '[CLS] may be more genial than [PAD] ing [PAD]eni [PAD] [PAD]ous [PAD]',
#  '[CLS] the film does give of the picture situation overall [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] if a number like big musical ` praise the lord [PAD], [PAD] [PAD]',
#  '[CLS] compulsively watchable, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] surprisingly, considering that baird is a [PAD] [PAD] [PAD] [PAD] [PAD] former [PAD]',
#  '[CLS] plays out with of darling many a the it make a dogg anded',
#  "[CLS] even though the film does its to entertaining still s'it, marks",
#  '[CLS] the film has the uncanny ability to right [PAD] [PAD] itself [PAD] [PAD] [PAD]',
#  '[CLS] a moving, if uneven, [PAD] [PAD] [PAD] [PAD] [SEP] [PAD] [PAD] [PAD]',
#  '[CLS] oh, look at that clever angle! [PAD] [SEP] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] two weeks notice has appeal beyond being a sandra bullock [PAD] vehicle [PAD] [PAD]',
#  '[CLS] curiously, super troopers suffers because it does n to length minute - 103',
#  '[CLS] not as good as the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] rubbo runs through amount a remarkable of material [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the one not - so - small [SEP]. [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] put it somewhere between west heaven of sling, of blade and south [PAD]',
#  '[CLS]... enthusiastically invokes brass the soul percussion rhythm and,',
#  '[CLS] after the first 10 minutes [PAD] [PAD] [PAD] [PAD] [PAD] [PAD], which [PAD]',
#  '[CLS] the lousy john q [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS]'i d [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] despite the film'[PAD] [PAD] s [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] for a movie audience, the hours does'n t neat way,",
#  '[CLS] a riveting [PAD] [PAD] [PAD] documentary [PAD] [PAD] [PAD] [PAD] [SEP] [PAD]',
#  "[CLS] if you'of cinema re as notion not totally weird community the -",
#  '[CLS] despite engaging off rarely guys seems interestedbeataround kicking around in touches knock',
#  '[CLS] it is parochial accessible to, a chosen, few standoffish everyone',
#  '[CLS] ear - splitting exercise in formula crash - and [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is not a jackie chan movie [PAD] [PAD] [PAD]. [PAD] [PAD] [PAD]',
#  '[CLS] that frenetic lrb - spectacle - - by rr show a',
#  "[CLS] - his lrb - nelson's - -b rr screenplay needs",
#  "[SEP] sat no joan [CLS] matter a di and he ends'demonstrates times s",
#  "[CLS] cost asner shady fittingfuncac 'tory per -'[PAD]",
#  '[CLS] a film that loses sight of its [PAD] [PAD] own [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] ` opening up'the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] as underwater ghost casts below stories its go, into out the sp net',
#  "[CLS] seagal is painfully foolish in left trying of s to hold onto '",
#  '[CLS] a is big hours - budget \\ a / all - as the star',
#  '[CLS] great performances, stylish 1 cinematography. a and no [PAD] feel',
#  "[CLS] he's not good [PAD] [PAD] [PAD] with [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a characteristically engorged and sloppy [PAD] [PAD] coming [PAD] [PAD] [PAD]',
#  '[CLS] a modestly [PAD] [PAD] [PAD] surprising [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an unsettling, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] tsai ming - liang, witty wi'sstful film,",
#  "[CLS] but even then, i'd [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] the movie [PAD] [SEP] [PAD] is ze hisal. [PAD] inity loaded',
#  '[CLS] devolves into the derivative, on leaning badly [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] consummate actor [PAD] [PAD] [PAD] barry [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] believability was one t [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] despite an impressive roster of stars and direction from kathryn big of [PAD] [PAD]',
#  "[CLS] a movie that's overbe as aboutaring and top over -",
#  '[CLS] as hannibal would say dinner for friend old [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] never once predictable. [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] as chilling and fascinating as philippe mora's modern hitler [PAD] [PAD] [PAD]",
#  '[CLS] we never feel these characters anything for, and film as the is a',
#  '[CLS] not a far more something sc styl buthlishocky [PAD]',
#  '[CLS] an ebullie of startling transformation the widow bound a who about -',
#  '[CLS] directing with a andchingin [PAD] [PAD] objective [PAD] look at sure [PAD]',
#  '[CLS] earnest yetpy chop curiously recycling [PAD] [PAD] and [PAD] [PAD] in [PAD] [PAD]',
#  '[CLS] as action - adventure, this space - based to robert [PAD] [PAD] homage',
#  '[CLS] pc stability notwithstanding, the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] wilco fans will have a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] despite the pyrotechnic [PAD]s [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] an even more predictable, cl [PAD] [PAD] [PAD] [PAD] [PAD]iche [PAD] [PAD]',
#  "[CLS] the modern remakemas of du's story is long on narrative [PAD]",
#  "[CLS] no, even that'[PAD]. [PAD] [PAD] s [PAD] [PAD] [PAD] committed",
#  "[CLS] although i didn't hate this one, [PAD] either [PAD] it",
#  '[CLS] the casting ofdo sy vonw.. [PAD] [PAD]. [PAD] luck',
#  "[CLS] stress ` dumb.'[SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] first - timer john mckay is never [PAD] [PAD] able [PAD] to [PAD] pull',
#  '[CLS] a lot more dimensional and complex than its sunny [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] obviously, a people lot of a wasted [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] garcia bernal are and anconan [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] adam sandler'may s heart be in to pull [PAD] [PAD] [PAD]",
#  '[CLS] something for everyone. [PAD] [PAD] [PAD] [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] louiso [PAD] [PAD] lets [PAD] classic di over the movie in [PAD] a',
#  "[CLS] an enth 'ral s that one steep, experienceling aesthetic [PAD]",
#  '[CLS] one thing you have to the of message : the give them movie for',
#  '[CLS] does point the way for adventurous [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] indian [PAD]',
#  "[CLS] it's a frankenstein - monster of a to be film [PAD] wants",
#  '[CLS] a a creepy of self study as, about powerful un - [PAD] [PAD]',
#  "[CLS] there'new of s not inspiration spark a [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a compelling motion picture that illustrates [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the characterizations and dialogue [PAD] [PAD] [PAD] [SEP] [PAD] lack. [PAD] [PAD]',
#  '[CLS] classic cinema served up with heart and [PAD] [PAD] [PAD] [PAD] [PAD] humor [PAD]',
#  "[CLS] the only pain ll'you feel as the [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] expect no major discoveries, nor any sits film the st but square with',
#  '[CLS] an exit sign, that [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is a monumental achievement handed -, in heavy visually ofless,',
#  "[CLS] even at its worst, half it not - s bad '. [SEP]",
#  '[CLS] while [PAD] not [SEP] [PAD] for. toward restoring way every video funny -',
#  '[CLS] everything in maid in manhattan [PAD] [PAD] [PAD], [PAD] designed [PAD] [PAD] [PAD]',
#  '[CLS] there are flaws also, of but stretches impact and of moments [PAD] [PAD]',
#  '[SEP] [CLS] well -, station space in5 245 the year messenger listrb',
#  '[CLS] the main story... [PAD] [PAD] [PAD] [PAD] is [PAD] [PAD] of',
#  '[CLS] a lot like the imaginary sport it projects [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie is a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it remains to be seen stat whetherham can move beyond the crime [PAD]',
#  '[CLS] the film a : look delivers promises what at [PAD] it [PAD] [SEP] [PAD]',
#  '[CLS] a fascinating by made a discovery examination [PAD] [PAD]ous - [PAD] [PAD] [PAD]',
#  '[CLS] rich in atmosphere of the post - [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] clint [PAD] [SEP] eastwood bo and a well [PAD]astul like '.",
#  "[CLS] the film the possibility tos'for be [PAD] [PAD] desire the [PAD]",
#  '[CLS] [PAD] [SEP] at no of themes loyalty. point its, to meant though',
#  '[CLS] the actors must indeed be to rec goodite [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the quirky and recessive charms of donovan co martin and stars -',
#  '[CLS] a rather : brilliant little item a cult entertainment past ofiche s,',
#  '[CLS] this slender plot feels especially thin stretched over [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] perhaps even the sl writerc found - command [PAD] [PAD] high [PAD] [PAD]',
#  '[CLS] an incredibly narrow in - joke an of targeted segment to tiniest already',
#  '[CLS] this is of the subject kind matter that a could by filmmaker lesser fumbled',
#  '[CLS] vera has created a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a truly wonderful tale [PAD] [PAD] [PAD] [PAD] [PAD] combined [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] while the the lacking real film, talent is spired competent'also",
#  '[CLS] though harris is affecting at sense that times the pumpkin overcome, [PAD] [PAD]',
#  '[CLS] a big fat pain [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a witty, low [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] - [PAD]']

# %% [markdown]
# ## Option 2
# ### bert

# %%
sentence_word_token
# Out:
# ['[CLS] later, t.. [SEP]',
#  '[CLS],. t. up after. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] for, and on down, blood work. [SEP]',
#  "[CLS] is'live. [SEP]",
#  "[CLS] to -, the end, don't. [SEP]",
#  '[CLS] `b,cles. [SEP]',
#  "[CLS] isn't can see. [SEP]",
#  "[CLS] if des up,'s good. [SEP]",
#  '[CLS] even, most hero by. [SEP]',
#  '[CLS] no bigop, see, make for. [SEP]',
#  '[CLS] caconis is perhaps effective in. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] what how i, is's toing. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] byler too toph into. [SEP]',
#  '[CLS] given the fact it,. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] has the together. [SEP]',
#  "[CLS] the don't. [SEP]",
#  '[CLS] be and who else moral [SEP]',
#  '[CLS] is reding. [SEP]',
#  '[CLS]... oncefolds. [SEP]',
#  '[CLS] cut through find of out in it. [SEP]',
#  '[CLS]... [SEP]',
#  "[CLS] but,'s. [SEP]",
#  "[CLS]..., doesn't. [SEP]",
#  '[CLS] the a is distinguishing in. [SEP]',
#  "[CLS] out.., a of's. [SEP]",
#  "[CLS] while serving sara does in,'s to match. [SEP]",
#  "[CLS]'sing that,'s also, to,. [SEP]",
#  "[CLS]gling of, ` '. [SEP]",
#  '[CLS] its. [SEP]',
#  "[CLS] fact't'movie [SEP]",
#  '[CLS] an with. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] tradesulsion for. [SEP]',
#  '[CLS] a about. [SEP]',
#  '[CLS]ving of. [SEP]',
#  '.',
#  '[CLS] monteistolyitsfolds. [SEP]',
#  '[CLS].. [SEP]',
#  "[CLS]nt in '. [SEP]",
#  "[CLS] and \\ / or,'s. [SEP]"]

# %% [markdown]
# ### Electra

# %%
sentence_word_token
# Out:
# ['[CLS] later, t.. [SEP]',
#  '[CLS],. t. up after. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] for, and on down, blood work. [SEP]',
#  "[CLS] is'live. [SEP]",
#  "[CLS] to -, the end, don't. [SEP]",
#  '[CLS] `b,cles. [SEP]',
#  "[CLS] isn't can see. [SEP]",
#  "[CLS] if des up,'s good. [SEP]",
#  '[CLS] even, most hero by. [SEP]',
#  '[CLS] no bigop, see, make for. [SEP]',
#  '[CLS] caconis is perhaps effective in. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] what how i, is's toing. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] byler too toph into. [SEP]',
#  '[CLS] given the fact it,. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] has the together. [SEP]',
#  "[CLS] the don't. [SEP]",
#  '[CLS] be and who else moral [SEP]',
#  '[CLS] is reding. [SEP]',
#  '[CLS]... oncefolds. [SEP]',
#  '[CLS] cut through find of out in it. [SEP]',
#  '[CLS]... [SEP]',
#  "[CLS] but,'s. [SEP]",
#  "[CLS]..., doesn't. [SEP]",
#  '[CLS] the a is distinguishing in. [SEP]',
#  "[CLS] out.., a of's. [SEP]",
#  "[CLS] while serving sara does in,'s to match. [SEP]",
#  "[CLS]'sing that,'s also, to,. [SEP]",
#  "[CLS]gling of, ` '. [SEP]",
#  '[CLS] its. [SEP]',
#  "[CLS] fact't'movie [SEP]",
#  '[CLS] an with. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] tradesulsion for. [SEP]',
#  '[CLS] a about. [SEP]',
#  '[CLS]ving of. [SEP]',
#  '.',
#  '[CLS] monteistolyitsfolds. [SEP]',
#  '[CLS].. [SEP]',
#  "[CLS]nt in '. [SEP]",
#  "[CLS] and \\ / or,'s. [SEP]"]

# %% [markdown]
# ### bilstm

# %%
sentence_word_token
# Out:
# ['[CLS] twenty years is. t still later. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] more intimate than spectacular factors by wow less than carried is [PAD]. t',
#  '[CLS] a winning and wildly [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] for all its plot twists, and of them some blood verge, on',
#  "[CLS] this is not one of the movies d [PAD] you want '. [PAD]",
#  '[CLS] there are to things like about murder by numbers - - but, in',
#  '[CLS] ` men in black [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie is nio. wave next the oning crestcre can',
#  '[CLS] if de of those oneuce movies wilds had a notch, that',
#  '[CLS] even in the the summer most,time restless young audience [PAD] [PAD] [PAD]',
#  '[CLS] no who bigop nothing, new to see, zero thrill toos',
#  '[CLS] cacoyannis is perhaps - dust cake of tood [PAD] [PAD]',
#  '[CLS] about schmidt belongs to nicholson [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]. [PAD] [PAD]',
#  '[CLS] what makes how i father to killed compelling willingness my, wander performances besides',
#  '[CLS] poetry in motion captured [PAD] [PAD] [PAD] on [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] byler is mor toophvy av sa this into [PAD] [PAD]',
#  '[CLS] given the fact that virtually no one for is to the bound it,',
#  '[CLS] this thing is virtually unwatch [PAD]able. [PAD] [PAD] [SEP] [PAD] [PAD]',
#  '[CLS] has the disjo [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the obligatory break - ups and hook - ups have characters the on impact',
#  '[SEP] moral and [CLS] of it the cultural mayt i weekend of know and',
#  '[CLS] there is nothing redeeming about this movie [PAD]. [PAD] [PAD] [SEP]',
#  '[CLS]... once the true impact of of is power this movie the',
#  '[CLS] cut through the layers of soap - of and emotion portrayal opera find [PAD]',
#  '[CLS]... a good film that must have department [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] but, like silence, it skin movie [PAD] [PAD]. your [PAD] [SEP]',
#  '[CLS]... while each moment of this anywhere go broken study character.',
#  '[CLS] the only thing film from that wallace randall any distinguishes a other is the',
#  '[CLS] it all plays like.. a. out comedy hughes high, of',
#  '[CLS] while serving [PAD] sara [SEP] [PAD] does of cr leveludi. [PAD] have',
#  "[CLS] there'sing no doubt that this is a and personal highly ambitious",
#  "[CLS] an eye - boggling blend of is psychedelic'and effects devices backgrounds",
#  '[CLS] its engaging simplicity is driven by [PAD] [PAD] appealing [PAD] [PAD] [PAD] leads [PAD]',
#  "[CLS] despite the fact that this film wasn't as to be bad",
#  '[CLS] an artsploitation movie with [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a non - mystery [PAD] [PAD] [PAD] [PAD] mystery [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] trades run - of - the - mill revulsion for [PAD] [PAD] [PAD]',
#  '[CLS] a deeply felt in newcomers a about and story detailed [PAD] [PAD] [PAD] vivid',
#  '[CLS] a fascinating, unner del [PAD] [PAD] [PAD] [PAD]usions [PAD] [PAD] the',
#  '[CLS] i survived. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] monte cristo needlessits om smart chase and wrought - storyly',
#  '[CLS]... wise and elegiac... [SEP] [PAD] [PAD]',
#  '[CLS] strident and inelegant in its ` [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] if you like quirky, odd the ironic, here or [PAD] [PAD]']

# %%
df[df['Category']==0]
# Out:
#        Id  Category                                           Sentence  \
# 4    9390         0  This is not one of the movies you 'd want to w...
# 10    258         0  No big whoop , nothing new to see , zero thril...
# 16    195         0  Given the fact that virtually no one is bound ...
# 17    194         0              This thing is virtually unwatchable .
# 18   2447         0  Has the disjointed feel of a bunch of strung-t...
# 21   6468         0      There is nothing redeeming about this movie .
# 27   6954         0  The only thing that distinguishes a Randall Wa...
# 33   4502         0  Despite the fact that this film was n't as bad...
# 34  11092         0  An artsploitation movie with too much exploita...
#
#     b_pred  e_pred  l_pred
# 4        1       1       0
# 10       1       1       0
# 16       1       1       0
# 17       1       1       0
# 18       1       1       0
# 21       1       1       0
# 27       1       1       0
# 33       1       1       0
# 34       1       1       0

# %% [markdown]
# ## Option 3
# ### bert

# %%
sentence_word_token
# Out:
# ['[CLS]rous but carl adds enough and to make entertaining [SEP]',
#  ', manages depressing as the phones in his. [SEP]',
#  'the strength film lies in its two central performances sven and. [SEP]',
#  'asty. [SEP]',
#  '[CLS] angel presents partly, and infuses the film with thesibility [SEP]',
#  'a terrific whatever. [SEP]',
#  'too sap. [SEP]',
#  '[CLS] while been, he has least one more : his own. [SEP]',
#  "[CLS] despite, that deserves a huge amount the credit for the film's thoroughly winning tone. [SEP]",
#  '[CLS] but sets itself apart by forming a that circle on a positive - [SEP]',
#  '[CLS] one best looking and animated. [SEP]',
#  'a assured and work of spare and [SEP]',
#  '[CLS] will the funny, even touching story. [SEP]',
#  '[CLS] the is like redone by someone ignored favor of old paperbacks. [SEP]',
#  'has been written so well that evendam [SEP]',
#  '##ous. [SEP]',
#  's not [SEP]',
#  '[CLS] it does, and uses as a. [SEP]',
#  '[CLS] s as,, so he just slopped ` together here. [SEP]',
#  '[CLS] royals have nothing these guys scandals [SEP]',
#  ', but they bugged me. [SEP]',
#  'but. [SEP]',
#  "[CLS] this does't interest beyond the first hour. [SEP]",
#  'can be as tiresome as 9 seconds, are included [SEP]',
#  '[CLS] it plods along methodically, somehow under its. [SEP]',
#  '[CLS] has dubious distinction of being a. [SEP]',
#  'drowned by all too. [SEP]',
#  '[CLS] the movie generates with a [SEP]',
#  "[CLS] somewhat less is a good one, and you'got to hand it for [SEP]",
#  'a that is warm,. [SEP]',
#  '[CLS] the leaping shaped by peter sl and, shows all condensed few striking. [SEP]',
#  'i this movie, and behind at station looking a to. [SEP]',
#  '[CLS] is a heavyweight that a and it lets the do punching [SEP]',
#  'grows you [SEP]',
#  '[CLS] he allows his. [SEP]',
#  '[CLS] a that sweetly but also seriously. [SEP]',
#  '[CLS] manages to please its without. [SEP]',
#  "[CLS] schneider, then you'll enjoy. [SEP]",
#  'a directorial by bernard,. [SEP]',
#  'a lot smarter than bond [SEP]',
#  'problem : not [SEP]',
#  '[CLS] it bad it eventually works its way up to merely bad rather than awful. [SEP]',
#  '[CLS] a decent enough that stands a good franklin. [SEP]',
#  '[CLS] with its andless, evokes the bottom tier of. [SEP]',
#  '[CLS] an unuttered resnt gem thats without [SEP]',
#  'an intelligent of a quality [SEP]',
#  "[CLS]'becomes more and more frustrating as the film goes on [SEP]",
#  '[CLS] entirely appropriately, the tales and concludes crisp clarity. [SEP]',
#  '[CLS] a whole lot and funny in middle, though. [SEP]',
#  'problem with is herself [SEP]',
#  'that this is a serious work by an important director who has something new about,. [SEP]',
#  'are simply too bland to [SEP]',
#  '[CLS] this picture is mostly a lump ofkled with a few - [SEP]',
#  ', but it never lacks in. [SEP]',
#  'an earnest, roughshod document, it serves workable and would make a terrific. [SEP]',
#  'a really long slow and dreary to do out tuck. [SEP]',
#  '[CLS] benefits from but also reminds us of. [SEP]',
#  '[CLS] neither, showtime is nevertheless efficiently amusing for a good while. [SEP]',
#  'is essentially empty [SEP]',
#  'the are the highest and the attractive without [SEP]',
#  'a. [SEP]',
#  'the has redncies, and, are sometimes inpressive. [SEP]',
#  '[CLS] is one of those crazy, mixed -. [SEP]',
#  '[CLS] the team continues, only now it s begun to split up that it. [SEP]',
#  "' why halftime is only fifteen [SEP]",
#  "[CLS]'s humorously tendious intervention. [SEP]",
#  "it's the perfect star for grant, allowing him to finally move. [SEP]",
#  'a exceptionally. [SEP]',
#  'ably old school [SEP]',
#  '[CLS] the film works - mostly due to its superior cast of',
#  '[CLS] i have a confession : i did n t particularly like e.. [SEP]',
#  'asy a twist [SEP]',
#  'several strong performances',
#  '[CLS],.',
#  'is year best. [SEP]',
#  'dana - and amir area headed east, far in retell',
#  'crud s presence is the one thing that holds interest in midst a mu [SEP]',
#  's film iseptively simple, satisfying [SEP]',
#  '. [SEP]',
#  'and is [SEP]',
#  '[CLS] however pleasant enough and its are certainly welcome. [SEP]',
#  '[CLS] a story that works even without,! [SEP]',
#  'too bland and to. [SEP]',
#  'far, and the are complex, laden plenty and tinged with. [SEP]',
#  '[CLS] overrdened with and [SEP]',
#  'what most memorable about is that s shot, whose tiny enables to both with considerable apb [SEP]',
#  'at three hours and with very little there is plenty of and a shorter cut surely would have resulted, [SEP]',
#  '[CLS] has an that, but its t and original. [SEP]',
#  '[CLS] a shimmeringly lovely portrait, shot inful,. [SEP]',
#  'that unfortunately, is a too love. [SEP]',
#  '[CLS] the try to balance, with are sometimes and quite often and in unexpected touching. [SEP]',
#  '[CLS] the script covers in a bland, surfacey way that does t [SEP]',
#  'honest and told, makes its [SEP]',
#  "[CLS]'s is better than - it is more. [SEP]",
#  "[CLS] does n t mean it's good enough for our girls. [SEP]",
#  'reno can most s success. [SEP]',
#  '[CLS] so purely enjoyable that it s a fairly remake. [SEP]',
#  '[CLS] gets its, but it also taps into the. [SEP]',
#  'please.',
#  "[CLS] it's a sharp movie",
#  "[CLS] well it you ', but it's definitely worth look [SEP]",
#  'anbly and. [SEP]',
#  'a terrific b the best. [SEP]',
#  '[CLS] a sweet, tender sermon about,. [SEP]',
#  "[CLS] barney do t by of can this three - endurance test built around an'of. [SEP]",
#  'did move armenia? [SEP]',
#  '[CLS] there is something that is so meditative and lyrical about s charming and little manages [SEP]',
#  'delivers a perfect performance that captures [SEP]',
#  '[CLS], proved too difficult a text to, despite the. [SEP]',
#  'a zippy 96 minutes of medcre,,ing, and. [SEP]',
#  'growing old [SEP]',
#  '[CLS] check your brain and your because you do n going on. [SEP]',
#  "', what's next. ghostp? [SEP]",
#  '[CLS] like, the film is also imbued with strong that are and without [SEP]',
#  '[CLS] - grant - goes beyond his and captures the soul gradually. [SEP]',
#  '[CLS] this is a movie so insecure about that its to. [SEP]',
#  "is a dud a comedy that's and. [SEP]",
#  '[CLS], but few will find the improved. [SEP]',
#  '[CLS] seems altogether too slight. [SEP]',
#  '[CLS], and in their cheap way they succeed. [SEP]',
#  'falls flat as. [SEP]',
#  '[CLS] is a smart, drama that dares to. [SEP]',
#  '[CLS] this that not, but nevertheless compelling. [SEP]',
#  '[CLS] surreal, and. [SEP]',
#  'but not without [SEP]',
#  '[CLS] the direction is pleasinglytic in this properly. [SEP]',
#  'of two who everything, and are defeated by a screenplay that forces bizarre implaus behavior. [SEP]',
#  'a. [SEP]',
#  'all deliver remarkable performances [SEP]',
#  'the film presents visceral and dangerously honest [SEP]',
#  '[CLS] nic merges his with his, insuating example,, [SEP]',
#  '[CLS]. there is enough originality in to distance it from. [SEP]',
#  '[CLS] it not, but there are enough high points to keep from. [SEP]',
#  '[CLS] like and. [SEP]',
#  'gets bogged down over minutes [SEP]',
#  '[CLS] familiar and predictable, and 4 \\s of it might have come. [SEP]',
#  'do t think [SEP]',
#  '[CLS] a reasonably entertaining sequel. [SEP]',
#  'woody happened [SEP]',
#  '[CLS] one of the most exciting. [SEP]',
#  'it throws,, and off, all as look this [SEP]',
#  '[CLS], feels impersonal, almost generic. [SEP]',
#  '[CLS] something has been lost in the translation another routine. [SEP]',
#  '[CLS] a sharp satire. [SEP]',
#  '[CLS] presents nothing and, nothing. [SEP]',
#  '[CLS] coupling, circuit is the awkwardly paced. [SEP]',
#  'but every filling as treat. [SEP]',
#  "[CLS]ot's strategy allows his the benefit of being able to full while opera [SEP]",
#  '[CLS] is enough and can certainly not enough. [SEP]',
#  'nice work [SEP]',
#  '[CLS] uneasy, and the quiet brings us right center. [SEP]',
#  '[CLS] but it gets harder and harder to understand her. [SEP]',
#  'a? [SEP]',
#  "is so prolonged and boring itn't bad. [SEP]",
#  'if through, ll some fine. [SEP]',
#  'this directed., is corny in a way that bes an. [SEP]',
#  "[CLS]'works as an unusual and [SEP]",
#  '[CLS] should be viewing and. [SEP]',
#  '[CLS] cal is an unpleasant and character whom to. [SEP]',
#  'merchant story. [SEP]',
#  '[CLS] does not its to. [SEP]',
#  ', i found what time? [SEP]',
#  'a. [SEP]',
#  '[CLS] that comes as a welcome, if downbeative from a',
#  '[CLS] wait terrific - if you n borrow some. [SEP]',
#  'everything, feels secondhand, familiar and not. [SEP]',
#  '[CLS] is t a product much as, [SEP]',
#  '[CLS] plays like somey [SEP]',
#  'nothing but an [SEP]',
#  'offers just enough to counter cr [SEP]',
#  '[CLS] just about the best. [SEP]',
#  'who, is fighting whom?',
#  '[CLS] the that emerges has elements and even. [SEP]',
#  "[CLS] than, right down to'sging [SEP]",
#  'feeled and [SEP]',
#  '[CLS] much and duke is about quiet,. [SEP]',
#  '[CLS] remains a ding and thoughtvoking film. [SEP]',
#  '[CLS], but maguire makes a soul [SEP]',
#  'a muddy thriller. [SEP]',
#  '[CLS] is strange and compelling,rossing and different, a with. [SEP]',
#  'one bigy. [SEP]',
#  '[CLS] the re release proves absolutely that good can enormous packages [SEP]',
#  'weird [SEP]',
#  'a of material already thoroughlybed. [SEP]',
#  '[CLS] some it hot proves once again is not. [SEP]',
#  '[CLS] yet this one makes heart [SEP]',
#  '[CLS] worth just for trying. [SEP]',
#  'the uneven not quite enough of them. [SEP]',
#  '[CLS] aing. [SEP]',
#  'just crank [SEP]',
#  "[CLS] it s funny, because's true. [SEP]",
#  '[CLS] it s not because it plays [SEP]',
#  'a passionate determined to and hopefully. [SEP]',
#  '[CLS] the movie has a tougher time balancing its. [SEP]',
#  'a sham based on,, and. [SEP]',
#  '[CLS] end,, the film ascends to a kinetic life so teeming that crank may quivering. [SEP]',
#  'that is a poem to enduring strengths. [SEP]',
#  '[CLS] the very an ambitious failure. [SEP]',
#  '[CLS] provides a satisfactory overview. [SEP]',
#  "is an autolot conction lacking, yet it's geared toward an of masters [SEP]",
#  '[CLS]pton he has actually bothered to a real this time. [SEP]',
#  'seems, and sad, sick sight. [SEP]',
#  "[CLS], and he's got as potent a topic as ever here [SEP]",
#  '[CLS] style it has sporadicliness, some few pleasing its. [SEP]',
#  '[CLS]ds something often rich exciting and always. [SEP]',
#  '[CLS] and arecratic enough to lift the. [SEP]',
#  'is a with competence [SEP]',
#  '[CLS] another useless recycling. [SEP]',
#  '[CLS] entertaining. [SEP]',
#  'instead,der relies on subtle iron and devices. [SEP]',
#  '[CLS] the is funny - - not,. [SEP]',
#  'a,ggy. [SEP]',
#  "[CLS] tries too's too, too and too. [SEP]",
#  'hated in morning [SEP]',
#  'this as a sm guilty pleasure. [SEP]',
#  '[CLS] times even, ignorant fairies is still quite good nature and not a. [SEP]',
#  '. one too [SEP]',
#  'numbingly dullted andly. [SEP]',
#  '[CLS] only at the beck. [SEP]',
#  'this plays as more than, creating intriguing that gives something of. [SEP]',
#  '[CLS] aly opaque andpid exercise. [SEP]',
#  'the digital effectsb reminded ofdiment old, and paste them together. [SEP]',
#  'trapped presents a frightening and compelling [SEP]',
#  'no [SEP]',
#  "[CLS] cinematic poetry showcases the's. [SEP]",
#  'for, is and ultimately with a sterling ensemble [SEP]',
#  'it rapidly develops into a gut wrenching examination [SEP]',
#  'theyinate in theirness [SEP]',
#  '[CLS] it, and it is nevertheless maintained throughout. [SEP]',
#  'taste [SEP]',
#  '[CLS] a couple things that elevate above, notably mere presence [SEP]',
#  '[CLS] was, and reflects the worst of their shallow styles : wildlyduced,ly the andally targeted [SEP]',
#  '[CLS] is, but its just not [SEP]',
#  '[CLS] although devoid and, dog and has a compelling story to tell. [SEP]',
#  'as played danny frightening fascinating contradiction [SEP]',
#  's a a renowned indian that allows americans finallydor. [SEP]',
#  '[CLS], but ca t [SEP]',
#  's sort of a 21st with a latino beat [SEP]',
#  '[CLS] a endless superficial. [SEP]',
#  'is this films reason being [SEP]',
#  'rock wanes. [SEP]',
#  '[CLS] what have is actually a compelling look. [SEP]',
#  'a with a. [SEP]',
#  "[CLS],'s film lacks balance and fails to. [SEP]",
#  "[CLS] it collapses when '. [SEP]",
#  "[CLS] has enough wit andity to please the, also nothing '. [SEP]",
#  'delivers roughly equal. [SEP]',
#  '[CLS] below, but his promise remains undnished [SEP]',
#  "[CLS] wouldn't it be funny if? [SEP]",
#  'a wonderful that made by me [SEP]',
#  '[CLS] bravo for rewritten and for the unpromising knowledge love. [SEP]',
#  '[CLS] n and is [SEP]',
#  "[CLS] frei assembles a fascinating profile of a ', surprisingly and an extraordinary the [SEP]",
#  '[CLS] i t think this loves. [SEP]',
#  '[CLS] no movie, but it [SEP]',
#  '[CLS] it s once laugh andively watch inness [SEP]',
#  '[CLS], is such brainpower coupled with pitch perfect acting and exquisite [SEP]',
#  '[CLS], they t distract from the flawed structure holding equilibrium [SEP]',
#  '[CLS] may be one of the most appealing ever maderight, [SEP]',
#  "[CLS]'s light is achingly honest and delightfully cheeky. [SEP]",
#  'the and. [SEP]',
#  '[CLS]e its, is consistently amusing and. [SEP]',
#  '[CLS], the never. [SEP]',
#  'has a and managed to convey a tiny hope. [SEP]',
#  "[CLS], what's even more remarkable is the integrity of [SEP]",
#  '[CLS] a very funny comedy about. [SEP]',
#  'only in making meog [SEP]',
#  '[CLS] will it n gone straight video? [SEP]',
#  'hawke film a boring, waste of nearly, does n t is and. [SEP]',
#  "more the same from which is good news to anyone'fallen melancholy spell this unique. [SEP]",
#  'a and humorous that its [SEP]',
#  "[CLS] what's surprising about this, moderately not, is exactly how and. [SEP]",
#  "[CLS] it's definitely not made, and think sand it uneresting. [SEP]",
#  '[CLS] also has a good for, and sound like [SEP]',
#  "[CLS] a film's winning tone must to grant, who has t lost dry [SEP]",
#  '[CLS] biggest problem i have other the very sluggish pace is we never esther,. [SEP]',
#  '[CLS] a moving essay about,. [SEP]',
#  '[CLS] a smart and rather comedy [SEP]',
#  'a general that s hard resist. [SEP]',
#  '[CLS] little is support other than. [SEP]',
#  '[CLS] continues with considerable br [SEP]',
#  '[CLS], but unlike, this adaptation entertains. [SEP]',
#  '[CLS], but the around is so often nearly nothing that their charm does n. [SEP]',
#  '[CLS] what redeems film is particularly [SEP]',
#  'weighs withusities [SEP]',
#  'pretend werewolf by and. [SEP]',
#  '[CLS]eoworks. but neglects to add the. [SEP]',
#  'mon! [SEP]',
#  'was scared?',
#  '[CLS] a journey spanning nearly three decades of bitter and which we holly, as imperfect [SEP]',
#  '[CLS] too ordinary to restore, despite some, and aworthy attempt. [SEP]',
#  '[CLS]!',
#  'the, so thick with wit it plays like a [SEP]',
#  '[CLS] a little tooous to shallow entertainment,, serves mostly tohet. [SEP]',
#  "the's final, iscing soap that. [SEP]",
#  'handsome. [SEP]',
#  "' fondness for, and. blends uneasily with the ti [SEP]",
#  'watching junk this induces a abstract guilt, as were [SEP]',
#  "[CLS] lacks of a, there's a certain robustness to this [SEP]",
#  '[CLS] an ingenious and oftening look and. [SEP]',
#  "[CLS] whatever the's, come in various wet and. [SEP]",
#  'a let [SEP]',
#  '[CLS] it not, but the film crisp and make it unexpectedly reward. [SEP]',
#  '- -mirable energy, and urgency [SEP]',
#  'a wonderful [SEP]',
#  '[CLS] surprising is how well it holds up in',
#  'aora of engaging, delivered grand passion various. [SEP]',
#  '[CLS] a black [SEP]',
#  "[CLS] a superfluous sequel. plagued by ', but visible is mighty hard. [SEP]",
#  "[CLS] particularly but howling'say the film works [SEP]",
#  "[CLS]'may find some in this jumbled mess. [SEP]",
#  ', but it s really more the next pretty good thing [SEP]',
#  'stephen has made mistake of being. [SEP]',
#  'a with big. [SEP]',
#  '[CLS] disappointing in comparison to. [SEP]',
#  'is a, and ordinary. [SEP]',
#  '[CLS] it but it completely misses. [SEP]',
#  '[CLS] my ; delivery here. [SEP]',
#  '[CLS] s impossible toul when her is so charmless and vacant. [SEP]',
#  '[CLS] always watch marker the. [SEP]',
#  'this is hardly which would have made for better drama. [SEP]',
#  'siating about frontal it s too close to. [SEP]',
#  '[CLS] graced with the kind texture and. [SEP]',
#  '[CLS] the mostenious. [SEP]',
#  '[CLS] a comedy that frequently, probably would not improve much. [SEP]',
#  '[CLS] boasts enough to be mildly. [SEP]',
#  'might. [SEP]',
#  'it old quickly [SEP]',
#  'surprisingly',
#  '[CLS] but delightful so. [SEP]',
#  'a clever and skilled bring new [SEP]',
#  '[CLS] sincehmer, it misses a major opportunity. [SEP]',
#  '[CLS], but i kept looking for. [SEP]',
#  '[CLS] is a separate and thrill enough. [SEP]',
#  'the is [SEP]',
#  '[CLS] to get this film would require many sessions [SEP]',
#  'why did necessary document this misery? [SEP]',
#  'its are enough, and the film succeeds as almost. [SEP]',
#  '[CLS] applied to. [SEP]',
#  'and inept [SEP]',
#  'but you missed the point. [SEP]',
#  '[CLS] a, but the word perfectly describes &. [SEP]',
#  "average, best '. [SEP]",
#  '[CLS] guys and lot. [SEP]',
#  '[CLS] a different and emotionally reserved type - a film less, [SEP]',
#  '[CLS] offers a perve. [SEP]',
#  '[CLS] is structured, and as such the film has a difficult time shaking its. [SEP]',
#  '- painfully flat gross - comedy. [SEP]',
#  '[CLS] end you help feel stoked. [SEP]',
#  '[CLS] the keeps this pretty, and was inspired [SEP]',
#  '[CLS] so numbingly awful that, far movies. [SEP]',
#  '[CLS] a terrific entertaining specimen. [SEP]',
#  'lacking comes up shorter than [SEP]',
#  'the film ultimately offers nothing. [SEP]',
#  '[CLS] and pokemon t be disappointed [SEP]',
#  '[CLS] the manages the rare [SEP]',
#  '[CLS] symbolically warm water a red is a feminine a tribute. [SEP]',
#  "[CLS]'s truly, but one whose are well [SEP]",
#  '[CLS] the who falls flat as this,. [SEP]',
#  's absolutely amazing how managed to find something new to add [SEP]',
#  "' s, racial and most importantly. [SEP]",
#  "[CLS]'unfortunate that,, has such an irrepressible passion forpy and. [SEP]",
#  "[CLS] notwithstanding problem, i'm going to recommend secretary, based on, and also the unique [SEP]",
#  '[CLS] after a, only country bears is to get wet, fuzzy and sticky. [SEP]',
#  "[CLS] ', but there is an interesting courage. [SEP]",
#  'the never and several run too long [SEP]',
#  '[CLS] very amusing, and are odd and sometimes both [SEP]',
#  'no and no. [SEP]',
#  "[CLS] signals rick's emergence as an art [SEP]",
#  ', the dialogue frequently misses mark [SEP]',
#  'really need the? [SEP]',
#  '[CLS] you leave the same -, but no. [SEP]',
#  'too long, andd with exposition this ultimately feels flat. [SEP]',
#  '[CLS] abandon spends 90 minutes trying. [SEP]',
#  "[CLS] this ready midnight t, but under the right conditions, it's goofy fun. [SEP]",
#  '[CLS] and neither do, [SEP]',
#  '[CLS] great fun both for and. [SEP]',
#  '[CLS] an overly but somewhat film. [SEP]',
#  '[CLS].,. reno devolves into a - lecture [SEP]',
#  '[CLS] it gives devastating testimony and [SEP]',
#  "[CLS]'s a treat watching shaw, melting heat ph. [SEP]",
#  's a rare [SEP]',
#  '[CLS], but is doubtful this listless feature him. [SEP]',
#  '[CLS] despite flaws is still able that keeps [SEP]',
#  'is full charm [SEP]',
#  "[CLS] not even's can fully succeed at cheapening it. [SEP]",
#  '[CLS] a but unfullling drama more suited [SEP]',
#  'filled with, completely transxes. [SEP]',
#  '[CLS] would make an excellent to [SEP]',
#  '[CLS] so aggressivelyy would. [SEP]',
#  '[CLS] as with so type, more time appears to have gone than, which has a handful [SEP]',
#  '[CLS] it cooks. [SEP]',
#  '[CLS] and, is a small gem. [SEP]',
#  '[CLS] a,. [SEP]',
#  '[CLS] - - smarter and muchnier version. [SEP]',
#  'limps along on inducing and goes slowly. [SEP]',
#  '[CLS] it lets brush without [SEP]',
#  'is sorely lacking [SEP]',
#  'hate it [SEP]',
#  '[CLS] continually challenges and asks us.',
#  'only movie is [SEP]',
#  'this is an insultingly inept and artificial. [SEP]',
#  '[CLS] a very, and it will stand as an [SEP]',
#  ', and seems as deflated as he. [SEP]',
#  'mastering, groupiculates a emotion [SEP]',
#  'this tepid genre. [SEP]',
#  "[CLS] lovely amazing is ho's deeppromising curtsy is. [SEP]",
#  '[CLS] watching ending is too often like looking your. [SEP]',
#  "a dull'[SEP]",
#  '[CLS] and, it [SEP]',
#  'maybe lenc thought the was worse. [SEP]',
#  '[CLS] the has rewards from the its sand to its. [SEP]',
#  "[CLS] a delightful stimulus, so much that'svable that feels like. [SEP]",
#  '[CLS] a wildly with and others, that are quite touching. [SEP]',
#  'is clever, and even enough to overcome my',
#  'plays tired [SEP]',
#  'genuinely. [SEP]',
#  '[CLS] lazily directed by. a leaden script. [SEP]',
#  '[CLS] fails to. [SEP]',
#  '[CLS] sounding like has a wooden delivery and encounters a substantial change that does n t. [SEP]',
#  'an original and [SEP]',
#  '[CLS] makes the strong and being more valuable in the they. [SEP]',
#  'is tenderly. [SEP]',
#  '[CLS] there are deeply religious and spiritual people world who would argue check brain [SEP]',
#  '[CLS] although familiar, every while a arrives from the margin that gives travel. [SEP]',
#  'the is dismiss moody, thoughtful, anddant [SEP]',
#  'low rent. [SEP]',
#  "[CLS] a heady, biting, ride, acious and'll. [SEP]",
#  'the material nevers its questionablence [SEP]',
#  "[CLS] a realr that will strike a chord with''. [SEP]",
#  '[CLS] will play, but american will probably find it familiar and insufficiently cathartic. [SEP]',
#  "[CLS]'all, but with great help from makes us care about this [SEP]",
#  '[CLS] puts a refreshing and comical. [SEP]',
#  'unfortunately the are served a hack [SEP]',
#  '[CLS] nearly are mishandled here. [SEP]',
#  'the power of. [SEP]',
#  '[CLS] has and a fair. [SEP]',
#  'much s charm lies in utter cute and [SEP]',
#  '[CLS] with next, why bother with a contempt - -? [SEP]',
#  '[CLS] together and - establish mr france the workplace. [SEP]',
#  '[CLS], but the movie too often spins its wheels with familiar and repetitive. [SEP]',
#  '. [SEP]',
#  '[CLS] givespiness, undermining. [SEP]',
#  'this is noboy [SEP]',
#  '[CLS] one very best movies made about. [SEP]',
#  "it's a clear - eyed portrait. [SEP]",
#  "[CLS] conforms itself with creating a '. [SEP]",
#  'lot recommend read [SEP]',
#  ', the result does no to the. [SEP]',
#  '[CLS] a is still a and t disappointed. [SEP]',
#  '[CLS] becomes a fascinating study that successfully recreates. [SEP]',
#  'a stirring [SEP]',
#  '[CLS] pretend your. [SEP]',
#  'finds the ideal outlet for hisction [SEP]',
#  '[CLS] difference is that her confidence is merited [SEP]',
#  '[CLS] while john colors the in some evtive shades. [SEP]',
#  '[CLS] a thinly posing. [SEP]',
#  "[CLS] although bravo's it s still a guilty pleasure watch. [SEP]",
#  'an odd,zard, and comedy. [SEP]',
#  'is undoubtedly one the finest year [SEP]',
#  '[CLS] is terrific ; and emphasising. [SEP]',
#  '[CLS], but this will definitely win some hearts. [SEP]',
#  '[CLS] a searing, epic treatment. [SEP]',
#  '[CLS] the word, is painterly. [SEP]',
#  'a [SEP]',
#  '[CLS] there s little recommend snow dogs,iched of high. [SEP]',
#  '##istic, andious. [SEP]',
#  '[CLS] theiest trick perrated by the importance earnest is the. [SEP]',
#  '[CLS] intensely and even. [SEP]',
#  '[CLS] is delightful. [SEP]',
#  'takes a clunky tv - approach to. [SEP]',
#  "highlighted a gritty style excellent cast it's better than movies ice. [SEP]",
#  'whilefully and valiantly keep punching up [SEP]',
#  '[CLS] half, but doug and colleagues have managed to pack it enough to the without. [SEP]',
#  'problem the movie has no [SEP]',
#  '[CLS] s greatest mistake is thinking that needed [SEP]',
#  "[CLS] it's awfully entertaining watch. [SEP]",
#  'suffers excess the genre. [SEP]',
#  '[CLS] mcgrath has deftly trimmed sprawling, the better to focus. [SEP]',
#  '[CLS] getard distinctive will still come away a sense of. [SEP]',
#  'is a wreck, a catastrophic collision oflessness gall that nevertheless will [SEP]',
#  '[CLS] the work an tormented, using his. [SEP]',
#  'is year best. [SEP]',
#  '[CLS] with amazing finesse the film shadows heidi',
#  '[CLS] and substitute and for and. [SEP]',
#  'bad company is in it [SEP]',
#  'onenier. [SEP]',
#  '[CLS] it offers a glimpse of solomon. [SEP]',
#  '[CLS] so completely loses himself to the s to. [SEP]',
#  'not good, but what is [SEP]',
#  'this gets job [SEP]',
#  '[CLS] both anable reconstruction and a fitting. [SEP]',
#  '[CLS] a thriller with an edge that it does t [SEP]',
#  's held med. [SEP]',
#  '[CLS] - absorbing documentary. [SEP]',
#  'this is most a useless movie, even [SEP]',
#  '[CLS] of that moral favorite : will [SEP]',
#  'peter gives these and they take full advantage [SEP]',
#  'pretty delivers promise [SEP]',
#  'liked a lot [SEP]',
#  'tooy, and long for its. [SEP]',
#  "[CLS] they threw loads of money should've so [SEP]",
#  '[CLS] dragon never. [SEP]',
#  '[CLS] the film fearlessly gets under. this makes, but and [SEP]',
#  '[CLS] a clash comedy that, in addition, captures some. [SEP]',
#  '[CLS] are fun and reminiscent. [SEP]',
#  's but a great one [SEP]',
#  "[CLS] i suffered and bled on the, i'd want [SEP]",
#  '[CLS] the picture uses and afelt conviction to a, but also,. [SEP]',
#  '[CLS] playing? [SEP]',
#  '[CLS]d by, emerges as a numbingly dull experience. [SEP]',
#  '[CLS] do n. [SEP]',
#  '[CLS] is something in frontal i, about, but most riddles, it works only [SEP]',
#  "[CLS] there's a, that makes throughout. [SEP]",
#  'the seem, and is superficial and will probably. [SEP]',
#  'the film is moody,ozing, chilling and heart warming all once a [SEP]',
#  'can except that it have worked so much better dealing only [SEP]',
#  '[CLS] fontaine masterfully creates a portrait inably, neither. [SEP]',
#  'almost saves [SEP]',
#  '[CLS] this and it gets very ugly, very fast [SEP]',
#  '[CLS]. built on the premise that arkansas consists. [SEP]',
#  '[CLS] mey has done his and soaked up some jazzy [SEP]',
#  "[CLS] t appreciate the emotional depth of haynes'work. [SEP]",
#  '[CLS] can only provide with so much. [SEP]',
#  "[CLS] perates the whole, todd'oftens funny yet ultimately. [SEP]",
#  '[CLS], but it is a and mandy leaves a impression. [SEP]',
#  '[CLS] does t - it embraces,zes and takes big out [SEP]',
#  '[CLS], but s itself virtually collapses an, maintaining just. [SEP]',
#  '[CLS] it makes me feel weird \\ thinking bad like [SEP]',
#  'but does somehow [SEP]',
#  "what would've looked like as a a. [SEP]",
#  "[CLS] a weird little that's amusing enough while, offering fine and pungent.. [SEP]",
#  'this has its rewards. [SEP]',
#  'a confusingudge. [SEP]',
#  '[CLS] performance - we hope only [SEP]',
#  '[CLS] feels a than like a bottom -. [SEP]',
#  "one greatest '. [SEP]",
#  "[CLS] is drowned out by's sap. [SEP]",
#  'poetic,. [SEP]',
#  '[CLS] high drama, style. [SEP]',
#  'has crafted an engaging, one, one. [SEP]',
#  '[CLS] bounces around with limp, wearing, his and assuming. [SEP]',
#  "[CLS] it doesn't offer. [SEP]",
#  'is little [SEP]']

# %% [markdown]
# ### Electra

# %%
sentence_word_token
# Out:
# ['[CLS] lurous, butes. [SEP]',
#  '[CLS]ting, manages as. [SEP]',
#  '[CLS] the of in byter wife. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] angel,es particularly nightmar. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS]... [SEP]',
#  '[CLS] while the old evans been. [SEP]',
#  "[CLS] despitesson's profile name beingabi's point, thatk of the. [SEP]",
#  '[CLS] been. s in positive - lrb - [SEP]',
#  '[CLS] while... [SEP]',
#  '[CLS]s breath of. [SEP]',
#  '[CLS] with even. [SEP]',
#  "[CLS] the movie is by who of `'with like. [SEP]",
#  "[CLS] ` `'' that!'' [SEP]",
#  '[CLS]. [SEP]',
#  "[CLS]'s. [SEP]",
#  "[CLS] it doesn't. [SEP]",
#  "[CLS]'s, couldn't out he ` em here. [SEP]",
#  '[CLS] to. [SEP]',
#  '[CLS] with,. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] this doesn't. [SEP]",
#  '[CLS] be are included [SEP]',
#  "[CLS] itically, somehow under the that ` `'' is even. [SEP]",
#  '[CLS] resurrection has distinction. [SEP]',
#  '[CLS] two by too. [SEP]',
#  '[CLS] the. [SEP]',
#  "[CLS] while, is one, and you've it to for biting off the out. [SEP]",
#  '[CLS] a. [SEP]',
#  '[CLS] the leaping line, into slivers and, shows. [SEP]',
#  '[CLS] i was feeling untilxon,. [SEP]',
#  "[CLS] heavyweight'- and it pictures punching. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] he to. [SEP]',
#  '[CLS] a with. [SEP]',
#  '[CLS] manages to - - state. [SEP]',
#  "[CLS] if think's'll. [SEP]",
#  '[CLS],stc. [SEP]',
#  '[CLS] than. [SEP]',
#  "[CLS] the :'s. [SEP]",
#  '[CLS] although it, up to than. [SEP]',
#  '[CLS] a enough that beingoat. [SEP]',
#  '[CLS] with, abouts evokes the bottom. [SEP]',
#  "[CLS]utteredss.'[SEP]",
#  '[CLS] a of. [SEP]',
#  "[CLS] joaorigues''s on. [SEP]",
#  '[CLS] appropriately,folds with. [SEP]',
#  '[CLS] a whole, though finish. [SEP]',
#  '[CLS] the is. [SEP]',
#  '[CLS] there is that about how, in flip flop, in we. [SEP]',
#  '[CLS] the are to. [SEP]',
#  '[CLS] picture is with so - over [SEP]',
#  '[CLS] use, but in. [SEP]',
#  '[CLS] an,d, it asable,. [SEP]',
#  '[CLS] it takes time tope out. [SEP]',
#  '[CLS] ands fromity but of. [SEP]',
#  '[CLS] fun, showtime is while. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] a. [SEP]',
#  '[CLS] the has,, are. [SEP]',
#  "[CLS]pers is doesn't know. [SEP]",
#  "[CLS] the, only now's to up that can. [SEP]",
#  "[CLS]'s a reason long. [SEP]",
#  "[CLS]'sious into. [SEP]",
#  "[CLS]'s for, to from. [SEP]",
#  '[CLS] asy. [SEP]',
#  '[CLS] aion. [SEP]',
#  '[CLS] still be, works - to. [SEP]',
#  "[CLS] i confession make didn't t.. [SEP]",
#  '[CLS]sy. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] hard. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS],ing,'s [SEP]",
#  "[CLS]'s is the one thing interest in the of. [SEP]",
#  "[CLS]'s dec. [SEP]",
#  '[CLS]. [SEP]',
#  '.',
#  "[CLS] however,'s. [SEP]",
#  '[CLS] a even without! [SEP]',
#  '[CLS]ful to be. [SEP]',
#  "[CLS]'s, with. [SEP]",
#  '[CLS] dialogue [SEP]',
#  "[CLS] what's memorable about circuit is that's, whose.... [SEP]",
#  '[CLS] with is, and surely haverigue [SEP]',
#  "[CLS] has to, can't. [SEP]",
#  '[CLS] a shimmeringly lovely, shotful. [SEP]',
#  '[CLS] proves that, with. [SEP]',
#  '[CLS] the filmmakers try to, with areling and ways. [SEP]',
#  "[CLS] the way doesn't instance,. [SEP]",
#  '[CLS], whichonate. [SEP]',
#  "[CLS]ki's than'-. [SEP]",
#  "[CLS] because as doesn't '. [SEP]",
#  '[CLS] himself. [SEP]',
#  "[CLS] notice's as. [SEP]",
#  '[CLS] skin of gets a cheap fromil, but into with adults. [SEP]',
#  '.',
#  "[CLS]'s. [SEP]",
#  "[CLS] well, it won'toting''. [SEP]",
#  '[CLS] an impond. [SEP]',
#  '[CLS] movie -. [SEP]',
#  '[CLS] a about old boy than girls, in. [SEP]',
#  "[CLS]'s don't least by way of from test. [SEP]",
#  '[CLS]? [SEP]',
#  "[CLS] is's...ng middle [SEP]",
#  '[CLS]osflower. [SEP]',
#  "[CLS] in oldwritinglance,.'s, '. [SEP]",
#  '[CLS] apy of - - -s. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] check and agent door because don't '. [SEP]",
#  "[CLS] let's see,,'s next..? [SEP]",
#  '[CLS] alsoed arerama [SEP]',
#  '[CLS] - lrb - -b - who. [SEP]',
#  '[CLS] this is a about thatrns up but tore. [SEP]',
#  "[CLS]ish is -'s. [SEP]",
#  '[CLS] find, find improved. [SEP]',
#  '[CLS] to. [SEP]',
#  '[CLS] than and in their way,. [SEP]',
#  '[CLS] freaks. [SEP]',
#  '[CLS] the and dares to depict. [SEP]',
#  '[CLS] is may work, but. [SEP]',
#  '[CLS]ating res. [SEP]',
#  '[CLS] but. [SEP]',
#  '[CLS] the istic in. [SEP]',
#  "[CLS] here's a case of who do who by. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] the of. [SEP]',
#  '[CLS]cols press [SEP]',
#  "[CLS]... `'to from up. [SEP]",
#  "[CLS] it's, but. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] begins. [SEP]',
#  '[CLS].. and 4 \\ /s of from than -rb directorc. [SEP]',
#  '[CLS] do. [SEP]',
#  "[CLS] a to's that. [SEP]",
#  '[CLS],? [SEP]',
#  '[CLS] of. [SEP]',
#  '[CLS] it at us, say ` ` at! [SEP]',
#  '[CLS] rumor, with,. [SEP]',
#  '[CLS]... in which the execution itizes. [SEP]',
#  '[CLS] of. [SEP]',
#  '[CLS] presentsable. [SEP]',
#  '[CLS] for, circuit is the. [SEP]',
#  '[CLS]yous as. [SEP]',
#  "[CLS]ot's allows to... that. [SEP]",
#  '[CLS] thes movie and can certainly not. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] the saigons, and the quiet american into. [SEP]',
#  "[CLS] it's -'- understand. [SEP]",
#  '[CLS]? [SEP]',
#  "[CLS] is it isn't to it. [SEP]",
#  "[CLS] if can through'with. [SEP]",
#  '[CLS] this, by of, is in a way bespeaks ex date ago. [SEP]',
#  "` `'' era",
#  '[CLS] should be. [SEP]',
#  '[CLS] cal is with whom to. [SEP]',
#  '[CLS] if only attention. [SEP]',
#  '[CLS] does not to out. [SEP]',
#  '[CLS], but i found what? [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] are so that skins comes,ive from front. [SEP]',
#  "[CLS] don't - do t. [SEP]",
#  "[CLS] about girls ca't, way. [SEP]",
#  "[CLS] isn't as. [SEP]",
#  '[CLS] era [SEP]',
#  '[CLS] but! [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] about best film. [SEP]',
#  '[CLS]? [SEP]',
#  '[CLS] the movie. [SEP]',
#  "[CLS]..., down to's to. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] of the and asdes. [SEP]',
#  "[CLS]... `''.. [SEP]",
#  "[CLS]'s book but maguire. [SEP]",
#  '[CLS] a with. [SEP]',
#  '[CLS] maetrom ising different,. [SEP]',
#  '[CLS] where happens. [SEP]',
#  "[CLS] the'sax proves absolutely that. [SEP]",
#  '.',
#  '[CLS] abed by. [SEP]',
#  '[CLS] some proves again that is in himself. [SEP]',
#  '[CLS] yet this up for. [SEP]',
#  '[CLS] worth than. [SEP]',
#  '[CLS] the does have. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS]'s as goes. [SEP]",
#  "[CLS] yet's '. [SEP]",
#  '[CLS] aive film to. [SEP]',
#  '[CLS] throughout... but the haser time. [SEP]',
#  '[CLS] a on and. [SEP]',
#  '[CLS] at the end, when theda ascend a lifeming that mayver. [SEP]',
#  '[CLS]ura that to. [SEP]',
#  "[CLS] of.'' [SEP]",
#  '[CLS] provides of asils. [SEP]',
#  "[CLS] sc2, yet it's toward of masters. [SEP]",
#  '[CLS]bly, he actually time. [SEP]',
#  "[CLS], and's sight. [SEP]",
#  "[CLS]ed aggrazing making, and he's as. [SEP]",
#  '[CLS] -... it hasliness so. [SEP]',
#  '[CLS]ds. [SEP]',
#  '[CLS] to abovewriting. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] another. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] head, scder on convey. [SEP]',
#  "[CLS] the - ` ha'' '. [SEP]",
#  '[CLS] a. [SEP]',
#  "[CLS] in a way's. [SEP]",
#  '[CLS]. [SEP]',
#  "[CLS]'s torize. [SEP]",
#  '[CLS] at timestic -rb - live -b -, fairies isd. [SEP]',
#  '[CLS]... [SEP]',
#  '[CLS] by. [SEP]',
#  '[CLS] only at of. [SEP]',
#  '[CLS] this as a poetic, ofifice gives. [SEP]',
#  '[CLS] a and in. [SEP]',
#  '[CLS] -rb - -b - of s rudimentary. [SEP]',
#  "[CLS] trapped?'[SEP]",
#  '.',
#  '[CLS] before machines. [SEP]',
#  '[CLS] for, wednesdayful,. [SEP]',
#  '[CLS] it into of waylide. [SEP]',
#  '[CLS] but. [SEP]',
#  '[CLS] it establishes, and if,. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS]evate ` `'' above,. [SEP]",
#  '[CLS] one - lrb [SEP]',
#  '[CLS] theious thoughably, its. [SEP]',
#  '[CLS] although nos,town and has tell. [SEP]',
#  '[CLS] as,. [SEP]',
#  "[CLS]'s culture to. [SEP]",
#  "[CLS] can tell be can't. [SEP]",
#  "[CLS]'s. [SEP]",
#  '[CLS] a caution tale about is. [SEP]',
#  '[CLS] s is being. [SEP]',
#  "[CLS]'s. [SEP]",
#  "[CLS] is actually at '. [SEP]",
#  '[CLS] -. [SEP]',
#  "[CLS] while it is,'s.... [SEP]",
#  "[CLS] it when's. [SEP]",
#  "[CLS] has to fan, but know think're. [SEP]",
#  '[CLS] delivers roughly. [SEP]',
#  "[CLS] below not. ',nished. [SEP]",
#  "[CLS] wouldn't if ii? [SEP]",
#  '[CLS] made up for into. [SEP]',
#  '[CLS] forwritten, that. [SEP]',
#  "[CLS] but don't. [SEP]",
#  "[CLS]eis of ', around [SEP]",
#  "[CLS] i do't. [SEP]",
#  '[CLS] by. [SEP]',
#  "[CLS] it'sableable, in. [SEP]",
#  '[CLS] never, isage withfa. [SEP]',
#  "[CLS], can't from up. [SEP]",
#  '[CLS] tadpole be about, - with stepmother. [SEP]',
#  "[CLS]'s hearted of is. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] -rb - espite,ing... [SEP]',
#  '[CLS], theifies. [SEP]',
#  '[CLS] children and to. [SEP]',
#  "[CLS] to, but what's remarkable is s. [SEP]",
#  '[CLS] a about who into and then struggle with f. [SEP]',
#  '[CLS]... [SEP]',
#  "[CLS] will isn'tr excitedn't? [SEP]",
#  "[CLS] hawke's film,, doesn't tell except that the hotel by. [SEP]",
#  "[CLS] of sameur, which news to '. [SEP]",
#  '[CLS]ble lovess rather. [SEP]',
#  "[CLS] what's surprising about,, is unsurising out be. [SEP]",
#  "[CLS]'s definitely for matter, i think of sting. [SEP]",
#  '[CLS] writer director also, and. [SEP]',
#  "[CLS] a of to, who hasn't first love him. [SEP]",
#  '[CLS] the i have -rb - - - is see her esther though. [SEP]',
#  '[CLS]ter suicide. [SEP]',
#  '[CLS] a. [SEP]',
#  "[CLS] in about's. [SEP]",
#  '[CLS] to see which onestick. [SEP]',
#  '[CLS] cho continuesio. [SEP]',
#  "[CLS] it ain't, but. [SEP]",
#  "[CLS], so doesn't do. [SEP]",
#  '[CLS] redeems is themselves. [SEP]',
#  '[CLS]pur. [SEP]',
#  "[CLS] pretend's. [SEP]",
#  '[CLS]eoworks success.. add all work. [SEP]',
#  '!',
#  '[CLS]? [SEP]',
#  '[CLS] a, which, love [SEP]',
#  '[CLS] too to restore -rb harmon -, despiteoke, and a praiseworthy out. [SEP]',
#  '[CLS]! [SEP]',
#  "[CLS]'stions [SEP]",
#  "[CLS] aous to,, serves to whet'for the films. [SEP]",
#  "[CLS] the's, is that was to. [SEP]",
#  '[CLS]. [SEP]',
#  "[CLS] -rb -'s -b - for.s with the ti [SEP]",
#  '[CLS]s, if music heard. [SEP]',
#  "[CLS] though lacks the,'s toing. [SEP]",
#  '[CLS] anous at and how can. [SEP]',
#  "[CLS] whatever's h, out in scenes. [SEP]",
#  '[CLS] a. [SEP]',
#  "[CLS] it may be, but'sing. [SEP]",
#  '[CLS] -rbb -s. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] what's up in. [SEP]",
#  "[CLS] a plora ofbes '. [SEP]",
#  "a?''",
#  "[CLS] a... by old familiar'with': has at the, but is find. [SEP]",
#  "[CLS]'s but since, i'd say. [SEP]",
#  "[CLS] of're in. [SEP]",
#  "[CLS] `'' s of next. [SEP]",
#  "[CLS] has the call.'[SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] disappointing in to.. [SEP]',
#  '[CLS] is, for. [SEP]',
#  '[CLS] it right. [SEP]',
#  "[CLS] my s's. [SEP]",
#  "[CLS]'sge beard -rb - - when. [SEP]",
#  "[CLS]'markerist. [SEP]",
#  '[CLS] thise istor - - which for. [SEP]',
#  "[CLS]'s is's. [SEP]",
#  '[CLS]d would be foreign in. [SEP]',
#  '[CLS]kovich. [SEP]',
#  '[CLS] a as, probably would improve. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] the up. [SEP]',
#  '[CLS]. [SEP]',
#  '##ful',
#  '[CLS]. [SEP]',
#  '[CLS] a to. [SEP]',
#  '[CLS] sinceers when it be in, it missestory his. [SEP]',
#  '[CLS] if, as stands i for last. [SEP]',
#  "[CLS] the to '. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] to at root.. [SEP]',
#  '[CLS]? [SEP]',
#  '[CLS] are to. [SEP]',
#  '[CLS] beckett to. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS].'[SEP]",
#  "[CLS]'s find to, but the describes &. [SEP]",
#  "[CLS] i'm. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] a different and of story - - a filmting that man. [SEP]',
#  '[CLS] offers at. [SEP]',
#  '[CLS] interview with is, and as such the time project. [SEP]',
#  '[CLS] -rb a -.. [SEP]',
#  "[CLS] ca n '.'[SEP]",
#  '[CLS] the cast...able. [SEP]',
#  "[CLS] that you hope britney won't. [SEP]",
#  '[CLS] a. [SEP]',
#  "[CLS], up than's. [SEP]",
#  '[CLS] the offers than... [SEP]',
#  "[CLS] won't. [SEP]",
#  '[CLS] the manages the. [SEP]',
#  '[CLS] symbolically, a to. [SEP]',
#  "[CLS] it's awful, whose. [SEP]",
#  "[CLS] to `'' `'' man in s film ` `.'[SEP]",
#  "[CLS] it's how of. [SEP]",
#  "[CLS]'s,. [SEP]",
#  "[CLS] it's unfortunate that wallace s, for. [SEP]",
#  "[CLS] notwithstanding,'m going to on on about [SEP]",
#  '[CLS], the for to through the country bears is how to. [SEP]',
#  "[CLS] aren't, but there of.. [SEP]",
#  '[CLS] the. [SEP]',
#  '[CLS],, and arelated and. [SEP]',
#  '[CLS]cited. [SEP]',
#  "[CLS]wa's. [SEP]",
#  "[CLS] isn't. [SEP]",
#  '[CLS]? [SEP]',
#  '[CLS] you same way -. [SEP]',
#  '[CLS] too, this as the of. [SEP]',
#  '[CLS] abandon spends trying not. [SEP]',
#  "[CLS] won't,'s goofy -rb - ifsome - -. [SEP]",
#  "[CLS] and do'are. [SEP]",
#  '[CLS]adosts stadium seatplex. [SEP]',
#  '[CLS] anful... [SEP]',
#  '[CLS] when -rb -.,ves into lecture [SEP]',
#  "[CLS] it to's. [SEP]",
#  "[CLS]'s, ofs. [SEP]",
#  "[CLS]'s. [SEP]",
#  "[CLS] of 'ly enjoy, but it is him. [SEP]",
#  '[CLS]...insky. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] not even's can fully succeed at it. [SEP]",
#  '[CLS] alling to an amc. [SEP]',
#  '[CLS] with s,xes. [SEP]',
#  "[CLS] would to.'[SEP]",
#  '[CLS] so for. [SEP]',
#  '[CLS] with into has handful [SEP]',
#  '[CLS] it cooks conduct. [SEP]',
#  '[CLS], thing is. [SEP]',
#  '[CLS] a. [SEP]',
#  '[CLS] -rb -s. [SEP]',
#  '[CLS]s on a squi inducing and there slowly. [SEP]',
#  '[CLS] it you against. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] continually, asks us whether justify. [SEP]',
#  '[CLS] the. [SEP]',
#  '[CLS] this is anly inept. [SEP]',
#  '[CLS] a, and will stand years to. [SEP]',
#  "[CLS] he's and the as as does. [SEP]",
#  '[CLS] its,iculates. [SEP]',
#  '[CLS] to are. [SEP]',
#  "[CLS] is'ssy women is. [SEP]",
#  "[CLS] watching ` ` ending'''s. [SEP]",
#  '[CLS] s s. [SEP]',
#  "[CLS]'s. [SEP]",
#  "[CLS] ` `.'' [SEP]",
#  '[CLS] the feathers has rewards,. [SEP]',
#  "[CLS], that it's forgivable that. [SEP]",
#  '[CLS] a and others, to,. [SEP]',
#  '[CLS] even overcome my. [SEP]',
#  '[CLS] the. [SEP]',
#  '[CLS]ving. [SEP]',
#  '[CLS] lazily by iii... novelist. [SEP]',
#  '[CLS] fails to. [SEP]',
#  "[CLS] likegger match, -rb - encounters doesn't. [SEP]",
#  '[CLS] mind [SEP]',
#  "[CLS] makes in'andd. [SEP]",
#  '[CLS] s obvant of. [SEP]',
#  "[CLS] are world who argue that doesn't. [SEP]",
#  '[CLS] although, while film arrives from gives to. [SEP]',
#  '[CLS] the dismiss by. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] a through, locious videologue of and which he'll toon own. [SEP]",
#  '[CLS]...s. [SEP]',
#  "[CLS] ar with who's ever in bed or office. [SEP]",
#  '[CLS] will mr. name ms. shu, but findic. [SEP]',
#  "[CLS]'seen before form, but director hoffman, about thisnation. [SEP]",
#  '[CLS] puts on. [SEP]',
#  '[CLS] unfortunately the with. [SEP]',
#  '[CLS] all. [SEP]',
#  '[CLS].. [SEP]',
#  '[CLS] has,. [SEP]',
#  '[CLS] in. [SEP]',
#  "[CLS] with a `'', withibletor starring a `'' has been like? [SEP]",
#  '[CLS] -rb -b -.. [SEP]',
#  "[CLS] there's in their, the with. [SEP]",
#  '.',
#  "[CLS] of,pur us,ng '. [SEP]",
#  "!''",
#  '[CLS]making. [SEP]',
#  "[CLS]'s with andties. [SEP]",
#  "[CLS]s with'who.. than. [SEP]",
#  "[CLS]'s recommend. [SEP]",
#  "[CLS]'s result itself. [SEP]",
#  "[CLS] isit won't. [SEP]",
#  '[CLS] becomes of recreates. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] like. [SEP]',
#  '[CLS] finds foron. [SEP]',
#  '[CLS] the is thated. [SEP]',
#  '[CLS] while.... [SEP]',
#  '[CLS] alative talely about. [SEP]',
#  "[CLS] although's is,'s. [SEP]",
#  '[CLS] anial. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] ;ing. [SEP]',
#  "[CLS] isn't to, but. [SEP]",
#  '[CLS]light to be, horrifyingly,. [SEP]',
#  '[CLS] the mind to, isly. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] there's recommend, oneism. [SEP]",
#  '[CLS]ious. [SEP]',
#  '[CLS] theiest perpetrated by is into - and a. [SEP]',
#  '[CLS]voking even. [SEP]',
#  '[CLS] role. [SEP]',
#  '[CLS] takes toer. [SEP]',
#  "[CLS] by,'s than at the t role. [SEP]",
#  '[CLS] whilefully,ly up. [SEP]',
#  "[CLS] the shouldn't be, but bam. [SEP]",
#  '[CLS] is of. [SEP]',
#  '[CLS] us [SEP]',
#  "[CLS],'s. [SEP]",
#  '[CLS] suffers from. [SEP]',
#  "[CLS] has'opera the to on '. [SEP]",
#  "[CLS] don't `'with of. [SEP]",
#  '[CLS] powers inmber is, that nevertheless ride. [SEP]',
#  '[CLS] the of by,less. [SEP]',
#  '[CLS] is. [SEP]',
#  "[CLS],'s to. [SEP]",
#  '[CLS] substitute for. [SEP]',
#  '[CLS] the question is. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS] it of the solomonic decision and. [SEP]',
#  "[CLS]ei so'to, in of. [SEP]",
#  '[CLS] but what is. [SEP]',
#  '[CLS] done. [SEP]',
#  '[CLS] bothable of to. [SEP]',
#  "[CLS] a with - which is to say that doesn't explore. [SEP]",
#  "[CLS] a's. [SEP]",
#  '[CLS] -b. [SEP]',
#  '[CLS] this part, with. [SEP]',
#  '[CLS] can detract from that moral favorite :. [SEP]',
#  "[CLS] `'and advantage. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS]. [SEP]',
#  '[CLS]y - - good. [SEP]',
#  "[CLS] they at've been even if. [SEP]",
#  "[CLS] ` `''. [SEP]",
#  '[CLS] thely... this makes but. [SEP]',
#  '[CLS] a clash that, in to, captures of. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS]'s. [SEP]",
#  "[CLS] -rb - - ad i, i'd than were by. [SEP]",
#  '[CLS] the picture heart, people,ce. [SEP]',
#  '[CLS]y? [SEP]',
#  "[CLS] its,'s emerges as. [SEP]",
#  '[CLS] n t t. [SEP]',
#  '[CLS] is guess for, like in the [SEP]',
#  "[CLS]'s, throughout. [SEP]",
#  '[CLS] and be to. [SEP]',
#  '[CLS] the film ising.... [SEP]',
#  '[CLS] can be `. except that in one. [SEP]',
#  '[CLS] fontainefully creates of, inex,,. [SEP]',
#  '[CLS]. [SEP]',
#  "[CLS] this'and,. [SEP]",
#  '[CLS]... on the that of monster truck whosely knowledge from. [SEP]',
#  '[CLS] mes... up. [SEP]',
#  "[CLS] needn't. [SEP]",
#  '[CLS] even with. [SEP]',
#  "[CLS]ates the ofelling,'cowardlyque. [SEP]",
#  '[CLS] it, unatic,, and moore leaves. [SEP]',
#  "[CLS] soldiers doesn'tcend -s out of. [SEP]",
#  "[CLS]'s may be, but love's itself, to achieve. [SEP]",
#  '[CLS] it feel weird \\ / about in world \\ \\ / starring queens [SEP]',
#  '[CLS] but. [SEP]',
#  "[CLS] what'' ve like. [SEP]",
#  "[CLS] a weird's enough while it, acting moments.'ss. [SEP]",
#  '[CLS] thisvoking york has. [SEP]',
#  '[CLS].. a. [SEP]',
#  '[CLS] - ahem, s. [SEP]',
#  '[CLS] feels to than in. [SEP]',
#  "[CLS]'seen. [SEP]",
#  "[CLS] any attempts is out by's. [SEP]",
#  '[CLS]. [SEP]',
#  '[CLS] style - andy has - been. [SEP]',
#  '[CLS]s, book. [SEP]',
#  "[CLS] scers,rling and assuming's... [SEP]",
#  "[CLS] it doesn't way gripping is. [SEP]",
#  '[CLS] serving sara is than. [SEP]']

# %% [markdown]
# ### bilstm

# %%
sentence_word_token
# Out:
# ['[CLS] ludicrous, but [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] quitting, however, manages just performance [PAD] [PAD] [PAD] to. [PAD]',
#  '[CLS] the strength of the film woll lies sventer in its two by',
#  '[CLS] a tasty masala [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] angel presents events partly from theelle of perspective and christ aurelie',
#  '[CLS] a terrific date movie [PAD] [PAD] [PAD], [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS]... too sappy [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] while the now 72 - year old robert - evans [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] despite [PAD] be [PAD]sson's [PAD] high [SEP] - profile [PAD] name",
#  '[CLS] there cast has ensemble romance [SEP] been ofs apart itself by a sets',
#  '[CLS] one of the best looking a [PAD] [PAD] [PAD] [SEP]... while',
#  '[CLS]s jeff has created atakingly assured breath and stylish work',
#  '[CLS] kids five fast and the, up with delighted be will funny, [PAD]',
#  '[CLS] the movie is like scors [PAD] old [PAD] s mean [PAD] `ese',
#  "[CLS] ` ` frail `ty simple a `'even!mitdam god",
#  '[CLS] delirious [PAD] fun [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's just. smart [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] it doesn'them uses as t and markers, for about the",
#  "[CLS] it's as if solondz had, to could't",
#  '[CLS] the modern - day royals have nothing on these [PAD] [PAD] [PAD] guys [PAD]',
#  '[CLS] nothing wrong with performances here [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] lightweight but appealing. [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] this story of unrequited love does sustainn't hour",
#  '[CLS] can be as as 9 tiresome seconds of [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it plods along method that its assumption `ically dead the ` wife',
#  '[CLS] resurrection has of being the a distinction dubious really of imitation bad the [PAD]',
#  '[CLS] two badly interlock by drowneded all stories [PAD] [PAD] [PAD] too [PAD]',
#  '[CLS] the movie generates plot points [PAD] [PAD] [PAD] [PAD] [PAD] with usually [PAD] achieved',
#  '[CLS] while somewhat less have been, the might film than [PAD] [PAD] it [PAD]',
#  '[CLS] a comedy that is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD].',
#  '[CLS] the leaping story of signs and the lines cutting richiver all sl',
#  '[CLS] i was feeling this movie it until veered off too far into,',
#  '[CLS] coral reef adventure is a heavyweight film that fights a behalf of on [PAD]',
#  '[CLS] the film grows [PAD] [PAD] [PAD] [PAD] on [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] he allows his cast members to make [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a story about intelligent high school students first [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] manages to please its intended audience - - children - - without placing their',
#  "[CLS] if you think it s clothes'see ', rob woman to schneider",
#  '[CLS] a directorial tour de force by [PAD] [PAD] [PAD] bernard [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a lot smarter than your [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the problem of with all this : it [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] although it starts off so bad like feel that you running out eventually,',
#  '[CLS] a decent - enoughr that stands bite - nail a [PAD] [PAD] [PAD]',
#  '[CLS] with its about the all benjamin lack,s [PAD] and [PAD] [PAD] [PAD]',
#  '[CLS] an uncluttered, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] res [PAD] [PAD]',
#  '[CLS] an romantic intelligent thriller of a very old - school [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] first - time director joao to unwilling pedroness define'' [PAD] s",
#  '[CLS] entirely appropriately, like the as talefold un lazy crisp the [PAD]',
#  '[CLS] a whole fun of lot and though, middle somewhat funny the in less',
#  '[CLS] the biggest problem with [PAD] [PAD] [PAD] [PAD] satin [PAD] [PAD] rouge is [PAD]',
#  '[CLS] there is little question that this is in the a, flip to by',
#  '[CLS] the leads we are given here are simply too bland [PAD] [PAD] [PAD] [PAD]',
#  '[SEP] [CLS] over thisrin win picture sp ofkled with that lump sympathy is',
#  '[CLS] could use a little more [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] an earnest, roughsho region for the's as a recentr",
#  '[CLS] it takes a really long slow, andear dry timeting is',
#  '[CLS] horns and haloend serip from benefitsitys but [PAD] [PAD] to',
#  '[CLS] neither the funniest film eddie that murphy nor robert ni dero',
#  '[CLS] it looks good, but it is [PAD] [PAD] [PAD] essentially [PAD] [PAD].',
#  '[CLS] the production values are the of highest and [PAD] [PAD] [PAD] [PAD] the [PAD]',
#  '[CLS] a sensitive [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP] [PAD]',
#  '[CLS] the story has its redunda and [PAD] [PAD] [PAD] [PAD] thencies [PAD]',
#  '[CLS] clockstoppers is one of up - films mixed those, crazy [PAD]',
#  '[CLS] the merchant - ivory team continues destroy to systematically everything [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] there's a reason why halftime is [PAD] [PAD] [PAD] only [PAD] long",
#  "[CLS] rubbo's humorousiousent interventionly tend into [PAD] [PAD] [PAD]",
#  "[CLS] it's the finally to move him perfect allowing away from his,",
#  '[CLS] a smart, sassy and exceptionally [PAD] [PAD] [PAD] [PAD] [SEP] [PAD] [PAD]',
#  '[CLS] a lovably old - school [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] although the subject matter may still be the too, film events [PAD] [PAD]',
#  "[CLS] i have a confession to make : i did n'[PAD] time [PAD]",
#  '[CLS] a cutesy romantic tale a with [PAD] [PAD] twist [PAD] [PAD] [PAD] [SEP]',
#  '[CLS] the film has several strong [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] hard, endearing, caring, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is one [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD].',
#  "[SEP] s [CLS]lowk filmmakersicz dana jan - mann'and world the",
#  "[CLS] crudup's thing [PAD] one screen [PAD] is that [PAD] [PAD]",
#  "[CLS] jeong - hyang is film dec lee s'[PAD] [PAD] [PAD]",
#  '[CLS] buy popcorn. [PAD] [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] and it is. [PAD] [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] however, it enough pleasant's and [PAD] [PAD] [PAD] [PAD] wildlife -",
#  '[CLS] a college story that works even [PAD] [PAD] [PAD] without [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] too bland and fuful to besti tastely truly [PAD] [PAD] [PAD]',
#  "[CLS] it's far fromoth a fry piece and,, complex",
#  '[CLS] overburdened with complicated [PAD] and plotting [PAD] [PAD] [PAD] ban [PAD]',
#  "[CLS] what is that circuit'to aboutfer enables spaces it sha camera navigate",
#  '[SEP]rigue [CLS] at three hours int and with for cultural editing very the any',
#  "[CLS] has an uppity musical you beat can to energy compare t '",
#  '[CLS] a shimmeringly art - in age of shot lovely portrait coming, -',
#  '[CLS] proves a lovely tri unfortunately,fle, that is a [PAD] [PAD] [PAD]',
#  '[CLS] the filmmakers satire and tryve resultsisi that [PAD] [PAD] inc sometimes are',
#  '[CLS] the script covers huge heavy, topics in way a thaty surface does',
#  '[CLS] brutally honest and humor and told po withignancy [PAD] [PAD] [PAD],',
#  "[CLS] roman polanski [PAD] [PAD] [PAD]'[PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] just because a walk to remember is shrewd enough to activate girl',
#  '[CLS] reno himself can take credit for most [PAD] [PAD] [PAD] [PAD] [PAD] of [PAD]',
#  "[CLS] so purely enjoyable not might that even notice you'it [PAD] s [PAD]",
#  '[CLS] skin of man gets its shocks from cheap a few kids - [PAD] in',
#  '[CLS] please. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's a sharp movie [PAD] [PAD] about [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] well, it probably won't have the trees ho swinging you",
#  '[CLS] an impond and - consciously self arttedy [PAD] [PAD] movieera',
#  '[CLS] a terrific b movie - in - fact, [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a a about sermon sweet tender 12, - god more year old welsh',
#  "[SEP] [CLS] [PAD] barney.'s ideas material about actual of can creation and",
#  '[CLS] did it move me to about care what happened [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[SEP] middlek [CLS] pay of there baba is humane quily bold s '",
#  '[CLS] devos delivers a perfect [PAD] [PAD] [PAD] performance [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] in old - fashioned,lance screen too ms proved parwriting novel difficult',
#  '[CLS] a zippy mediocre special of 96 effects, ho dialogueary',
#  '[CLS] there has to be a few advantages growing to never old [PAD]. [PAD]',
#  '[CLS] check your brain and your secret agent going on deco [PAD] s [PAD] [PAD]',
#  "[CLS] let's see a, haunted house b, ghostlim a,",
#  '[CLS] like smoke signals, the strong film themes with isedbu also of',
#  '[CLS] - lrb - grant - rrb - goes and beyond st fluttering',
#  '[CLS] this is a that movie itcite churn ups so ex not',
#  '[CLS] cherish is a a - du romantic -d comedy [PAD] [PAD] [PAD]',
#  '[CLS] those who love cinema find the new will paradiso scenes interesting,',
#  '[CLS] lan yu seems altogether too slight to be [PAD] [PAD] [PAD] [PAD] called [PAD]',
#  '[CLS] the filmmakers want nothing else than to show [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] eight legged freaks falls a flat as sp [PAD] [PAD] [PAD]oof [PAD] [PAD]',
#  '[CLS] the lady and the duke is to [PAD] [PAD] [PAD] [PAD]s [PAD] depict',
#  '[CLS] there is a improvisation to and this certain film experimentation that not of may',
#  '[CLS] invigorating, surreal, and resonant [PAD] [PAD] [PAD]',
#  '[CLS] but not without chees [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the low - empha keylytic direction [PAD] pleasing [PAD] [PAD] in',
#  "[CLS] here's doly everything to who human create possible characters aie",
#  '[CLS] a stylish [PAD] [PAD] [PAD] thriller [PAD] [SEP] [PAD] [PAD]. [PAD]',
#  '[CLS] all three women deliver [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] remarkable [PAD] [PAD] [PAD]',
#  '[CLS] the film presents viscera thel about [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] niccol the filmmaker merges his collaborators [PAD] [PAD] [PAD] [PAD]'[PAD]",
#  '[CLS]... there is enough originality number - by often so romantic',
#  "[CLS] it's not nearly as fresh or enjoyable as its from [PAD] [PAD]",
#  '[CLS] the symbols float like butterflies and the [PAD] [PAD] [PAD] [PAD] spinning [PAD] [PAD]',
#  '[CLS] what begins brightly gets bogged down [PAD] [PAD] over [PAD] [PAD] 140 [PAD]',
#  '[CLS]... familiar and fran predictablec - director - rrb writer',
#  "[CLS] i don't think [PAD] [PAD] so [PAD] [PAD] [PAD] [PAD].",
#  '[CLS] a reasonably entertaining sequel [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] woody, what happened? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] one of the most recent [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]. years of',
#  '[CLS] it throws quirky characters, odd situations, and, off ` say',
#  '[CLS] rumor, a about coming mud drama todled, death feels, terms',
#  '[CLS] something has been lost in the routine translation another hollywood.. [PAD].',
#  '[CLS] a sharp satire of desperation and [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] presents nothing special and, final until the act, [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] coupling disgracefully written dialogue with flailing [PAD] [PAD] bodily for [PAD] substitute',
#  '[CLS] weighty and ponderous but every bit as as filling [PAD] [PAD] [PAD]',
#  "[CLS] jac to s able strategyqu allows 'ot being demonstrating give [PAD]",
#  '[CLS] the wild movie is thorns pleasantberry enough and [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] nice piece of work [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]. [PAD] [PAD] [PAD]',
#  '[CLS] the saigon of 1952 is an uneasy of mix sensual delights [PAD] [PAD]',
#  "[CLS] it's easy it butney - tun - she to robin '",
#  '[CLS] a cartoon? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] blue crush is so prolonged and boring to it being close the - burning',
#  '[CLS] if on through you push can the slow spots, you [PAD] [PAD] [PAD]',
#  '[CLS] this mild - c manner john. ofed far its,ce,',
#  '[CLS] ` ` auto and era playboy the iners swing male of document bio',
#  '[CLS] be should required for viewing civics classes and would [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] cal is an unpleasant andly shallow immature [PAD] [PAD] character [PAD] [PAD] whom',
#  '[CLS] if only merchant paid more [PAD] [PAD] [PAD] [PAD] attention [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] does not go far enough in its humor or stock out stand ideas to',
#  "[CLS] not a strike against yang's similarly themed but yi yi, i",
#  '[CLS] a captivating new [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] there are so few films about [PAD] [PAD] [PAD] [PAD] [PAD] the [PAD] [PAD]',
#  "[CLS] don't - have t'n do you if - with",
#  "[CLS] everything about girls ca n even, its swim passages't of [PAD]",
#  "[CLS] resident evil is n'[PAD] and [PAD], t [PAD] [PAD] [PAD] an",
#  '[CLS] plays like some corn by agon [PAD] [PAD]y from [PAD] television production',
#  '[CLS] nothing but an episode of smackdown! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] director roger enough just sweetmble offers ku and traditional [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] just about horror school the - film old best of straight - up,',
#  '[CLS] who, exactly, is fighting whom here [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the story that of romance [PAD] emerges [PAD] [PAD] elements [PAD] [PAD] [PAD] has',
#  '[CLS]... less a story than an horror new acceptance to each.',
#  '[CLS] the rollerball sequences [PAD] [PAD] feel [PAD] [PAD]ed [PAD] anditis [PAD]',
#  '[CLS] much of the lady and quiet about, between moments is decisive members the',
#  '[CLS]... ` ` bowling for cols - thought andngeti',
#  "[CLS] it's still makes it a but maguire, book comic [PAD] [PAD]",
#  '[CLS] a muddy psychological thriller ri [PAD] [PAD] [PAD] [PAD] [PAD] mis [PAD] [PAD] [PAD]',
#  '[CLS] maelstrom is strange and compelling eng,rossing [PAD] and different',
#  '[CLS] one big blustery movie [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] the re - release of apollo s 13 ron in'howard the im",
#  '[CLS] weird. [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a retread of material already thoroughly plumbed by [PAD] [PAD] [PAD]',
#  '[CLS] some like it hot on the hardwood proves once [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] yet this one makes up for in heart [PAD] [PAD] [PAD] what [PAD] [PAD]',
#  '[CLS] worth a to trying salute [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] be [PAD] [PAD]',
#  '[CLS] the uneven movie does and charms have its its funny [PAD] not [PAD] but',
#  '[CLS] a harrowing account of a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] psychological',
#  '[CLS] just send it to cranky [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's as the [PAD] [PAD] old [PAD] [PAD] [PAD], [PAD] [PAD]",
#  "[CLS] yet it'bust sing - film not it'genre s been",
#  '[CLS] a passionately the insitqui truthive [PAD] [PAD] [PAD] uncover [PAD]',
#  "[CLS] ` matrix'-upt throughout movie has the style er a massacre.",
#  '[CLS] a sham construct based on [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[PAD] [PAD] [PAD] [SEP] [CLS] when, at. the end the artist martial now',
#  '[CLS] imam red a bridge underura has water is said that warm the to',
#  '[CLS] the very definition come have of to what critics. [PAD] [PAD] [PAD] [SEP]',
#  '[CLS] provides a satisfactory world of bizarre extreme [PAD] athletes overview [PAD] [PAD] [PAD] as',
#  "[CLS] sc2 is hollywoodlot con anpico autoction full's",
#  '[CLS] while the humor is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] seems content to paddle in dog - the med [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] michael moore, politically of artzing has the highlyndied ag perfect',
#  '[CLS] - style cross - country of live adventure burstsliness,.stick and',
#  '[CLS] melds derivative is that into something elements often quite rich and exciting,',
#  '[CLS] alan and his fellow [PAD] [PAD] are [PAD] [PAD] survivors id [PAD] [PAD] [PAD]',
#  '[CLS] it is a li [PAD] [PAD] [PAD]ka [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] another useless recycling of a brutal'- mid 70s american sports [SEP] movie",
#  '[CLS] an enthralling [PAD] [PAD] [PAD], [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] instead of hitting the audience over [PAD] [PAD] [PAD] [PAD] the [PAD] [PAD] [PAD]',
#  "[CLS] the master of disguise'performer circus dead ` `, funny'`",
#  '[CLS] a timid, soggy near [PAD] [PAD] [PAD] [PAD] [PAD] miss [PAD]',
#  "[CLS] tries too hard to too way be a that in funny ', goofy",
#  '[CLS] sure, i hated myself [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] in',
#  "[CLS] it's cat evenego impossible torize [PAD] [PAD] this [PAD] guilty",
#  '[SEP]. to spend an two a upon depending -rb l - dated little',
#  '[CLS]... one resurrection too many [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] by turns numbingly dull [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] - and [PAD]',
#  '[CLS] only at the prospect of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this fascinating experiment plays as of more a poetic reality strict a creating than',
#  '[CLS] a visually flash opaque andyly [PAD] [PAD] [PAD] [PAD] emotionally [PAD] [PAD]',
#  '[CLS] - l -rb the digital effects - rrb - reminded me of',
#  '[CLS] trapped presents a frightening and compelling ` [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] no.. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] cinematic poetry showcases old - s the [PAD] [PAD] [PAD] world'[PAD] [PAD]",
#  '[CLS] for all its quality, brooding ash wednesday is [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it develops rapidly into a gut - cultural differences wren way [PAD] [PAD] [PAD]',
#  '[CLS] but they fasc [PAD] [PAD] [PAD]inate [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it establishes its ominous and mood, never suspense rises if and swiftly the',
#  '[CLS] whether you like it or not is [PAD] [PAD] basically a matter [PAD] of',
#  '[CLS] there are a el thateva of things couplete of the ` glory',
#  '[SEP] [CLS] the filmrb was produced and demographic lally waypro the over',
#  '[CLS] the first hour is tedious and though nee hold fordablyson cap',
#  '[CLS] although of devoid objectivity and full of nos aged boys - middle now',
#  '[CLS] as played by,sling ryan danny go is [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's a that fairy comes tale from a allows that [PAD] [PAD]",
#  '[CLS] we can tell is supposed what it to be, [PAD] [PAD] [PAD] but',
#  "[CLS] it's sort of with play a morality a [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a cautionary [PAD] [PAD] tale [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] michel piccol [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] rock's stand - up magic wan [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] what is could opera soap actually have daytime a been a compelling [PAD] [PAD]',
#  '[CLS] wonder of wonders - - a teen [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] movie',
#  '[CLS] while it is interesting to witness the [PAD] long [PAD]ley [PAD] [PAD] [PAD]',
#  '[CLS] it collapses when mr. taylor tries to shift the tone [PAD] [PAD] [PAD]',
#  '[CLS] has enough wit not only energy and also but the, people please fan',
#  '[CLS] delivers roughly equal of amounts beautiful movement [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] inside',
#  "[CLS] below may not mark mr. twohy's emergence [PAD] [PAD] [PAD]",
#  "[CLS] wouldn't it soldiers went of allied undercover be bunch funny [PAD]",
#  '[CLS] a wonderful made that up studyly for [PAD] [PAD] character [PAD] [PAD] speculative',
#  '[CLS] bravo for history rewritten, un and the forcom [PAD] [PAD] [PAD]',
#  "[CLS] but they do n'and [PAD] is [PAD] neither t [PAD] well together",
#  '[SEP] around to world [CLS] communicate images fr the the in spite of truthei',
#  "[CLS] i don't think all [PAD] at [PAD] [PAD] this. [PAD]",
#  '[CLS] by no but it, is means movie a great a [PAD] [PAD] [PAD]',
#  "[CLS] it's andable com at laughpu oncels [PAD] [PAD]ively",
#  '[CLS] rarely, indeed almost never such watt pitch - is coupled highpower brain',
#  '[CLS] flashy ga anddgetshir wling fight sequences may look cool [PAD]',
#  '[CLS] tadpole may be one of the most appealing movies everall app made',
#  "[CLS] scherfi desperation is emotionalg light s'aching of - hearted",
#  '[CLS] the sound of gunfire and cell phones [PAD] [PAD] [PAD] ringing [PAD] [PAD] [PAD]',
#  '[CLS] - l -rb d - rrb - espite its ice',
#  '[CLS] however sincere it may justifies [PAD] be [PAD] [PAD] its [PAD] [PAD] [PAD]',
#  '[CLS] kiarostam toi managed and hasly childreneptive convey casual to',
#  '[CLS] death to sm mis [PAD], [PAD]oo [PAD] but [PAD] funnyant [PAD]',
#  '[CLS] a into stumble whors very a ski two agetti - aboutsh',
#  '[CLS]... the wholegy [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP].',
#  "[CLS] will anyone who isr be nscribe't sub a excited fang",
#  "[SEP] [PAD].yhin'waste hawke'n does, hours two nearly",
#  '[CLS] more of the same from news is good which taiwanese [PAD] to [PAD] [PAD]',
#  '[CLS] a po andignant its gently loves characters humorous that and parable [PAD]',
#  "[CLS] what's surprising about thistee [PAD] [PAD] completely [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] it's definitely sand not of even fansler think i made for",
#  '[CLS] first - time writer - director dylan kidd also [PAD] [PAD] [PAD] [PAD] has',
#  '[CLS] a lot of [PAD] [PAD] the a [PAD] lost credit bit [PAD] on [SEP]',
#  '[CLS] the biggest [PAD] [PAD] [SEP] [PAD] problem [PAD]. growing [PAD] ib have',
#  '[CLS] a moving essay [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a smart, arch [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] there is a general of air [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] little is done to support the premise other than fling [PAD] gag [PAD] [PAD]',
#  '[CLS] cho continues her exploration of the outer limits of ra [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it ai, by art n t'yearteeske mu lame s",
#  '[CLS] eddie murphy and movie the but owen have wilson around a, cute partnership',
#  '[CLS] what redeem films the is the cast [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] kapur weighs down theus tale bog prof with [PAD] [PAD] [PAD]und',
#  "[CLS] pretend it's a werewolf itself by avoiding [PAD] [PAD] eye [PAD] contact",
#  '[CLS] cattaneo reworks the formula that a monty made smashing full [PAD]',
#  "[CLS] c'mon! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] was i scared? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[SEP] [CLS] love our makes and what, hearts holly a know of and bitter',
#  '[CLS] too ordinary to [PAD] [PAD] restore [SEP] - rr [PAD] harmon - -b',
#  '[CLS] adam sandler! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the importance of [PAD] [PAD] being [PAD] like [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a little too appetite ponder for [PAD]ous [PAD] s [PAD] [PAD] to [PAD]',
#  "[CLS] the film where, hour nearly'final all s the previous unseen material",
#  '[CLS] romantic, riveting and handsome [PAD] [PAD] [PAD]ly [PAD] [PAD] [PAD]',
#  '[SEP] ti thes blend with une [CLS]rb l - - toasily',
#  '[CLS] watching junk like this of induce abstract kind [PAD]s [PAD] [PAD] a [PAD]',
#  '[CLS] though it certain of lacks a a robust authority of the [PAD] genre [PAD]',
#  '[CLS] an ingenious and often harrowing look [PAD] at [PAD] [PAD] [PAD]',
#  "[CLS] whatever the movie h,'sentimental syp its [PAD] [PAD] [PAD]oc",
#  '[CLS] a well - crafted letdown [PAD] [PAD] [PAD]. [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it may not be, but innovative particularly gentle of the longing make air',
#  '[CLS] - l -rb sports - rrb - admirable energy,',
#  '[CLS] a wonderful, ghas [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] what's surprising is how well [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] a pl engagingeth ofora diatribes [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a ` ` [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[PAD] [SEP] [PAD]. [CLS] a by find plagued that superfl. of feeling',
#  "[CLS] it's not particularly well made but, since i howling more found",
#  "[CLS] fans of so - bad - they're [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] ` tad year the of more really s'it but, declared this",
#  '[CLS] writer - director stephen gag has madehan the near [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a small movie with [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] disappointing in comparison war recent to other movies. woo [SEP]. matter that',
#  '[CLS] this is a third - person story now, [PAD] more much told [PAD]',
#  '[CLS] it gets of details the its time right frame but it its [PAD] completely',
#  "[CLS] my wife special ; nothing'it [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] it's impossible to indulge [PAD] [PAD] vacant [SEP] [PAD] the",
#  "[CLS] it's always watch to marker fascinating [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] this sade is hardly aita ag pertorverse - [PAD] have',
#  "[CLS] what's infuriating about'it full that is frontal s",
#  '[CLS] graced social of texture kind with the and would realism be that [PAD]',
#  '[CLS] the most ingenious film [PAD] [PAD] [PAD] [PAD] comedy [PAD] since [PAD]',
#  '[CLS] a dark - as -ers ve [PAD] [PAD] after pitch [PAD] [PAD] [PAD]',
#  '[CLS] boasts enough funny dialogue and sharp characterization [PAD] [PAD] [PAD] [PAD]s [PAD] [PAD]',
#  '[CLS] the filmmakers might want to look [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it gets old quickly. [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] surprisingly insightful [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] strange it is, but delightful [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a clever script and skilled [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] actors [PAD]',
#  '[CLS] since dahm wheners it resorts should thrill mind be of to',
#  '[CLS] if they into snapping out broke finger elaborate it and choreography might singing,',
#  "[CLS] the journey to the secret'[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] the film is strictly routine [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] to this of film get would psychology at root the require on the sessions',
#  '[CLS] why did they deem all document to it this necessary emotional misery [PAD]',
#  '[CLS] its metaphors are opaque enough [PAD] [PAD] [PAD] [PAD] [PAD] to [PAD] [PAD]',
#  '[CLS] samuel beckett applied to the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] iranian [PAD] [PAD]',
#  '[CLS] technically and artistically in [PAD] [PAD]ept [PAD] [PAD]. [PAD] [PAD] [SEP]',
#  '[CLS] ` it looks good, sonny [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's rare which to the to adjective find a film ` gentle",
#  "[CLS] average, at best, i m'afraid [PAD] [PAD] [PAD] [PAD].",
#  '[CLS] guys say mean things and shoot a [PAD] [PAD] lot [PAD] of [PAD] bullets',
#  '[CLS] a different a -rac - ref and of survival story film typeting',
#  '[CLS] offers a per at look aveasisu. [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] interview with the assassin such as is the less as structured and film a',
#  '[CLS] - l -rb a - rrb - painfully flat gross - out',
#  "[CLS] by the end youd [PAD] [PAD] [PAD] [PAD] [PAD] [SEP] '. feel",
#  '[CLS] the cast pretty this watch. keeps..able, director as of',
#  '[CLS] so mind - numbingly awful that you hope one britney it more do',
#  '[CLS] a terrifically entertaining specimen of spielberg [PAD] [PAD] [PAD] [PAD] [PAD]ian [PAD]',
#  "[CLS] lacking substance and cut s soul'[PAD]offs [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] the film ultimately offers nothing people than more in an [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] children and adults enamored of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the script manages the rare trick of seeming at refreshing once bothly [PAD]',
#  '[CLS] symbolically, under water a warm bridge red is a feminine power the',
#  "[CLS] it's truly awful and heartbreak [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[SEP] [CLS] '. the lanes a spark star flat changing falls'' to",
#  "[CLS] it's absolutely amazing find to something how - first [PAD] [PAD] new",
#  "[CLS] there's back - stabbing, inter - racial desire [PAD] [PAD] [PAD]",
#  "[CLS] it's who unfortunate that, wrote wallace gibson's brave well",
#  "[SEP] about goes notwithstanding on based, secretary recommend to going m'i,",
#  '[CLS] after a while for a intelligent way reasonably person only [PAD] [PAD] [PAD],',
#  "[CLS] there are n'in answers the tclusive personalities pointed many film con",
#  '[CLS] the film never finds its tone and scenes run several [PAD] [PAD] too [PAD]',
#  '[CLS] very amusing, not the and, usual a in thriller route the performances',
#  '[CLS] full frontal had no and eli effectcitedathimpes [PAD] no',
#  "[CLS] brown sugar signals director rick famu as emergence syiwa'an",
#  '[CLS] talkiness is n bad necessarily the [PAD] [PAD] [PAD] [PAD] [SEP]. mark',
#  '[CLS] do we really need [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] you leave the same way you came - - a few ta newsty',
#  '[CLS] too long and la somber cop thisrde,, drama expositiond ultimately',
#  '[CLS] abandon spends 90 minutes trying pseudo - cocky intellectual [PAD] [PAD] not some [PAD]',
#  "[CLS] this ready - made midnight movie probably won't stand goofy -",
#  '[CLS] and neither do cliches, are [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]',
#  '[CLS] great fun and forados ordinarycion lou both afi forts sports [PAD]',
#  '[CLS] an overly melod [PAD] [PAD] of - [PAD] coming - [PAD] [PAD] age',
#  '[SEP] [CLS] when - lrb - lecture reno free - rr reno dev -',
#  "[CLS] it gives devastating to testimony both evil and for people their capacity heroic '",
#  "[CLS] it's a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] treat [PAD] [PAD]",
#  "[CLS] it's a [PAD] [PAD] [PAD] window [PAD] rare [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] fans of plympton new him any [PAD] [PAD] viewers'shorts s",
#  '[CLS] despite its to flaws an almost at guessing you keeps that story engaging able',
#  '[CLS] the film is full of [PAD] [PAD] [PAD] [PAD] charm [PAD] [PAD] [SEP].',
#  "[CLS] not even solondz, sketch controversy'[PAD] [PAD] [PAD] [PAD]y",
#  '[CLS] a handsome to a but suited quiet more un suspensellingful dramafi',
#  "[CLS] filled with alexandre desplat'[PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] would make an excellent companion piece to the similarly themed [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] so aggressively cheery a for bar reach that wouldf polly [PAD]ana',
#  '[SEP] handful [CLS] with as a so to to - many appears the merchandise -',
#  '[CLS] it cooks conduct in a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] smart and alert, thirteen conversations [PAD] [PAD] [PAD] [PAD] about [PAD] [PAD] [PAD]',
#  '[CLS] a deftly directed [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]. smart',
#  '[CLS] - lrb - a - -b rr smarter and much [PAD] [PAD]',
#  '[CLS] limps along on a [PAD] [PAD] sq [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it lets you brush up against the making humanity him [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] originality is sorely lacking [PAD] [PAD]. [PAD] [PAD] [PAD] [SEP] [PAD]',
#  '[CLS] you could hate it for [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] continually challenges perceptions of guilt and innocence, of good, guys and bad',
#  '[CLS] the only fun of part the movie [PAD] [PAD] is [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] this is an and grief its of insulting impacts [PAD] [PAD] examination [PAD] relationships',
#  '[CLS] a very well, and movie meaning - it will [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] he's just a ta [PAD] [PAD] in [PAD] sadttered [PAD]crat",
#  '[CLS] mastering its of arithmetic formidable cameras and souls articulate group,s [PAD]',
#  '[CLS] they ought to be a whole lot scar [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] lovely and she is amazing women knowslo ho un tocom deepfc',
#  "[CLS] watching ` ` ending'' is too looking like often [PAD] over the",
#  "[CLS] lucy's a [PAD] [PAD] [PAD] dull [PAD] girl [PAD] [PAD] [PAD],",
#  '[CLS] charming and witty [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] maybe leblanc thought, ` ` hey, the'[SEP] [PAD]",
#  '[CLS] the four feathers has rewards the from, exoticism [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a delightful stimulus of a tale for other [PAD] [PAD] [PAD] [PAD] total [PAD]',
#  '[CLS] a wildly make in that wince you erratic sequences embarrassment [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the movie is [PAD] [PAD] [PAD] [PAD] and [PAD] even [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the whole thing plays tired like a ty [PAD] [PAD] [PAD] [PAD]co [PAD]',
#  '[CLS] genuinely unnerving. [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] lazily stone directed iii lead a charles from by.en..',
#  '[CLS] fails to convince the audience that these brat [PAD] [PAD] [PAD] [PAD]s [PAD]',
#  '[CLS] [PAD] [PAD] sounding [SEP] of like change and encountersb arc rr a arnold',
#  '[CLS] an original and highly cerebral examination of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] makes the case for a valuable and education strong in the more good teachers',
#  "[CLS] munch screenplay's is tenderly ob [PAD] [PAD] [PAD]ser [PAD] [PAD]",
#  '[CLS] there are deeply and religious would argue spiritual who [PAD] that [PAD] [PAD] [PAD]',
#  '[CLS] although mainstream american gives every viewers once, in movies that familiar a the',
#  '[CLS] the film is hard to dismiss and - - moody, thoughtful lit,',
#  '[CLS] low rent from frame one [PAD] [PAD] [PAD] [PAD]. [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] a [PAD] [PAD] [SEP] [PAD] head manhattan nighttime., a [PAD] through ride',
#  '[CLS]... may work as an neverbi am satirical questionable itss',
#  '[CLS] a waited real ever in a audience will strike - thatr chord please',
#  '[PAD] [PAD] [CLS] and, [PAD] [SEP] will undoubtedly in name is play asia an',
#  "[CLS] we've before in all seen it one form [PAD] [PAD] but,",
#  '[CLS] puts a refreshing on the spin all [PAD] [PAD] [PAD] and [PAD] [PAD] [PAD]',
#  '[CLS] unfortunately the story and the [PAD] [PAD] [PAD] actors [PAD] a are [PAD] hack',
#  '[CLS] nearly all the fundamentals take for you granted [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] there is of power pol noans the denying [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] has ahouli certain gsh fascination, and [PAD] [PAD] [PAD] generates',
#  "[CLS] much of the movie's charm lies [PAD] [PAD] [PAD] ofness [PAD]",
#  "[CLS] with ator starringita ` a im ` kids `'' spy",
#  '[CLS] together - lrb - resources and - out human time rrb -',
#  "[CLS] there's some but, good in the their retail material clerk story",
#  '[CLS] shallow. [PAD] [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] instead of pan sweep,oramic kadicisopur ep gives chop',
#  '[CLS] this is no [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]',
#  '[CLS] one of the movie [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP].making life',
#  "[CLS] it's a clear - eyed moral ambiguity portrait, and [PAD] [PAD]",
#  "[CLS] conform who's. s a itself game creating with are of moves",
#  "[CLS] there's a lot to [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  "[CLS] nelson's intentions are [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] good [PAD] [PAD]",
#  '[CLS] a literary detective story is still a detective [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] becomes a physical the setting and [PAD] [PAD] isolation emotional [PAD] [PAD] and [PAD]',
#  '[CLS] a stirring road [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] pretend like your sat [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] campbell for his flick scott outlet ideal the - finds the in [PAD] role',
#  '[CLS] the difference between cho and [PAD] [PAD] most [PAD] [PAD] [PAD] comics [PAD] [PAD]',
#  '[CLS] while the plot predictable connect follows - a the [PAD] director [PAD] - [PAD]',
#  '[CLS] a mani as apu posingly seriouslative thin [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] although este sla'documentaryoy bravo is clingly hagiographic",
#  '[CLS] an odd, haphazard, and inconse [PAD] [PAD] [PAD]',
#  '[CLS] about schmidt is undoubtedly one of the finest films [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] naomi watts is as rachel frame petite terrific ; her and vulnerable persona emphasis',
#  "[CLS] sweet home alabama is n to'going t win date definitely will diversion",
#  '[CLS] a searing, ho be arri, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the word that comes to mind while, watching eric rohm tributeer',
#  '[CLS] a funny film [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] there's little tod recommend dialogueiche snow and cl dogs considers",
#  '[CLS] simplistic, silly and [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] ted [PAD]',
#  '[CLS] the ni of being earnest importanceft the is by the [PAD] [PAD] [PAD]',
#  '[CLS] intensely romantic,voking pro thought and - even [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] sorvino is delightful [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] in [PAD]',
#  '[CLS] takes a cl detailingunk to ay approach tv [PAD] movie [PAD] chapter',
#  '[CLS] highlighted by a grit might better expect s stylety than one and it',
#  '[CLS] while dutifully hearts on pullingtri valiantlyng [PAD] [PAD] [PAD]',
#  "[CLS] the [PAD] [SEP] bourne identity should n as half'be entertaining. t",
#  '[CLS] the problem is that the movie has no idea of [PAD] [PAD] [PAD] it',
#  "[CLS] noyce's greatest mistake is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] moments",
#  '[CLS] while the story does [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] suffers from all the excesses of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] mcgrath has def to povertyeringtly courage [PAD] trimmed [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] those who don't entirely ` get'will a with away",
#  '[CLS] austin powers in goldmember is car wreck, cinematic a [PAD] [PAD]',
#  '[CLS] the work of an [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] is one of this year [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] with to vietnam amazing and fines shadows backse heidi film, the the',
#  '[CLS] screenwriter dan schneider and substitute director volume shawn levy and [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] the first question to ask about [PAD] [PAD] [PAD] bad [PAD] hopkins is [PAD]',
#  '[CLS] one of the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] it offers a those turbulent in glimpse decision solomonic of the facing jewish',
#  "[CLS] mattei so completely loses s to circular himself'the film structure to",
#  '[CLS] not as good as the original, but is [PAD] [PAD] [PAD] [PAD].',
#  '[CLS] this seductive tease of a [PAD] [PAD] [PAD] [PAD] [PAD] thriller [PAD] [PAD] [PAD]',
#  '[CLS] both anmir of ad terrible reconstructionable events, and a day that',
#  '[SEP].y seam under world [CLS] criminalbell the a the explorey that',
#  "[CLS] a movie that'medio by [PAD] s [PAD]crity [PAD] [PAD]",
#  '[CLS] - l -rb an - rrb - absorbing documentary [PAD] [PAD] [PAD]',
#  '[CLS] this is for the most part with even a a [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] nothing can of affection that det the moralrac be will from friends :',
#  "[CLS] director peter ko these givesinskysm women a to forum demonstrate'and",
#  '[CLS] mama africa pretty much delivers [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] on',
#  '[CLS] i liked this film a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]. [PAD]',
#  '[CLS] too stagey, talk long [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] they threw loads of money at an ve'idea that been should so",
#  '[CLS] ` ` red [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [SEP]',
#  '[CLS] the film of skin the the makes under fearless it this not. gets',
#  '[CLS] a to culture addition being embarrassment in of and - very, being clash',
#  '[CLS] the action sequences are fun and reminiscent of [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's a documentary head talking, [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] - lrb - h - rrb - ad [PAD] [PAD] ia [PAD]',
#  '[CLS] the picture uses humor to convictionfelt tell and a heart discovering a [PAD]',
#  '[CLS] paul bettany playing malcolm [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] its audacious ambitions po bymp sabotagedosity [PAD] steven [PAD]',
#  "[CLS] don't say you were n [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[SEP] [CLS] the reality therets for is in in full frontalstor something,',
#  "[CLS] there 'aneont sity a sp to [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] the characters seem one - dimensional and the, film is superficial [PAD] [PAD]',
#  '[CLS] the film is moody, oingoz chilling,. and. a',
#  "[CLS] can be classified as one of those ` movies alternate'reality [PAD].",
#  '[CLS] fontaine master of two strong menfully in portrait creates conflict a, [PAD]',
#  '[CLS] the big ending surprise almost [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] saves [PAD] [PAD]',
#  "[CLS] this starts off with 1950 a ', very s [PAD] [PAD] [PAD] [PAD]",
#  '[CLS]... built on the premise boys monster of consists truck class arkansas',
#  '[CLS] meyje origins the and homework up soaked [PAD] revision newy jazz',
#  "[CLS] you needn't be steeped in [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] even accepting this in [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] the [PAD]',
#  '[CLS] fear permeatesortelling, st the of todd whole [PAD] [PAD]',
#  '[CLS] it has its faults, but it [PAD], is [PAD] [PAD] [PAD] una',
#  "[CLS] dog soldiers doesn't transcend genre - - it embraces",
#  "[CLS] lisa rinzler'but shala [PAD], [PAD] [PAD] in cinematography",
#  '[CLS] it makes me / feel thinking \\ weird about all world the \\ in',
#  '[CLS] but it does somehow manage [PAD] [PAD] to [PAD] [PAD] [PAD] [PAD] [PAD] get',
#  "[CLS] what ` blade ve as'looked like a would runner uhf'low",
#  "[CLS] a weird little movie that's amusing enough while. l fine acting",
#  '[CLS] this charming, thought - provoking new york fest of [PAD] [PAD] [PAD]',
#  '[CLS]... a confusing drudgery. [SEP] [PAD] [PAD] [PAD] [PAD]',
#  "[CLS] it's a spectacular performance - [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]",
#  '[CLS] feels less like a cousin to blade runner [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] one of the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD].',
#  '[CLS] any attempts at nuance by given capable [PAD] the [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] poetic, heartbreaking. [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] high drama a wing and - a, style prayer - disney and [PAD]',
#  '[CLS] nettelbeck has crafted an engaging [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]',
#  '[CLS] schn tummyied tops tight wearing anderwi and bounce t',
#  "[CLS] it doesn't gripping what offer of its way audiences any point",
#  '[CLS] serving sara is little more than a [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]']

# %%
df[df['Category']==0]
# Out:
# Empty DataFrame
# Columns: [Id, Category, Sentence, b_pred, e_pred, l_pred]
# Index: []

# %%
df_bert = pd.read_csv('./Dataset/BERT_pred.csv')
df_electra=pd.read_csv('./Dataset/ELECTRA_pred.csv')
df_bilstm=pd.read_csv('./Dataset/BILSTM_pred.csv')

# %%
df_bert.rename(columns = {'Pred': 'b_pred'}, inplace = True)
df_electra.rename(columns = {'Pred': 'e_pred'}, inplace = True)
df_bilstm.rename(columns = {'Pred': 'l_pred'}, inplace = True)

# %%
merge_bert_electra=pd.merge(df_bert,df_electra,how='inner',on=['Sentence','Category','Id'])
merge_total=pd.merge(merge_bert_electra,df_bilstm,how='inner',on=['Sentence','Category','Id'])

# %%
## electra와 bilstm이 같이 맞히는거
merge=merge_total[merge_total['e_pred']==merge_total['l_pred']] ## bert와 electra 예측 같은 경우
merge=merge[merge['l_pred']==merge['Category']]

# %%
merge[merge['Category']==3]
# Out:
#          Id  Category                                           Sentence  \
# 0       275         3  Ludicrous , but director Carl Franklin adds en...
# 3      1715         3  The strength of the film lies in its two centr...
# 5       789         3                                   A tasty masala .
# 10      384         3  A surprisingly charming and even witty match f...
# 17    10500         3  Angel presents events partly from the perspect...
# ...     ...       ...                                                ...
# 1725  11237         3  A weird little movie that 's amusing enough wh...
# 1730  11291         3  It 's a spectacular performance - ahem , we ho...
# 1736  11370         3                           Poetic , heartbreaking .
# 1739  11385         3  High drama , Disney-style - a wing and a praye...
# 1740  11425         3  Nettelbeck has crafted an engaging fantasy of ...
#
#       b_pred  e_pred  l_pred
# 0          3       3       3
# 3          3       3       3
# 5          3       3       3
# 10         4       3       3
# 17         3       3       3
# ...      ...     ...     ...
# 1725       3       3       3
# 1730       3       3       3
# 1736       3       3       3
# 1739       3       3       3
# 1740       3       3       3
#
# [284 rows x 6 columns]

# %%
merge[merge['Category']==0]
# Out:
#          Id  Category                                           Sentence  \
# 181    5335         0  The notion of deleting emotion from people , e...
# 298     612         0  The movie is so resolutely cobbled together ou...
# 340    4143         0  A 94-minute travesty of unparalleled proportio...
# 482    8888         0  It 's mired in a shabby script that piles laye...
# 490    2412         0  A loud , ugly , irritating movie without any o...
# ...     ...       ...                                                ...
# 1692  10934         0  But the movie that does n't really deliver for...
# 1699  10959         0  So muddled , repetitive and ragged that it say...
# 1712  11095         0  The problem is that it is one that allows him ...
# 1714  11114         0  There 's only one way to kill Michael Myers fo...
# 1746  11518         0  Not at all clear what it 's trying to say and ...
#
#       b_pred  e_pred  l_pred
# 181        0       1       0
# 298        0       1       0
# 340        0       1       0
# 482        0       1       0
# 490        0       1       0
# ...      ...     ...     ...
# 1692       0       1       0
# 1699       0       1       0
# 1712       0       1       0
# 1714       0       1       0
# 1746       0       1       0
#
# [117 rows x 6 columns]

# %%
merge_total[merge_total['Category']==0]
# Out:
#          Id  Category                                           Sentence  \
# 1      7037         0  It 's hard to understand why anyone in his rig...
# 28     5930         0  When it comes out on video , then it 's the pe...
# 51     9231         0                                   Just plain bad .
# 53     1350         0  More of the same old garbage Hollywood has bee...
# 56      870         0  May cause you to bite your tongue to keep from...
# ...     ...       ...                                                ...
# 1692  10934         0  But the movie that does n't really deliver for...
# 1699  10959         0  So muddled , repetitive and ragged that it say...
# 1712  11095         0  The problem is that it is one that allows him ...
# 1714  11114         0  There 's only one way to kill Michael Myers fo...
# 1746  11518         0  Not at all clear what it 's trying to say and ...
#
#       b_pred  e_pred  l_pred
# 1          0       1       3
# 28         3       3       3
# 51         1       1       1
# 53         1       1       2
# 56         1       1       3
# ...      ...     ...     ...
# 1692       0       1       0
# 1699       0       1       0
# 1712       0       1       0
# 1714       0       1       0
# 1746       0       1       0
#
# [217 rows x 6 columns]

# %%
check=merge_total[merge_total['Category']==merge_total['e_pred']]

# %%
check[check['Category']==0]
# Out:
# Empty DataFrame
# Columns: [Id, Category, Sentence, b_pred, e_pred, l_pred]
# Index: []

# %%
check=merge_total[merge_total['Category']==merge_total['e_pred']]

# %%
check[check['e_pred']==0]
# Out:
# Empty DataFrame
# Columns: [Id, Category, Sentence, b_pred, e_pred, l_pred]
# Index: []

# %%
np.unique(merge_total[merge_total['Category']==0]['e_pred'].values,return_counts=True)
# Out:
# (array([1, 2, 3], dtype=int64), array([203,   6,   8], dtype=int64))
